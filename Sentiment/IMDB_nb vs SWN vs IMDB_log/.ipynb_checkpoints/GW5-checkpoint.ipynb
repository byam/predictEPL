# %%
import pickle
import re
import os
import time

os.chdir('/Users/Bya/git/predictEPL/MyFunctions/')
import tokenizers
import senti_word_net
import featx
import replacers
import dataIO
import converter

from nltk.corpus import stopwords

from nltk.tokenize import TweetTokenizer
from nltk.stem import PorterStemmer

os.chdir('/Users/Bya/Dropbox/Research/datas/movieclassifier/')
from vectorizer import vect


# load Long IMDB model
clf = pickle.load(open(
        os.path.join('pkl_objects',
                     'classifier.pkl'), 'rb'))

# load Short IMDB model
with open("/Users/Bya/git/predictEPL/NLTK/NLTK_TUTORIAL/pickled_algos/naiveBayes_for_short_reviews_NEW.pickle", "rb") as saved_classifier_f:
    nb_classifier = pickle.load(saved_classifier_f)

def cleanHash(word):
    if word[0] == '#':
        return '#'
    elif word[0] == '@':
        return '@'
    elif word[0:4] == 'http':
        return 'http'
    else:
        return word

def sentiment_short_long_IMDB(tweet):
    
    # can't -> cannot, bya's -> bya is
    replacer = replacers.RegexpReplacer()
    tweet = replacer.replace(tweet)
    
    # Tweet tokenizer
    words = TweetTokenizer().tokenize(tweet)
    
    # defining stopwords
    english_stops = set(stopwords.words('english'))
    english_stops_added = english_stops | {'.', ',', ':', ';', '#', '?', 'RT', '-', '@', 'rt'}
    words = [word.lower() for word in words if word.lower() not in english_stops_added]
    
    # Stemmer
    porter = PorterStemmer()
    words = [porter.stem(word) for word in words]
    
    # words = map(lambda word: cleanHash(word), words)
    words = [cleanHash(word) for word in words]
    
    # defining stopwords
    english_stops_added =  {'.', ',', '!', ':', ';', '#', '?', 'RT', '-', '@', 'rt', 'http'}
    words = [word.lower() for word in words if word.lower() not in english_stops_added]
 

    # Naive Bayes: IMDB Short Reviews   
    probs = nb_classifier.prob_classify(featx.bag_of_words(words))
    short_sent = probs.max()
    short_pos = probs.prob('pos')
    short_neg = probs.prob('neg')
    
    
    # Naive Bayes: IMDB Long Reviews
    label = {0: 'neg', 1:'pos'}
    sentence = [' '.join(words)]
    X = vect.transform(sentence)
    long_sent = label[clf.predict(X)[0]]
    long_pos = clf.predict_proba(X)[0][1]
    long_neg = clf.predict_proba(X)[0][0]
    
    
    return (short_sent, short_pos, short_neg,
            long_sent, long_pos, long_neg)

# %%
# Change home directory
pathData = "/Users/Bya/Dropbox/Research/datas/"
os.chdir(pathData)

filenames = dataIO.GetFilenames('GW' + str(5) + '/SingleGames')
filenames
# Out:
# ['GW5/SingleGames/Arsenal_vs_Stoke.csv',
#  'GW5/SingleGames/Crystal_vs_City.csv',
#  'GW5/SingleGames/Everton_vs_Chelsea.csv',
#  'GW5/SingleGames/Leicester_vs_Villa.csv',
#  'GW5/SingleGames/Norwich_vs_Bournemouth.csv',
#  'GW5/SingleGames/Sunderland_vs_Tottenham.csv',
#  'GW5/SingleGames/United_vs_Liverpool.csv',
#  'GW5/SingleGames/Watford_vs_Swansea.csv',
#  'GW5/SingleGames/WestBromwich_vs_Southampton.csv',
#  'GW5/SingleGames/WestHam_vs_Newcastle.csv']

# %%
for filePath in filenames:
    start_time = time.time()

    GW = filePath.split('/')[0]
    home_team = filePath[:-4].split('/')[2].split('_')[0]
    away_team = filePath[:-4].split('/')[2].split('_')[2]
    print(GW, home_team, away_team)

    # Change home directory
    pathData = "/Users/Bya/Dropbox/Research/datas/"
    os.chdir(pathData)    

    # read csv as df
    df = dataIO.csv_dic_df(filePath)

    # add 'time' column
    df['time'] = df['date']
    df.time = [converter.toSeconds(date) for date in df.time]

    # set time
    start = converter.toSeconds(df.date[0]) - int(df['date'][0][-13:-11])

    # add 'ith_minute'
    df['ith_minute'] = (df['time'] - start) / 60

    short_sent = []
    short_pos = []
    short_neg = []
    long_sent = []
    long_pos = []
    long_neg = []

    for row in df.iterrows():
        tweet = row[1]['text']
        x,y,z,a,b,c = sentiment_short_long_IMDB(tweet)
        short_sent.append(x)
        short_pos.append(y)
        short_neg.append(z)
        long_sent.append(a)
        long_pos.append(b)
        long_neg.append(c)

    df['short_sent'] = short_sent
    df['short_pos'] = short_pos
    df['short_neg'] = short_neg
    df['long_sent'] = long_sent
    df['long_pos'] = long_pos
    df['long_neg'] = long_neg  


    savePath = '/Users/Bya/Dropbox/Research/datas/Results/NB_Short_Long/' + GW
    dataIO.DFtoCSV(df, savePath, home_team + "_vs_" + away_team, False)

    # print computing time
    print(time.time() - start_time)
# Out:
# GW5 Leicester Villa
# 10.305387020111084
#                                 date  side  \
# 0     Sun Sep 13 15:00:23 +0000 2015  both
# 1     Sun Sep 13 15:00:24 +0000 2015  home
# 2     Sun Sep 13 15:00:24 +0000 2015  away
# 3     Sun Sep 13 15:00:25 +0000 2015  both
# 4     Sun Sep 13 15:00:25 +0000 2015  home
# 5     Sun Sep 13 15:00:25 +0000 2015  away
# 6     Sun Sep 13 15:00:26 +0000 2015  away
# 7     Sun Sep 13 15:00:28 +0000 2015  both
# 8     Sun Sep 13 15:00:29 +0000 2015  away
# 9     Sun Sep 13 15:00:29 +0000 2015  both
# 10    Sun Sep 13 15:00:30 +0000 2015  home
# 11    Sun Sep 13 15:00:30 +0000 2015  both
# 12    Sun Sep 13 15:00:30 +0000 2015  both
# 13    Sun Sep 13 15:00:31 +0000 2015  both
# 14    Sun Sep 13 15:00:31 +0000 2015  home
# 15    Sun Sep 13 15:00:31 +0000 2015  away
# 16    Sun Sep 13 15:00:32 +0000 2015  both
# 17    Sun Sep 13 15:00:33 +0000 2015  away
# 18    Sun Sep 13 15:00:33 +0000 2015  both
# 19    Sun Sep 13 15:00:34 +0000 2015  away
# 20    Sun Sep 13 15:00:34 +0000 2015  away
# 21    Sun Sep 13 15:00:35 +0000 2015  away
# 22    Sun Sep 13 15:00:35 +0000 2015  home
# 23    Sun Sep 13 15:00:36 +0000 2015  both
# 24    Sun Sep 13 15:00:36 +0000 2015  away
# 25    Sun Sep 13 15:00:36 +0000 2015  away
# 26    Sun Sep 13 15:00:36 +0000 2015  home
# 27    Sun Sep 13 15:00:36 +0000 2015  both
# 28    Sun Sep 13 15:00:37 +0000 2015  both
# 29    Sun Sep 13 15:00:37 +0000 2015  both
# ...                              ...   ...
# 7014  Sun Sep 13 16:00:01 +0000 2015  both
# 7015  Sun Sep 13 16:00:02 +0000 2015  away
# 7016  Sun Sep 13 16:00:02 +0000 2015  away
# 7017  Sun Sep 13 16:00:03 +0000 2015  away
# 7018  Sun Sep 13 16:00:03 +0000 2015  both
# 7019  Sun Sep 13 16:00:03 +0000 2015  both
# 7020  Sun Sep 13 16:00:03 +0000 2015  both
# 7021  Sun Sep 13 16:00:05 +0000 2015  home
# 7022  Sun Sep 13 16:00:06 +0000 2015  away
# 7023  Sun Sep 13 16:00:06 +0000 2015  away
# 7024  Sun Sep 13 16:00:08 +0000 2015  away
# 7025  Sun Sep 13 16:00:08 +0000 2015  home
# 7026  Sun Sep 13 16:00:08 +0000 2015  both
# 7027  Sun Sep 13 16:00:08 +0000 2015  away
# 7028  Sun Sep 13 16:00:09 +0000 2015  away
# 7029  Sun Sep 13 16:00:08 +0000 2015  both
# 7030  Sun Sep 13 16:00:10 +0000 2015  away
# 7031  Sun Sep 13 16:00:10 +0000 2015  away
# 7032  Sun Sep 13 16:00:10 +0000 2015  both
# 7033  Sun Sep 13 16:00:10 +0000 2015  away
# 7034  Sun Sep 13 16:00:14 +0000 2015  both
# 7035  Sun Sep 13 16:00:16 +0000 2015  both
# 7036  Sun Sep 13 16:00:16 +0000 2015  both
# 7037  Sun Sep 13 16:00:16 +0000 2015  both
# 7038  Sun Sep 13 16:00:17 +0000 2015  both
# 7039  Sun Sep 13 16:00:17 +0000 2015  away
# 7040  Sun Sep 13 16:00:17 +0000 2015  both
# 7041  Sun Sep 13 16:00:18 +0000 2015  home
# 7042  Sun Sep 13 16:00:19 +0000 2015  both
# 7043  Sun Sep 13 16:00:21 +0000 2015  away
#
#                                                    tags  \
# 0                        leiast,avfc,lcfc,leiavl,motogp
# 1                                                  lcfc
# 2                                                  avfc
# 3           leiast,avfc,lcfc,leiavl,bpl,soccer,football
# 4                                           lcfc,leiast
# 5                                                  avfc
# 6                                                  avfc
# 7     matchday,letsgetthatwin,foxes,leicestercity,av...
# 8                                           leiavl,avfc
# 9                                  avfc,lcfc,bpl,leiavl
# 10                                          lcfc,leiast
# 11                       leiast,avfc,lcfc,leiavl,motogp
# 12                                 avfc,lcfc,bpl,leiavl
# 13                                            avfc,lcfc
# 14                                kingpowerstadium,lcfc
# 15                                        avfc,bplonnbc
# 16                                     lcfc,avfc,leiavl
# 17                                                 avfc
# 18    lcfc,bluearmy,ltid,coyf,fnq,leiavl,bpl,supersu...
# 19                                                 avfc
# 20                                                 avfc
# 21                                          leiavl,avfc
# 22                                                 lcfc
# 23                                            avfc,lcfc
# 24                                          leiavl,avfc
# 25                                                 avfc
# 26                                          lcfc,leiast
# 27           leiast,avfc,lcfc,leiavl,coys,greatnorthrun
# 28                                 avfc,lcfc,bpl,leiavl
# 29           leiast,avfc,lcfc,leiavl,coys,greatnorthrun
# ...                                                 ...
# 7014                                   avfc,lcfc,leiavl
# 7015                                               avfc
# 7016                                               avfc
# 7017                                               avfc
# 7018                                   avfc,lcfc,leiavl
# 7019                                   lcfc,avfc,leiavl
# 7020                                   lcfc,avfc,leiavl
# 7021                                               lcfc
# 7022                                 mcfc,mufc,cfc,avfc
# 7023              avfc,astonvilla,jackgrealish,grealish
# 7024     europeisthebest,coys,avfc,idolssa,roalddahlday
# 7025                                               lcfc
# 7026                                   lcfc,avfc,leiavl
# 7027                                               avfc
# 7028          europeisthebest,ospvmun,avfc,coys,camogie
# 7029                                   lcfc,avfc,leiavl
# 7030                                               avfc
# 7031                                               avfc
# 7032                                   lcfc,avfc,leiavl
# 7033           europeisthebest,coys,idolssa,avfc,trndnl
# 7034                                   lcfc,avfc,leiavl
# 7035                                   lcfc,avfc,leiavl
# 7036                                   lcfc,avfc,leiavl
# 7037                                          lcfc,avfc
# 7038                                   avfc,lcfc,leiavl
# 7039                                               avfc
# 7040                                   lcfc,avfc,leiavl
# 7041                                               lcfc
# 7042                                   lcfc,avfc,leiavl
# 7043                                               avfc
#
#                                                    text             user  \
# 0     Leicester City VS Aston Villa\n\nLive Stream :...        OzgeFerah
# 1     RT @LetsRantLcfc: EVERYWHERE WE GO, WE'RE LEIC...      jody_hovell
# 2     Big test for Amavi against Mahrez today! Come ...   TheHolteTweets
# 3     Leicester City VS Aston Villa\n\nLive Stream :...       sewimkayaa
# 4     KICK-OFF: We are under way at the King Power S...       Merc_Sport
# 5                              COME ON YOU LIONS! #AVFC       Ringo11Lee
# 6                             worry worry worry ! #avfc    ElectriCheese
# 7     Leicester City V Aston Villa\n\nLive Stream : ...        OzgeFerah
# 8     RT @AVFCOfficial: It's showtime! Villa to kick...    Charlthevamps
# 9     RT @premierleague: KICK-OFF #AVFC get us under...  UnderAverageMan
# 10    RT @LCFC: ARRIVALS: The #lcfc boys are here re...         Hand1075
# 11    Leicester City VS Aston Villa\n\nLive Stream :...       sewimkayaa
# 12    RT @premierleague: KICK-OFF #AVFC get us under...         moiRosni
# 13    RT @Villafandan: Hey sky. It's a local game.  ...      _fishywishy
# 14    Wow what a fab atmosphere at the #KingPowerSta...      maxloweboss
# 15    Sinclair, Grealish, Gill as the 3 on the 4-2-3...       ScottDCole
# 16         Kick-Off: #LCFC v #AVFC is underway! #LEIAVL           TNC_PL
# 17                                 Come on Villa! #avfc        will_avfc
# 18    Leicester City VS Aston Villa\n\nLive Stream :...        OzgeFerah
# 19                              Come on then boys #AVFC          Dr_coxy
# 20    All this sky hype reminds me of that season wh...  official_patnee
# 21    RT @AVFCOfficial: It's showtime! Villa to kick...      BoyNinjaJoe
# 22    Leicester, Champions League. Chelsea, Champion...       glecharles
# 23                        GAME KICKS OFF #AVFC at #lcfc         AVFCBlog
# 24    RT @AVFCOfficial: It's showtime! Villa to kick...     JayAVFCJohno
# 25                Come on villa, 3 points will do #AVFC          LouuC92
# 26    RT @LCFC: TEAM NEWS: #lcfc team to face @AVFCO...    naga_neta_bot
# 27    Leicester City V Aston Villa Live Stream : htt...     16Gamzeturan
# 28    RT @premierleague: KICK-OFF #AVFC get us under...  GuidoCastillo00
# 29    Leicester City V Aston Villa Live Stream : htt...       TugeKeskin
# ...                                                 ...              ...
# 7014  RT @AVFCOfficial: GOAL! GOAL! GOAL!! Step forw...        dinesyboi
# 7015  Give that man a badge #AVFC http://t.co/9MhUsX...     football_spy
# 7016  Awesome finish from @JackGrealish1 congrats on...         TEClabon
# 7017      @JackGrealish1 what a Beauty jack ⚽️👍🏻\n#AVFC  Obaid_Alkindi84
# 7018  RT @AVFCOfficial: GOAL! GOAL! GOAL!! Step forw...   barrera_rosete
# 7019  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...       priceyctfc
# 7020  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...      SimplyAmavi
# 7021                              Come one lads !!#lcfc     jacksutlieff
# 7022  RT @TitanBet: Lovely goal, Grealish Predicting...      VillaSphera
# 7023  RT @kiddestiny: Jack, Congratulation !!! #avfc...       RNolan1989
# 7024  TT UK 16:00\n1.#europeisthebest\n2.#COYS\n3.#a...      TTMobile_uk
# 7025  RT @LCFC: MEET MUZZY: #lcfc legend @Muzzie06 i...           MrAo33
# 7026  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...       Gav_Oleary
# 7027  Richards, Lescott and Amavi very calm &amp; as...  UpTheAstonVilla
# 7028  TT IRELAND 16:00\n1.#europeisthebest\n2.Air Fo...      TTMobile_ie
# 7029  RT @AVFCOfficial: #LCFC 0-1 #AVFC – GOAL - 39m...         Fatttkie
# 7030                              Keep it up boys #avfc        xSampless
# 7031  Amavi just getting better and better, his touc...  Corscombe_Villa
# 7032  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...   Sarut_Adhikari
# 7033  1. #europeisthebest\n2. #COYS\n3. #IdolsSA\n4....    trendinaliaGB
# 7034  Not gonna lie, my favourite part of this pic i...         DaveyB95
# 7035  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...  BradleyHudsonnn
# 7036  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...   The11thPanther
# 7037  #LCFC 0-1 #AVFC Riyad Mahrez has been shackled...        StatsZone
# 7038  RT @AVFCOfficial: GOAL! GOAL! GOAL!! Step forw...    liamfarrell99
# 7039  Relationship goals 😂 #avfc http://t.co/x3f4V2FETK      briggs_avfc
# 7040  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...            VLzed
# 7041  What happened to the exciting, attacking, pres...          Watto_T
# 7042  RT @AVFCOfficial: #LCFC 0-1 #AVFC - GOAL PIC: ...        rachdarlo
# 7043  RT @HeartOfTheHolte: What a strike @JackGreali...   jameshendicott
#
#        time  ith_minute short_sent  short_pos  short_neg long_sent  long_pos  \
# 0     54023    0.383333        neg   0.359504   0.640496       neg  0.401158
# 1     54024    0.400000        pos   0.602156   0.397844       neg  0.490573
# 2     54024    0.400000        pos   0.502667   0.497333       pos  0.606981
# 3     54025    0.416667        neg   0.359504   0.640496       neg  0.389754
# 4     54025    0.416667        pos   0.500757   0.499243       pos  0.673645
# 5     54025    0.416667        pos   0.531938   0.468062       pos  0.567234
# 6     54026    0.433333        pos   0.500000   0.500000       pos  0.520916
# 7     54028    0.466667        pos   0.737288   0.262712       pos  0.578043
# 8     54029    0.483333        pos   0.710176   0.289824       pos  0.569036
# 9     54029    0.483333        neg   0.117013   0.882987       pos  0.512652
# 10    54030    0.500000        pos   0.692016   0.307984       pos  0.759255
# 11    54030    0.500000        neg   0.359504   0.640496       neg  0.401158
# 12    54030    0.500000        neg   0.117013   0.882987       pos  0.512652
# 13    54031    0.516667        neg   0.253378   0.746622       pos  0.595886
# 14    54031    0.516667        neg   0.357143   0.642857       neg  0.488845
# 15    54031    0.516667        neg   0.466905   0.533095       neg  0.035606
# 16    54032    0.533333        pos   0.500000   0.500000       pos  0.533521
# 17    54033    0.550000        neg   0.448052   0.551948       neg  0.497500
# 18    54033    0.550000        neg   0.359504   0.640496       pos  0.599821
# 19    54034    0.566667        pos   0.545746   0.454254       pos  0.580245
# 20    54034    0.566667        pos   0.824941   0.175059       pos  0.542445
# 21    54035    0.583333        pos   0.710176   0.289824       pos  0.569036
# 22    54035    0.583333        neg   0.086966   0.913034       pos  0.604821
# 23    54036    0.600000        neg   0.350000   0.650000       pos  0.646989
# 24    54036    0.600000        pos   0.710176   0.289824       pos  0.569036
# 25    54036    0.600000        neg   0.423189   0.576811       neg  0.132408
# 26    54036    0.600000        pos   0.827273   0.172727       pos  0.574684
# 27    54036    0.600000        pos   0.737288   0.262712       neg  0.371054
# 28    54037    0.616667        neg   0.117013   0.882987       pos  0.512652
# 29    54037    0.616667        pos   0.737288   0.262712       neg  0.371054
# ...     ...         ...        ...        ...        ...       ...       ...
# 7014  57601   60.016667        pos   0.528846   0.471154       neg  0.310596
# 7015  57602   60.033333        pos   0.634582   0.365418       pos  0.606869
# 7016  57602   60.033333        neg   0.292043   0.707957       pos  0.588644
# 7017  57603   60.050000        pos   0.562500   0.437500       pos  0.658679
# 7018  57603   60.050000        pos   0.528846   0.471154       neg  0.310596
# 7019  57603   60.050000        pos   0.997155   0.002845       neg  0.319653
# 7020  57603   60.050000        pos   0.997155   0.002845       neg  0.319653
# 7021  57605   60.083333        pos   0.799258   0.200742       pos  0.547291
# 7022  57606   60.100000        pos   0.899088   0.100912       pos  0.777953
# 7023  57606   60.100000        pos   0.562500   0.437500       pos  0.658679
# 7024  57608   60.133333        pos   0.825179   0.174821       neg  0.400326
# 7025  57608   60.133333        pos   0.558252   0.441748       pos  0.568588
# 7026  57608   60.133333        neg   0.492188   0.507813       neg  0.252312
# 7027  57608   60.133333        pos   0.754654   0.245346       pos  0.598938
# 7028  57609   60.150000        pos   0.690698   0.309302       neg  0.416389
# 7029  57608   60.133333        pos   0.901940   0.098060       neg  0.363035
# 7030  57610   60.166667        pos   0.687847   0.312153       pos  0.735390
# 7031  57610   60.166667        pos   0.716309   0.283691       neg  0.351939
# 7032  57610   60.166667        neg   0.492188   0.507813       neg  0.252312
# 7033  57610   60.166667        pos   0.617347   0.382653       neg  0.099545
# 7034  57614   60.233333        pos   0.949778   0.050222       pos  0.529508
# 7035  57616   60.266667        pos   0.997155   0.002845       neg  0.319653
# 7036  57616   60.266667        pos   0.997155   0.002845       neg  0.319653
# 7037  57616   60.266667        pos   0.750000   0.250000       neg  0.293385
# 7038  57617   60.283333        pos   0.528846   0.471154       neg  0.310596
# 7039  57617   60.283333        pos   0.597345   0.402655       pos  0.691381
# 7040  57617   60.283333        pos   0.997155   0.002845       neg  0.319653
# 7041  57618   60.300000        pos   0.794766   0.205234       pos  0.562847
# 7042  57619   60.316667        pos   0.997155   0.002845       neg  0.319653
# 7043  57621   60.350000        pos   0.500000   0.500000       neg  0.485991
#
#       long_neg
# 0     0.598842
# 1     0.509427
# 2     0.393019
# 3     0.610246
# 4     0.326355
# 5     0.432766
# 6     0.479084
# 7     0.421957
# 8     0.430964
# 9     0.487348
# 10    0.240745
# 11    0.598842
# 12    0.487348
# 13    0.404114
# 14    0.511155
# 15    0.964394
# 16    0.466479
# 17    0.502500
# 18    0.400179
# 19    0.419755
# 20    0.457555
# 21    0.430964
# 22    0.395179
# 23    0.353011
# 24    0.430964
# 25    0.867592
# 26    0.425316
# 27    0.628946
# 28    0.487348
# 29    0.628946
# ...        ...
# 7014  0.689404
# 7015  0.393131
# 7016  0.411356
# 7017  0.341321
# 7018  0.689404
# 7019  0.680347
# 7020  0.680347
# 7021  0.452709
# 7022  0.222047
# 7023  0.341321
# 7024  0.599674
# 7025  0.431412
# 7026  0.747688
# 7027  0.401062
# 7028  0.583611
# 7029  0.636965
# 7030  0.264610
# 7031  0.648061
# 7032  0.747688
# 7033  0.900455
# 7034  0.470492
# 7035  0.680347
# 7036  0.680347
# 7037  0.706615
# 7038  0.689404
# 7039  0.308619
# 7040  0.680347
# 7041  0.437153
# 7042  0.680347
# 7043  0.514009
#
# [7044 rows x 13 columns]
