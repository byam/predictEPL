# %%
import os
import sys
import pickle
from time import time
import pandas as pd

# Local Imports
path = str(os.path.expanduser('~')) + '/git/predictEPL/config'
sys.path.append(path)
import paths

sys.path.append(paths.UTILS)
import emolex
import useful_methods

# %%
# *******************************************************
# *******************************************************

# Limitations
TIME_LIMIT = 60
RETWEET_STATUS = False
FILTER_STATUS = True
START_TIME = 1
END_TIME = 60

# %%
# *******************************************************
# *******************************************************

# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')

# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]

# %%
# *******************************************************
# *******************************************************

# Read SVM(hash emolex) detecter
with open(paths.DETECTER_HOME + 'dtr_hash_svn_2016-01-24_05:14:42.pkl', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'utf-8'
    detector = u.load()

# %%
def AddScorePosNegColumn(df, detecter):
    df = df.copy().reset_index(drop=True)
    score_pos = []
    score_neg = []

    for text in df.text:
        neg, pos = detector.predict_proba([text])[0]
        score_pos.append(pos)
        score_neg.append(neg)

    df['score_pos'] = score_pos
    df['score_neg'] = score_neg

    return df

# %%
# Count Home, Away Emolex
def TweetPNscore(week, team_home, team_away):
    # week = 22
    # team_home = 'Swansea'
    # team_away = 'Watford'

    # Read Single as DF
    dfGame = useful_methods.SingleGameDf(week, team_home, team_away, filtering=True, retweet=RETWEET_STATUS)
    if dfGame is None:
        print(None, None)
        return None

    dfGame.ith_minute = [int(ith_minute) for ith_minute in list(dfGame.ith_minute)]

    # Count Emolex Words
    dfHome = AddScorePosNegColumn(dfGame[(dfGame.side == 'home') & (dfGame.ith_minute <= TIME_LIMIT)], detector)
    dfAway = AddScorePosNegColumn(dfGame[(dfGame.side == 'away') & (dfGame.ith_minute <= TIME_LIMIT)], detector)

    return (
        dfHome.score_pos.sum(), dfHome.score_neg.sum(),
        dfAway.score_pos.sum(), dfAway.score_neg.sum())

# %%
taken_time = time()

counted_game_emolex = []

for week in set(dfGameInfos.GW):
# for week in set([22]):
    for index in range((week - 1) * 10, week * 10):
        # Team names
        team_home = dfGameInfos[dfGameInfos.GW == week].loc[index]['home_team']
        team_away = dfGameInfos[dfGameInfos.GW == week].loc[index]['away_team']

        print("\n\n------------------")
        print(week, team_home, team_away)
        pn_score = TweetPNscore(week, team_home, team_away)
        counted_game_emolex.append(pn_score)
        print(pn_score)

print("[Done:] %.2f" % (time() - taken_time))
# Out:
# ------------------
# 1 United Tottenham
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Everton Watford
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Leicester Sunderland
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Norwich Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Bournemouth Villa
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Chelsea Swansea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Arsenal WestHam
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Newcastle Southampton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Stoke Liverpool
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 WestBromwich City
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Villa United
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Southampton Everton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Tottenham Stoke
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 WestHam Leicester
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Watford WestBromwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Sunderland Norwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Swansea Newcastle
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Crystal Arsenal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 City Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Liverpool Bournemouth
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 United Newcastle
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Crystal Villa
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 WestHam Bournemouth
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Sunderland Swansea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Norwich Stoke
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Leicester Tottenham
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 WestBromwich Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Watford Southampton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Everton City
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Arsenal Liverpool
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Newcastle Arsenal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Stoke WestBromwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Liverpool WestHam
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Chelsea Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Villa Sunderland
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Bournemouth Leicester
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 City Watford
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Tottenham Everton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Southampton Norwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Swansea United
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 5 Everton Chelsea
# (1013.3392414165855, 1127.6607585834145, 2713.293139856029, 4521.7068601439714)
#
#
# ------------------
# 5 Norwich Bournemouth
# (159.79855529800594, 172.20144470199409, 65.230459990252243, 77.769540009747743)
#
#
# ------------------
# 5 Watford Swansea
# (65.225316662747417, 73.774683337252583, 36.434743273899677, 64.56525672610033)
#
#
# ------------------
# 5 WestBromwich Southampton
# (70.702403405061716, 108.29759659493827, 66.368743553834179, 116.63125644616581)
#
#
# ------------------
# 5 Arsenal Stoke
# (1733.7939118570614, 1934.2060881429384, 101.4797554687909, 126.5202445312091)
#
#
# ------------------
# 5 Crystal City
# (188.70074450055375, 207.29925549944622, 512.29364067803374, 657.70635932196637)
#
#
# ------------------
# 5 United Liverpool
# (4080.5350652122502, 6505.4649347877494, 2389.2480551340732, 4109.7519448659277)
#
#
# ------------------
# 5 Sunderland Tottenham
# (301.60606210860391, 355.39393789139609, 662.2880625094715, 929.7119374905285)
#
#
# ------------------
# 5 Leicester Villa
# (161.53962355531513, 235.46037644468487, 932.79921927074554, 897.20078072925446)
#
#
# ------------------
# 5 WestHam Newcastle
# (409.97332321191573, 402.02667678808427, 907.09747487109507, 1414.9025251289049)
#
#
# ------------------
# 6 Chelsea Arsenal
# (1485.4358913643359, 2459.5641086356636, 1238.2287129358474, 1949.7712870641524)
#
#
# ------------------
# 6 Swansea Everton
# (35.539185527016059, 63.460814472983941, 199.60511554108871, 280.39488445891135)
#
#
# ------------------
# 6 Bournemouth Sunderland
# (185.42744798280043, 242.57255201719957, 368.62582542478833, 553.37417457521155)
#
#
# ------------------
# 6 Villa WestBromwich
# (238.42525080298458, 370.57474919701542, 156.91557506376569, 171.08442493623431)
#
#
# ------------------
# 6 Newcastle Watford
# (1078.5135165690394, 1613.4864834309606, 228.69646096699176, 175.30353903300824)
#
#
# ------------------
# 6 Stoke Leicester
# (180.5868169166967, 167.4131830833033, 195.92315275999795, 264.07684724000205)
#
#
# ------------------
# 6 City WestHam
# (992.0227890733961, 1099.9772109266039, 641.7151955659474, 783.2848044340526)
#
#
# ------------------
# 6 Tottenham Crystal
# (603.60478411882355, 587.39521588117645, 15.794959520736967, 13.205040479263033)
#
#
# ------------------
# 6 Southampton United
# (300.09076768470595, 300.90923231529405, 5451.2195988130388, 7117.7804011869612)
#
#
# ------------------
# 6 Liverpool Norwich
# (1472.4115170466641, 1831.5884829533359, 131.73147875253159, 182.26852124746841)
#
#
# ------------------
# 7 Tottenham City
# (1081.1281797683964, 1137.8718202316036, 1044.2946217250383, 1013.7053782749618)
#
#
# ------------------
# 7 Leicester Arsenal
# (203.18172901678352, 231.81827098321651, 1214.8613024173669, 1416.1386975826331)
#
#
# ------------------
# 7 Stoke Bournemouth
# (51.723659718113637, 65.276340281886363, 107.81249450882677, 162.18750549117323)
#
#
# ------------------
# 7 WestHam Norwich
# (99.139876843096829, 150.86012315690317, 151.66341435479916, 242.33658564520084)
#
#
# ------------------
# 7 Southampton Swansea
# (110.98317838888093, 117.01682161111906, 31.854660723208053, 64.145339276791944)
#
#
# ------------------
# 7 United Sunderland
# (3362.1414911730217, 4169.8585088269774, 128.12587746949862, 150.87412253050138)
#
#
# ------------------
# 7 Liverpool Villa
# (1445.3099365272778, 1524.6900634727222, 311.81926478612178, 435.18073521387828)
#
#
# ------------------
# 7 Newcastle Chelsea
# (1109.8712889967396, 1152.1287110032604, 1012.3853612351304, 1856.6146387648696)
#
#
# ------------------
# 7 Watford Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 7 WestBromwich Everton
# (195.40303102375563, 249.5969689762444, 268.10627330930373, 397.89372669069633)
#
#
# ------------------
# 8 Crystal WestBromwich
# (185.69823915034107, 249.30176084965893, 199.49466013683579, 346.50533986316418)
#
#
# ------------------
# 8 Norwich Leicester
# (110.1402082612633, 174.8597917387367, 163.47095296053897, 211.52904703946101)
#
#
# ------------------
# 8 Sunderland WestHam
# (351.12923195862732, 362.87076804137268, 179.53678758024068, 265.46321241975932)
#
#
# ------------------
# 8 City Newcastle
# (567.16064568060892, 675.83935431939108, 829.57434314743796, 990.42565685256204)
#
#
# ------------------
# 8 Villa Stoke
# (230.12323769824926, 341.87676230175077, 39.211369750281641, 47.788630249718366)
#
#
# ------------------
# 8 Bournemouth Watford
# (129.16541079852641, 159.83458920147359, 124.84046820368656, 174.15953179631344)
#
#
# ------------------
# 8 Chelsea Southampton
# (1892.4482852326953, 2741.5517147673045, 413.6355133939598, 629.36448660604015)
#
#
# ------------------
# 8 Everton Liverpool
# (534.52886904332956, 644.47113095667044, 3354.0264700332905, 4071.9735299667095)
#
#
# ------------------
# 8 Swansea Tottenham
# (140.07429576355491, 164.92570423644509, 592.49796536400243, 705.50203463599746)
#
#
# ------------------
# 8 Arsenal United
# (5090.3554422262041, 5278.644557773795, 6344.4038513175246, 9454.5961486824744)
#
#
# ------------------
# 9 Tottenham Liverpool
# (697.57404987082634, 945.42595012917354, 2617.2347601426741, 2992.7652398573259)
#
#
# ------------------
# 9 Southampton Leicester
# (148.57641054350881, 160.42358945649119, 110.99250409954709, 171.00749590045291)
#
#
# ------------------
# 9 WestBromwich Sunderland
# (95.029053755875395, 154.9709462441246, 96.370645167351057, 128.62935483264891)
#
#
# ------------------
# 9 Chelsea Villa
# (764.97308593673267, 1303.0269140632672, 329.59077087393871, 535.40922912606129)
#
#
# ------------------
# 9 Crystal WestHam
# (152.45979026288009, 241.54020973711994, 102.3536173128617, 134.6463826871383)
#
#
# ------------------
# 9 Everton United
# (375.13063159650892, 454.86936840349108, 4313.8211077976493, 3998.1788922023507)
#
#
# ------------------
# 9 City Bournemouth
# (836.05712335714838, 906.94287664285162, 154.79336964829022, 167.20663035170978)
#
#
# ------------------
# 9 Watford Arsenal
# (143.30522242633634, 164.69477757366363, 975.39509048488549, 1359.6049095151143)
#
#
# ------------------
# 9 Newcastle Norwich
# (1222.8602425549725, 1502.1397574450275, 513.85096376210788, 712.14903623789223)
#
#
# ------------------
# 9 Swansea Stoke
# (63.843492519945158, 124.15650748005484, 181.08979262596512, 223.91020737403488)
#
#
# ------------------
# 10 Norwich WestBromwich
# (82.165536928345531, 93.834463071654469, 143.58954839430635, 178.41045160569368)
#
#
# ------------------
# 10 Leicester Crystal
# (58.810112366974927, 78.189887633025052, 93.147893004752532, 135.85210699524748)
#
#
# ------------------
# 10 Villa Swansea
# (220.28429336426316, 316.71570663573686, 31.849185853188878, 61.150814146811129)
#
#
# ------------------
# 10 WestHam Chelsea
# (217.50665589455122, 308.49334410544878, 1362.7585059980693, 2891.2414940019307)
#
#
# ------------------
# 10 Stoke Watford
# (129.68376088288215, 184.31623911711785, 167.61450032558417, 170.38549967441583)
#
#
# ------------------
# 10 Arsenal Everton
# (1696.6876490111624, 1769.3123509888376, 360.42312902889392, 483.57687097110608)
#
#
# ------------------
# 10 Sunderland Newcastle
# (208.85223598534506, 290.14776401465497, 673.97705463392231, 897.02294536607769)
#
#
# ------------------
# 10 United City
# (1956.3554614008685, 2557.6445385991315, 356.29091217910104, 524.70908782089896)
#
#
# ------------------
# 10 Bournemouth Tottenham
# (184.79881082018565, 214.20118917981435, 776.35425312167501, 870.64574687832499)
#
#
# ------------------
# 10 Liverpool Southampton
# (1125.4506701218688, 1668.5493298781312, 129.45917450053918, 156.54082549946085)
#
#
# ------------------
# 11 Chelsea Liverpool
# (1052.7415222661909, 1642.2584777338091, 1307.4811103915267, 2105.5188896084733)
#
#
# ------------------
# 11 Swansea Arsenal
# (27.251366583086988, 45.748633416913009, 592.61403668862044, 833.38596331137956)
#
#
# ------------------
# 11 WestBromwich Leicester
# (85.759390418988232, 82.240609581011768, 77.550270657223265, 93.44972934277672)
#
#
# ------------------
# 11 Watford WestHam
# (70.902233056487717, 84.097766943512283, 55.93080280707143, 94.069197192928584)
#
#
# ------------------
# 11 Newcastle Stoke
# (260.20933102674508, 319.79066897325492, 55.285533942107037, 58.714466057892963)
#
#
# ------------------
# 11 City Norwich
# (310.44807547668705, 440.55192452331295, 93.498666196641977, 120.50133380335802)
#
#
# ------------------
# 11 Crystal United
# (85.76216236595431, 98.23783763404569, 1331.0659099427783, 2067.9340900572215)
#
#
# ------------------
# 11 Everton Sunderland
# (508.76508192110919, 523.23491807889081, 250.18640443157884, 305.81359556842119)
#
#
# ------------------
# 11 Southampton Bournemouth
# (267.68493447944979, 257.31506552055021, 146.11578862261416, 189.88421137738584)
#
#
# ------------------
# 11 Tottenham Villa
# (886.87393770489905, 892.12606229510106, 1025.9035330207287, 1477.0964669792716)
#
#
# ------------------
# 12 Bournemouth Newcastle
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Leicester Watford
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Norwich Swansea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 WestHam Everton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Sunderland Southampton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 United WestBromwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Stoke Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Villa City
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Liverpool Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Arsenal Tottenham
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 13 Watford United
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 13 Swansea Bournemouth
# (106.60943748500847, 148.39056251499153, 210.09423750014818, 201.90576249985182)
#
#
# ------------------
# 13 Chelsea Norwich
# (1221.9318853461414, 1783.0681146538584, 131.00527497883854, 146.99472502116146)
#
#
# ------------------
# 13 Everton Villa
# (454.53356540475329, 450.46643459524665, 531.10401144689365, 855.89598855310624)
#
#
# ------------------
# 13 WestBromwich Arsenal
# (138.26971774266224, 161.73028225733776, 1394.563609878604, 1925.436390121396)
#
#
# ------------------
# 13 Newcastle Leicester
# (415.55146541985749, 605.44853458014245, 422.31827718767727, 440.68172281232273)
#
#
# ------------------
# 13 Southampton Stoke
# (74.470956417619163, 128.52904358238084, 103.57531622866814, 91.424683771331857)
#
#
# ------------------
# 13 City Liverpool
# (922.9993491547807, 1106.0006508452193, 5946.7882289704849, 5690.2117710295151)
#
#
# ------------------
# 13 Tottenham WestHam
# (1544.1574567720177, 1559.8425432279823, 290.04930241434755, 374.95069758565245)
#
#
# ------------------
# 13 Crystal Sunderland
# (190.05580335767661, 256.94419664232339, 188.3940674549988, 228.6059325450012)
#
#
# ------------------
# 14 Sunderland Stoke
# (104.29660883180659, 129.70339116819341, 52.463960710905532, 78.536039289094475)
#
#
# ------------------
# 14 Bournemouth Everton
# (84.467336899897305, 104.53266310010271, 314.12632412164987, 260.87367587835013)
#
#
# ------------------
# 14 Villa Watford
# (461.04263655260058, 573.95736344739942, 89.685605315192618, 116.31439468480738)
#
#
# ------------------
# 14 Crystal Newcastle
# (235.43777381535693, 251.56222618464307, 1039.4476324710777, 1525.5523675289223)
#
#
# ------------------
# 14 City Southampton
# (562.01570286068568, 490.98429713931432, 209.3410986183585, 323.6589013816415)
#
#
# ------------------
# 14 Leicester United
# (1234.5932907197196, 1139.4067092802804, 4483.6213166418866, 5946.3786833581134)
#
#
# ------------------
# 14 Tottenham Chelsea
# (458.21838513052472, 653.78161486947533, 749.16317132123277, 1226.8368286787672)
#
#
# ------------------
# 14 WestHam WestBromwich
# (196.33709445449421, 217.66290554550579, 156.34291770855489, 307.65708229144514)
#
#
# ------------------
# 14 Liverpool Swansea
# (1117.4384095332869, 1351.5615904667131, 28.992294089492059, 61.007705910507937)
#
#
# ------------------
# 14 Norwich Arsenal
# (248.71989403497997, 326.28010596501997, 1415.0472429294805, 1778.9527570705195)
#
#
# ------------------
# 15 Stoke City
# (477.14149462432209, 443.85850537567796, 671.82731440280941, 1035.1726855971906)
#
#
# ------------------
# 15 Arsenal Sunderland
# (1125.3273188157516, 1394.6726811842484, 173.73224010910212, 177.26775989089791)
#
#
# ------------------
# 15 WestBromwich Tottenham
# (143.49234028201968, 158.50765971798032, 549.25360410565895, 632.74639589434105)
#
#
# ------------------
# 15 Watford Norwich
# (96.55743047903654, 119.44256952096347, 170.0450813958692, 263.9549186041308)
#
#
# ------------------
# 15 United WestHam
# (1581.4170506616279, 2389.5829493383726, 152.90068598360176, 220.09931401639821)
#
#
# ------------------
# 15 Swansea Leicester
# (67.957500732090637, 145.04249926790936, 358.03477110784235, 388.96522889215765)
#
#
# ------------------
# 15 Southampton Villa
# (122.39006243042047, 199.60993756957953, 485.17092956422317, 628.82907043577688)
#
#
# ------------------
# 15 Chelsea Bournemouth
# (699.91021570067653, 1261.0897842993236, 123.59036913851914, 156.40963086148088)
#
#
# ------------------
# 15 Newcastle Liverpool
# (510.36677966480977, 708.63322033519034, 1394.5265754928121, 2236.4734245071877)
#
#
# ------------------
# 15 Everton Crystal
# (233.72852506043978, 274.27147493956022, 188.40600318175862, 266.59399681824135)
#
#
# ------------------
# 16 Norwich Everton
# (237.60193030861907, 377.3980696913809, 480.2282498839254, 539.7717501160746)
#
#
# ------------------
# 16 WestHam Stoke
# (94.634533769522776, 117.36546623047722, 36.265080866553781, 50.734919133446219)
#
#
# ------------------
# 16 Sunderland Watford
# (152.05553751103159, 191.94446248896844, 137.55849309747035, 157.44150690252968)
#
#
# ------------------
# 16 City Swansea
# (363.27042969369751, 424.72957030630255, 81.905083704979504, 109.09491629502048)
#
#
# ------------------
# 16 Crystal Southampton
# (152.50235387751559, 138.49764612248441, 112.14567521804787, 158.85432478195213)
#
#
# ------------------
# 16 Bournemouth United
# (219.14784760037679, 262.85215239962321, 3212.8824371886321, 3936.1175628113679)
#
#
# ------------------
# 16 Villa Arsenal
# (763.1686370292739, 1149.8313629707261, 1655.3182903474597, 1693.6817096525403)
#
#
# ------------------
# 16 Liverpool WestBromwich
# (2102.2974607539413, 2546.7025392460582, 131.57320069525178, 168.42679930474819)
#
#
# ------------------
# 16 Tottenham Newcastle
# (793.3239091124035, 839.67609088759662, 749.08738383816228, 1039.9126161618378)
#
#
# ------------------
# 16 Leicester Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 17 Stoke Crystal
# (46.37706480803822, 69.622935191961773, 165.325415530876, 167.67458446912403)
#
#
# ------------------
# 17 WestBromwich Bournemouth
# (106.02381979426536, 198.97618020573464, 67.242371719501094, 84.757628280498921)
#
#
# ------------------
# 17 Chelsea Sunderland
# (3099.4343538030789, 4932.5656461969211, 214.01668497995547, 369.98331502004453)
#
#
# ------------------
# 17 Everton Leicester
# (198.960172759226, 241.039827240774, 265.24688459833783, 276.75311540166211)
#
#
# ------------------
# 17 United Norwich
# (3191.3469202314809, 4431.6530797685191, 246.53365253256032, 346.46634746743962)
#
#
# ------------------
# 17 Southampton Tottenham
# (210.72647475953488, 305.27352524046506, 963.01932451483515, 973.98067548516474)
#
#
# ------------------
# 17 Newcastle Villa
# (663.93888180579052, 888.06111819420948, 612.55178682410201, 1003.448213175898)
#
#
# ------------------
# 17 Watford Liverpool
# (428.71863409111677, 379.28136590888329, 3713.5563902454733, 5962.4436097545267)
#
#
# ------------------
# 17 Swansea WestHam
# (85.270592118119154, 152.72940788188086, 168.86326586498723, 288.13673413501283)
#
#
# ------------------
# 17 Arsenal City
# (3757.6116820729403, 3805.3883179270597, 719.37721273860336, 987.62278726139675)
#
#
# ------------------
# 18 Stoke United
# (547.92329078146145, 556.07670921853855, 6758.5005945656048, 10893.499405434397)
#
#
# ------------------
# 18 Tottenham Norwich
# (910.55459669165703, 930.44540330834297, 170.44846175955178, 219.55153824044822)
#
#
# ------------------
# 18 Swansea WestBromwich
# (45.298880708051826, 81.701119291948174, 128.13262026172279, 196.86737973827721)
#
#
# ------------------
# 18 City Sunderland
# (894.72735648819366, 816.27264351180634, 274.19847138728454, 406.80152861271552)
#
#
# ------------------
# 18 Liverpool Leicester
# (1448.3619266220303, 1802.6380733779697, 177.98438187985698, 222.01561812014302)
#
#
# ------------------
# 18 Chelsea Watford
# (991.08509985585681, 1607.9149001441433, 145.3991290626156, 199.6008709373844)
#
#
# ------------------
# 18 Villa WestHam
# (229.54950676754822, 340.45049323245178, 151.02930597331579, 191.97069402668421)
#
#
# ------------------
# 18 Bournemouth Crystal
# (60.866059800900814, 72.133940199099186, 91.546109921878795, 130.45389007812119)
#
#
# ------------------
# 18 Newcastle Everton
# (426.96934392384657, 649.03065607615349, 298.83036675309245, 364.16963324690749)
#
#
# ------------------
# 18 Southampton Arsenal
# (530.86816321937579, 500.13183678062421, 1315.8919546669895, 2209.1080453330105)
#
#
# ------------------
# 19 Crystal Swansea
# (91.799849370659928, 155.2001506293401, 31.518768158598235, 61.481231841401758)
#
#
# ------------------
# 19 Everton Stoke
# (281.73401074323033, 293.26598925676967, 257.67588449435948, 230.32411550564049)
#
#
# ------------------
# 19 Norwich Villa
# (130.10245758810669, 171.89754241189331, 414.16311303079874, 653.83688696920126)
#
#
# ------------------
# 19 Watford Tottenham
# (235.15271698345157, 197.84728301654846, 728.69491302182996, 777.30508697817004)
#
#
# ------------------
# 19 WestBromwich Newcastle
# (106.57230903455502, 129.42769096544498, 407.22046760953003, 549.77953239046997)
#
#
# ------------------
# 19 WestHam Southampton
# (133.57871172795836, 216.42128827204169, 194.11256905506573, 211.88743094493429)
#
#
# ------------------
# 19 Arsenal Bournemouth
# (1208.7335354283373, 1553.2664645716627, 102.29940080283194, 163.70059919716806)
#
#
# ------------------
# 19 United Chelsea
# (4972.4708587478872, 6075.5291412521137, 1181.2626215913779, 2386.7373784086221)
#
#
# ------------------
# 19 Leicester City
# (289.03880493478732, 367.96119506521268, 558.85711509116504, 713.14288490883519)
#
#
# ------------------
# 19 Sunderland Liverpool
# (217.4560438074987, 273.54395619250124, 1444.8790908838207, 2058.1209091161791)
#
#
# ------------------
# 20 WestHam Liverpool
# (338.01005436506966, 435.98994563493034, 2498.0584773060309, 4189.9415226939691)
#
#
# ------------------
# 20 Arsenal Newcastle
# (1129.4412607943837, 1673.5587392056163, 506.83235210877274, 671.16764789122726)
#
#
# ------------------
# 20 WestBromwich Stoke
# (75.781831727743679, 119.21816827225635, 42.90372288098856, 64.096277119011447)
#
#
# ------------------
# 20 Sunderland Villa
# (192.81905175210608, 242.18094824789392, 537.73127358161662, 755.26872641838338)
#
#
# ------------------
# 20 Norwich Southampton
# (165.43346590417892, 260.56653409582111, 122.56322073952083, 181.43677926047917)
#
#
# ------------------
# 20 United Swansea
# (2792.3251401033785, 4682.6748598966215, 60.475224279420694, 112.5247757205793)
#
#
# ------------------
# 20 Leicester Bournemouth
# (145.02600465881847, 184.97399534118151, 95.746815696252725, 118.25318430374729)
#
#
# ------------------
# 20 Watford City
# (126.14587434702945, 133.85412565297054, 459.34251283474578, 713.65748716525422)
#
#
# ------------------
# 20 Crystal Chelsea
# (263.06394675998251, 374.93605324001749, 1517.4317342467596, 2242.5682657532407)
#
#
# ------------------
# 20 Everton Tottenham
# (936.51290257383357, 1081.4870974261662, 2269.2067667106676, 2191.7932332893329)
#
#
# ------------------
# 21 Villa Crystal
# (275.66069037377514, 387.3393096262248, 133.03700440355121, 214.96299559644879)
#
#
# ------------------
# 21 Newcastle United
# (1369.6527270454376, 1628.3472729545624, 6040.842457704015, 6284.1575422959859)
#
#
# ------------------
# 21 Bournemouth WestHam
# (131.23790755722118, 133.76209244277885, 154.95587543475963, 290.04412456524039)
#
#
# ------------------
# 21 Stoke Norwich
# (72.2514200518021, 88.7485799481979, 241.47359043436376, 409.52640956563624)
#
#
# ------------------
# 21 Southampton Watford
# (191.81919462462315, 246.18080537537685, 117.35538237664511, 196.64461762335492)
#
#
# ------------------
# 21 City Everton
# (258.8829861464763, 363.1170138535237, 185.90349188147314, 181.09650811852686)
#
#
# ------------------
# 21 Chelsea WestBromwich
# (717.28134839077393, 1093.7186516092258, 180.15059815847468, 238.84940184152532)
#
#
# ------------------
# 21 Swansea Sunderland
# (103.94073605309481, 201.05926394690519, 358.72846420930432, 514.27153579069568)
#
#
# ------------------
# 21 Tottenham Leicester
# (390.18949978000006, 484.81050021999994, 127.02963611976921, 181.97036388023076)
#
#
# ------------------
# 21 Liverpool Arsenal
# (4683.7803631244105, 5677.2196368755885, 1996.0404881914433, 2712.9595118085567)
#
#
# ------------------
# 22 Tottenham Sunderland
# (693.26267531824101, 884.73732468175899, 410.1155760186362, 442.8844239813638)
#
#
# ------------------
# 22 Newcastle WestHam
# (1244.8678423089875, 1405.1321576910125, 179.54465678574905, 271.45534321425095)
#
#
# ------------------
# 22 Bournemouth Norwich
# (119.32627096436551, 126.67372903563449, 235.56599000997454, 363.43400999002552)
#
#
# ------------------
# 22 Chelsea Everton
# (765.94790882114842, 1568.0520911788517, 138.78828177879859, 162.21171822120141)
#
#
# ------------------
# 22 Southampton WestBromwich
# (360.01028328975121, 412.98971671024879, 125.82931385773307, 197.17068614226696)
#
#
# ------------------
# 22 City Crystal
# (538.60804214858058, 553.39195785141942, 242.45792162733659, 369.54207837266341)
#
#
# ------------------
# 22 Villa Leicester
# (465.08192815501144, 685.91807184498862, 352.92746120337176, 445.07253879662824)
#
#
# ------------------
# 22 Liverpool United
# (2250.6491910901523, 2908.3508089098477, 3611.8655458854196, 5801.13445411458)
#
#
# ------------------
# 22 Stoke Arsenal
# (264.2998131057459, 309.7001868942541, 1097.3748724139227, 1439.6251275860773)
#
#
# ------------------
# 22 Swansea Watford
# (129.77798674764608, 167.22201325235392, 232.96193920025758, 364.03806079974242)
# [Done:] 2733.54

# %%
pn_home_pos = []
pn_home_neg = []
pn_away_pos = []
pn_away_neg = []

for pn_scores in counted_game_emolex:
    if pn_scores is None:
        pn_home_pos.append(-1)
        pn_home_neg.append(-1)
        pn_away_pos.append(-1)
        pn_away_neg.append(-1)
    else:
        pn_home_pos.append(pn_scores[0])
        pn_home_neg.append(pn_scores[1])
        pn_away_pos.append(pn_scores[2])
        pn_away_neg.append(pn_scores[3])


dfGameInfos['pn_home_pos'] = pn_home_pos
dfGameInfos['pn_home_neg'] = pn_home_neg
dfGameInfos['pn_away_pos'] = pn_away_pos
dfGameInfos['pn_away_neg'] = pn_away_neg

dfGameInfos
# Out:
#      GW     away_team           date     home_team  score_ft_away  \
# 0     1     Tottenham   Sat. 8 Aug.         United              0
# 1     1       Watford   Sat. 8 Aug.        Everton              2
# 2     1    Sunderland   Sat. 8 Aug.      Leicester              2
# 3     1       Crystal   Sat. 8 Aug.        Norwich              3
# 4     1         Villa   Sat. 8 Aug.    Bournemouth              1
# 5     1       Swansea   Sat. 8 Aug.        Chelsea              2
# 6     1       WestHam   Sun. 9 Aug.        Arsenal              2
# 7     1   Southampton   Sun. 9 Aug.      Newcastle              2
# 8     1     Liverpool   Sun. 9 Aug.          Stoke              1
# 9     1          City  Mon. 10 Aug.   WestBromwich              3
# 10    2        United  Fri. 14 Aug.          Villa              1
# 11    2       Everton  Sat. 15 Aug.    Southampton              3
# 12    2         Stoke  Sat. 15 Aug.      Tottenham              2
# 13    2     Leicester  Sat. 15 Aug.        WestHam              2
# 14    2  WestBromwich  Sat. 15 Aug.        Watford              0
# 15    2       Norwich  Sat. 15 Aug.     Sunderland              3
# 16    2     Newcastle  Sat. 15 Aug.        Swansea              0
# 17    2       Arsenal  Sun. 16 Aug.        Crystal              2
# 18    2       Chelsea  Sun. 16 Aug.           City              0
# 19    2   Bournemouth  Mon. 17 Aug.      Liverpool              0
# 20    3     Newcastle  Sat. 22 Aug.         United              0
# 21    3         Villa  Sat. 22 Aug.        Crystal              1
# 22    3   Bournemouth  Sat. 22 Aug.        WestHam              4
# 23    3       Swansea  Sat. 22 Aug.     Sunderland              1
# 24    3         Stoke  Sat. 22 Aug.        Norwich              1
# 25    3     Tottenham  Sat. 22 Aug.      Leicester              1
# 26    3       Chelsea  Sun. 23 Aug.   WestBromwich              3
# 27    3   Southampton  Sun. 23 Aug.        Watford              0
# 28    3          City  Sun. 23 Aug.        Everton              2
# 29    3     Liverpool  Mon. 24 Aug.        Arsenal              0
# ..   ..           ...            ...           ...            ...
# 190  20     Liverpool   Sat. 2 Jan.        WestHam              0
# 191  20     Newcastle   Sat. 2 Jan.        Arsenal              0
# 192  20         Stoke   Sat. 2 Jan.   WestBromwich              1
# 193  20         Villa   Sat. 2 Jan.     Sunderland              1
# 194  20   Southampton   Sat. 2 Jan.        Norwich              0
# 195  20       Swansea   Sat. 2 Jan.         United              1
# 196  20   Bournemouth   Sat. 2 Jan.      Leicester              0
# 197  20          City   Sat. 2 Jan.        Watford              2
# 198  20       Chelsea   Sun. 3 Jan.        Crystal              3
# 199  20     Tottenham   Sun. 3 Jan.        Everton              1
# 200  21       Crystal  Tue. 12 Jan.          Villa              0
# 201  21        United  Tue. 12 Jan.      Newcastle              3
# 202  21       WestHam  Tue. 12 Jan.    Bournemouth              3
# 203  21       Norwich  Wed. 13 Jan.          Stoke              1
# 204  21       Watford  Wed. 13 Jan.    Southampton              0
# 205  21       Everton  Wed. 13 Jan.           City              0
# 206  21  WestBromwich  Wed. 13 Jan.        Chelsea              2
# 207  21    Sunderland  Wed. 13 Jan.        Swansea              4
# 208  21     Leicester  Wed. 13 Jan.      Tottenham              1
# 209  21       Arsenal  Wed. 13 Jan.      Liverpool              3
# 210  22    Sunderland  Sat. 16 Jan.      Tottenham              1
# 211  22       WestHam  Sat. 16 Jan.      Newcastle              1
# 212  22       Norwich  Sat. 16 Jan.    Bournemouth              0
# 213  22       Everton  Sat. 16 Jan.        Chelsea              3
# 214  22  WestBromwich  Sat. 16 Jan.    Southampton              0
# 215  22       Crystal  Sat. 16 Jan.           City              0
# 216  22     Leicester  Sat. 16 Jan.          Villa              1
# 217  22        United  Sun. 17 Jan.      Liverpool              1
# 218  22       Arsenal  Sun. 17 Jan.          Stoke              0
# 219  22       Watford  Mon. 18 Jan.        Swansea              0
#
#      score_ft_home  score_ht_away  score_ht_home   time  pn_home_pos  \
# 0                1              0              1  11:45    -1.000000
# 1                2              1              0  14:00    -1.000000
# 2                4              0              3  14:00    -1.000000
# 3                1              1              0  14:00    -1.000000
# 4                0              0              0  14:00    -1.000000
# 5                2              1              2  16:30    -1.000000
# 6                0              1              0  12:30    -1.000000
# 7                2              1              1  12:30    -1.000000
# 8                0              0              0  15:00    -1.000000
# 9                0              2              0  19:00    -1.000000
# 10               0              1              0  18:45    -1.000000
# 11               0              2              0  11:45    -1.000000
# 12               2              0              2  14:00    -1.000000
# 13               1              2              0  14:00    -1.000000
# 14               0              0              0  14:00    -1.000000
# 15               1              2              0  14:00    -1.000000
# 16               2              0              1  14:00    -1.000000
# 17               1              1              1  12:30    -1.000000
# 18               3              0              1  15:00    -1.000000
# 19               1              0              1  19:00    -1.000000
# 20               0              0              0  11:45    -1.000000
# 21               2              0              0  14:00    -1.000000
# 22               3              2              0  14:00    -1.000000
# 23               1              1              0  14:00    -1.000000
# 24               1              1              1  14:00    -1.000000
# 25               1              0              0  14:00    -1.000000
# 26               2              3              1  12:30    -1.000000
# 27               0              0              0  15:00    -1.000000
# 28               0              0              0  15:00    -1.000000
# 29               0              0              0  19:00    -1.000000
# ..             ...            ...            ...    ...          ...
# 190              2              0              1  12:45   338.010054
# 191              1              0              0  15:00  1129.441261
# 192              2              0              0  15:00    75.781832
# 193              3              0              1  15:00   192.819052
# 194              1              0              0  15:00   165.433466
# 195              2              0              0  15:00  2792.325140
# 196              0              0              0  15:00   145.026005
# 197              1              0              0  17:30   126.145874
# 198              0              1              0  13:30   263.063947
# 199              1              1              1  16:00   936.512903
# 200              1              0              0  19:45   275.660690
# 201              3              2              1  19:45  1369.652727
# 202              1              0              1  19:45   131.237908
# 203              3              0              0  19:45    72.251420
# 204              2              0              1  19:45   191.819195
# 205              0              0              0  19:45   258.882986
# 206              2              1              1  19:45   717.281348
# 207              2              1              2  19:45   103.940736
# 208              0              0              0  20:00   390.189500
# 209              3              2              2  20:00  4683.780363
# 210              4              1              1  12:45   693.262675
# 211              2              0              2  15:00  1244.867842
# 212              3              0              1  15:00   119.326271
# 213              3              0              0  15:00   765.947909
# 214              3              0              2  15:00   360.010283
# 215              4              0              2  15:00   538.608042
# 216              1              1              0  17:30   465.081928
# 217              0              0              0  14:05  2250.649191
# 218              0              0              0  16:15   264.299813
# 219              1              0              1  20:00   129.777987
#
#      pn_home_neg  pn_away_pos  pn_away_neg
# 0      -1.000000    -1.000000    -1.000000
# 1      -1.000000    -1.000000    -1.000000
# 2      -1.000000    -1.000000    -1.000000
# 3      -1.000000    -1.000000    -1.000000
# 4      -1.000000    -1.000000    -1.000000
# 5      -1.000000    -1.000000    -1.000000
# 6      -1.000000    -1.000000    -1.000000
# 7      -1.000000    -1.000000    -1.000000
# 8      -1.000000    -1.000000    -1.000000
# 9      -1.000000    -1.000000    -1.000000
# 10     -1.000000    -1.000000    -1.000000
# 11     -1.000000    -1.000000    -1.000000
# 12     -1.000000    -1.000000    -1.000000
# 13     -1.000000    -1.000000    -1.000000
# 14     -1.000000    -1.000000    -1.000000
# 15     -1.000000    -1.000000    -1.000000
# 16     -1.000000    -1.000000    -1.000000
# 17     -1.000000    -1.000000    -1.000000
# 18     -1.000000    -1.000000    -1.000000
# 19     -1.000000    -1.000000    -1.000000
# 20     -1.000000    -1.000000    -1.000000
# 21     -1.000000    -1.000000    -1.000000
# 22     -1.000000    -1.000000    -1.000000
# 23     -1.000000    -1.000000    -1.000000
# 24     -1.000000    -1.000000    -1.000000
# 25     -1.000000    -1.000000    -1.000000
# 26     -1.000000    -1.000000    -1.000000
# 27     -1.000000    -1.000000    -1.000000
# 28     -1.000000    -1.000000    -1.000000
# 29     -1.000000    -1.000000    -1.000000
# ..           ...          ...          ...
# 190   435.989946  2498.058477  4189.941523
# 191  1673.558739   506.832352   671.167648
# 192   119.218168    42.903723    64.096277
# 193   242.180948   537.731274   755.268726
# 194   260.566534   122.563221   181.436779
# 195  4682.674860    60.475224   112.524776
# 196   184.973995    95.746816   118.253184
# 197   133.854126   459.342513   713.657487
# 198   374.936053  1517.431734  2242.568266
# 199  1081.487097  2269.206767  2191.793233
# 200   387.339310   133.037004   214.962996
# 201  1628.347273  6040.842458  6284.157542
# 202   133.762092   154.955875   290.044125
# 203    88.748580   241.473590   409.526410
# 204   246.180805   117.355382   196.644618
# 205   363.117014   185.903492   181.096508
# 206  1093.718652   180.150598   238.849402
# 207   201.059264   358.728464   514.271536
# 208   484.810500   127.029636   181.970364
# 209  5677.219637  1996.040488  2712.959512
# 210   884.737325   410.115576   442.884424
# 211  1405.132158   179.544657   271.455343
# 212   126.673729   235.565990   363.434010
# 213  1568.052091   138.788282   162.211718
# 214   412.989717   125.829314   197.170686
# 215   553.391958   242.457922   369.542078
# 216   685.918072   352.927461   445.072539
# 217  2908.350809  3611.865546  5801.134454
# 218   309.700187  1097.374872  1439.625128
# 219   167.222013   232.961939   364.038061
#
# [220 rows x 13 columns]

# %%
# Save as CSV
useful_methods.DFtoCSV(dfGameInfos, paths.DATA_HOME + "EPL/", 'all_game_hash_review_pn_score', index=False)
print("[Saved in]: %s" % (paths.DATA_HOME + "EPL/" + 'all_game_hash_review_pn_score.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/all_game_hash_review_pn_score.csv
