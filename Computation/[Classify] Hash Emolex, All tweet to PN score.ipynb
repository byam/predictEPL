# %%
import os
import sys
import pickle
from time import time
import pandas as pd

# Local Imports
path = str(os.path.expanduser('~')) + '/git/predictEPL/config'
sys.path.append(path)
import paths

sys.path.append(paths.UTILS)
import emolex
import useful_methods

# %%
# *******************************************************
# *******************************************************

# Limitations
TIME_LIMIT = 60
RETWEET_STATUS = False
FILTER_STATUS = True
START_TIME = 1
END_TIME = 60

# %%
# *******************************************************
# *******************************************************

# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')

# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]

# %%
# *******************************************************
# *******************************************************

# Read SVM(hash emolex) detecter
with open(paths.DETECTER_HOME + 'dtr_hash_svn_2016-01-22_08:26:25.pkl', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'utf-8'
    detector = u.load()

# %%
def AddScorePosNegColumn(df, detecter):
    df = df.copy().reset_index(drop=True)
    score_pos = []
    score_neg = []

    for text in df.text:
        neg, pos = detector.predict_proba([text])[0]
        score_pos.append(pos)
        score_neg.append(neg)

    df['score_pos'] = score_pos
    df['score_neg'] = score_neg

    return df

# %%
# Count Home, Away Emolex
def TweetPNscore(week, team_home, team_away):
    # week = 22
    # team_home = 'Swansea'
    # team_away = 'Watford'

    # Read Single as DF
    dfGame = useful_methods.SingleGameDf(week, team_home, team_away, filtering=True, retweet=RETWEET_STATUS)
    if dfGame is None:
        print(None, None)
        return None

    dfGame.ith_minute = [int(ith_minute) for ith_minute in list(dfGame.ith_minute)]

    # Count Emolex Words
    dfHome = AddScorePosNegColumn(dfGame[(dfGame.side == 'home') & (dfGame.ith_minute <= TIME_LIMIT)], detector)
    dfAway = AddScorePosNegColumn(dfGame[(dfGame.side == 'away') & (dfGame.ith_minute <= TIME_LIMIT)], detector)

    return (
        dfHome.score_pos.sum(), dfHome.score_neg.sum(),
        dfAway.score_pos.sum(), dfAway.score_neg.sum())

# %%
taken_time = time()

counted_game_emolex = []

for week in set(dfGameInfos.GW):
# for week in set([22]):
    for index in range((week - 1) * 10, week * 10):
        # Team names
        team_home = dfGameInfos[dfGameInfos.GW == week].loc[index]['home_team']
        team_away = dfGameInfos[dfGameInfos.GW == week].loc[index]['away_team']

        print("\n\n------------------")
        print(week, team_home, team_away)
        pn_score = TweetPNscore(week, team_home, team_away)
        counted_game_emolex.append(pn_score)
        print(pn_score)

print("[Done:] %.2f" % (time() - taken_time))
# Out:
# ------------------
# 1 United Tottenham
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Everton Watford
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Leicester Sunderland
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Norwich Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Bournemouth Villa
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Chelsea Swansea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Arsenal WestHam
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Newcastle Southampton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 Stoke Liverpool
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 1 WestBromwich City
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Villa United
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Southampton Everton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Tottenham Stoke
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 WestHam Leicester
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Watford WestBromwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Sunderland Norwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Swansea Newcastle
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Crystal Arsenal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 City Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 2 Liverpool Bournemouth
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 United Newcastle
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Crystal Villa
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 WestHam Bournemouth
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Sunderland Swansea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Norwich Stoke
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Leicester Tottenham
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 WestBromwich Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Watford Southampton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Everton City
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 3 Arsenal Liverpool
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Newcastle Arsenal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Stoke WestBromwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Liverpool WestHam
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Chelsea Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Villa Sunderland
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Bournemouth Leicester
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 City Watford
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Tottenham Everton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Southampton Norwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 4 Swansea United
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 5 Everton Chelsea
# (996.06105738580766, 1144.9389426141925, 2976.8179096629192, 4258.1820903370808)
#
#
# ------------------
# 5 Norwich Bournemouth
# (198.91532016140388, 133.08467983859612, 82.571384906842837, 60.428615093157163)
#
#
# ------------------
# 5 Watford Swansea
# (53.387312335687881, 85.612687664312119, 73.90263423918573, 27.097365760814274)
#
#
# ------------------
# 5 WestBromwich Southampton
# (47.670936648821822, 131.32906335117821, 93.343791284796239, 89.656208715203746)
#
#
# ------------------
# 5 Arsenal Stoke
# (2282.0079240758914, 1385.9920759241088, 113.38877995877522, 114.61122004122478)
#
#
# ------------------
# 5 Crystal City
# (227.3134714950998, 168.6865285049002, 564.5642955481519, 605.43570445184798)
#
#
# ------------------
# 5 United Liverpool
# (4396.5596240464001, 6189.4403759535999, 2595.8907126975409, 3903.1092873024586)
#
#
# ------------------
# 5 Sunderland Tottenham
# (334.06956082714169, 322.93043917285831, 828.91997761997482, 763.08002238002518)
#
#
# ------------------
# 5 Leicester Villa
# (233.91952431163241, 163.08047568836759, 907.02691980542988, 922.97308019457012)
#
#
# ------------------
# 5 WestHam Newcastle
# (603.6961066194109, 208.30389338058913, 876.71347150045995, 1445.2865284995401)
#
#
# ------------------
# 6 Chelsea Arsenal
# (1629.4340146597563, 2315.565985340244, 1283.5155268002659, 1904.4844731997339)
#
#
# ------------------
# 6 Swansea Everton
# (66.384416284065338, 32.615583715934662, 250.46512457674089, 229.53487542325908)
#
#
# ------------------
# 6 Bournemouth Sunderland
# (271.08449027165778, 156.91550972834222, 358.64779816493171, 563.35220183506829)
#
#
# ------------------
# 6 Villa WestBromwich
# (191.76614479687618, 417.23385520312382, 104.89158416757405, 223.10841583242595)
#
#
# ------------------
# 6 Newcastle Watford
# (862.23506740087566, 1829.7649325991242, 224.03682612533885, 179.96317387466115)
#
#
# ------------------
# 6 Stoke Leicester
# (199.05307934458466, 148.94692065541534, 250.01063635368183, 209.98936364631817)
#
#
# ------------------
# 6 City WestHam
# (1141.3577209534524, 950.64227904654763, 917.27195590565611, 507.72804409434383)
#
#
# ------------------
# 6 Tottenham Crystal
# (731.37906625971596, 459.62093374028404, 18.748626648269003, 10.251373351730997)
#
#
# ------------------
# 6 Southampton United
# (391.13327046023579, 209.86672953976418, 6291.6568407342647, 6277.3431592657344)
#
#
# ------------------
# 6 Liverpool Norwich
# (1576.647735060438, 1727.352264939562, 139.91030566737274, 174.08969433262726)
#
#
# ------------------
# 7 Tottenham City
# (1425.8386909537558, 793.16130904624424, 1170.1780187331351, 887.8219812668649)
#
#
# ------------------
# 7 Leicester Arsenal
# (307.0009523460858, 127.99904765391427, 1579.001557559674, 1051.998442440326)
#
#
# ------------------
# 7 Stoke Bournemouth
# (62.900830809256419, 54.099169190743581, 121.84585506751415, 148.15414493248585)
#
#
# ------------------
# 7 WestHam Norwich
# (142.04112588832947, 107.95887411167053, 192.30670699004443, 201.69329300995557)
#
#
# ------------------
# 7 Southampton Swansea
# (146.99684827699542, 81.003151723004578, 70.001558060015626, 25.998441939984382)
#
#
# ------------------
# 7 United Sunderland
# (3856.6330132056937, 3675.3669867943063, 134.13250267628936, 144.86749732371064)
#
#
# ------------------
# 7 Liverpool Villa
# (1617.5399159624135, 1352.4600840375865, 253.74321374570863, 493.25678625429134)
#
#
# ------------------
# 7 Newcastle Chelsea
# (1227.9507946900399, 1034.0492053099601, 1366.7986948150333, 1502.2013051849667)
#
#
# ------------------
# 7 Watford Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 7 WestBromwich Everton
# (138.76902986606285, 306.23097013393715, 279.7797520484271, 386.2202479515729)
#
#
# ------------------
# 8 Crystal WestBromwich
# (237.51101969857888, 197.48898030142112, 135.59681681367181, 410.40318318632819)
#
#
# ------------------
# 8 Norwich Leicester
# (113.38495644785814, 171.61504355214183, 245.21167311773735, 129.78832688226268)
#
#
# ------------------
# 8 Sunderland WestHam
# (388.45489921387889, 325.54510078612105, 230.03777187159034, 214.96222812840969)
#
#
# ------------------
# 8 City Newcastle
# (705.50564853478863, 537.49435146521137, 901.93670037107722, 918.06329962892278)
#
#
# ------------------
# 8 Villa Stoke
# (180.01136335712812, 391.98863664287188, 52.934412310972839, 34.065587689027161)
#
#
# ------------------
# 8 Bournemouth Watford
# (172.54127230380655, 116.45872769619345, 122.64197618226359, 176.35802381773638)
#
#
# ------------------
# 8 Chelsea Southampton
# (2718.0777916256602, 1915.9222083743396, 504.70920034640312, 538.29079965359688)
#
#
# ------------------
# 8 Everton Liverpool
# (532.20056340572569, 646.79943659427431, 3842.4169409931324, 3583.5830590068672)
#
#
# ------------------
# 8 Swansea Tottenham
# (184.33400971308788, 120.66599028691211, 770.00134285342745, 527.99865714657255)
#
#
# ------------------
# 8 Arsenal United
# (6015.9172369150365, 4353.0827630849635, 6225.2468717109696, 9573.7531282890304)
#
#
# ------------------
# 9 Tottenham Liverpool
# (990.94815524462297, 652.05184475537692, 2837.8337702995232, 2772.1662297004773)
#
#
# ------------------
# 9 Southampton Leicester
# (205.11449685122133, 103.88550314877867, 159.06342138729468, 122.9365786127053)
#
#
# ------------------
# 9 WestBromwich Sunderland
# (62.238719606270926, 187.76128039372907, 112.79267871843426, 112.20732128156574)
#
#
# ------------------
# 9 Chelsea Villa
# (1106.7391384340585, 961.2608615659417, 298.82455782282125, 566.17544217717875)
#
#
# ------------------
# 9 Crystal WestHam
# (201.42580444603749, 192.57419555396251, 133.11791568723049, 103.88208431276948)
#
#
# ------------------
# 9 Everton United
# (361.4213935977175, 468.57860640228256, 4811.458956784023, 3500.541043215977)
#
#
# ------------------
# 9 City Bournemouth
# (1013.570322266366, 729.42967773363409, 189.07094102063024, 132.92905897936976)
#
#
# ------------------
# 9 Watford Arsenal
# (162.82117732941376, 145.17882267058624, 1339.7548094895683, 995.2451905104316)
#
#
# ------------------
# 9 Newcastle Norwich
# (1121.181662313747, 1603.818337686253, 481.77857671843401, 744.22142328156599)
#
#
# ------------------
# 9 Swansea Stoke
# (114.7908545156846, 73.2091454843154, 209.31532568092169, 195.68467431907831)
#
#
# ------------------
# 10 Norwich WestBromwich
# (75.913707342339791, 100.08629265766021, 134.80657327607332, 187.19342672392673)
#
#
# ------------------
# 10 Leicester Crystal
# (94.065972684500281, 42.934027315499712, 123.1041754216387, 105.8958245783613)
#
#
# ------------------
# 10 Villa Swansea
# (188.3233974592799, 348.67660254072007, 61.67421669343571, 31.32578330656429)
#
#
# ------------------
# 10 WestHam Chelsea
# (331.79550695413673, 194.20449304586327, 1757.4216117050755, 2496.5783882949245)
#
#
# ------------------
# 10 Stoke Watford
# (109.4055141479684, 204.5944858520316, 201.73006487748796, 136.26993512251207)
#
#
# ------------------
# 10 Arsenal Everton
# (2136.9145238771093, 1329.0854761228907, 373.21768523688098, 470.78231476311902)
#
#
# ------------------
# 10 Sunderland Newcastle
# (257.2089258242994, 241.79107417570054, 661.04429985983086, 909.95570014016914)
#
#
# ------------------
# 10 United City
# (2433.5217096946644, 2080.4782903053356, 497.96755235842841, 383.03244764157165)
#
#
# ------------------
# 10 Bournemouth Tottenham
# (209.78695627364223, 189.21304372635777, 968.74448417024041, 678.25551582975959)
#
#
# ------------------
# 10 Liverpool Southampton
# (1308.7970929842747, 1485.2029070157253, 172.44272587425917, 113.55727412574086)
#
#
# ------------------
# 11 Chelsea Liverpool
# (1456.2575346279511, 1238.7424653720489, 1413.2825551778501, 1999.7174448221499)
#
#
# ------------------
# 11 Swansea Arsenal
# (54.982126317448625, 18.017873682551375, 825.04795321177596, 600.95204678822415)
#
#
# ------------------
# 11 WestBromwich Leicester
# (62.539411241510585, 105.46058875848942, 113.7749804118973, 57.225019588102704)
#
#
# ------------------
# 11 Watford WestHam
# (89.447407250086201, 65.552592749913799, 84.437019952363329, 65.562980047636671)
#
#
# ------------------
# 11 Newcastle Stoke
# (270.81413126969403, 309.18586873030597, 64.972831522370669, 49.027168477629338)
#
#
# ------------------
# 11 City Norwich
# (389.26889651123054, 361.73110348876946, 93.605324704100326, 120.39467529589965)
#
#
# ------------------
# 11 Crystal United
# (115.81684765796244, 68.183152342037559, 1520.4733562531865, 1878.5266437468135)
#
#
# ------------------
# 11 Everton Sunderland
# (455.66127223253034, 576.33872776746966, 259.35622472100249, 296.64377527899751)
#
#
# ------------------
# 11 Southampton Bournemouth
# (376.2036593053798, 148.79634069462014, 194.28343629574783, 141.7165637042522)
#
#
# ------------------
# 11 Tottenham Villa
# (1193.0708023884376, 585.92919761156236, 768.15126357187057, 1734.8487364281295)
#
#
# ------------------
# 12 Bournemouth Newcastle
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Leicester Watford
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Norwich Swansea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 WestHam Everton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Sunderland Southampton
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 United WestBromwich
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Stoke Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Villa City
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Liverpool Crystal
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 12 Arsenal Tottenham
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 13 Watford United
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 13 Swansea Bournemouth
# (151.27077325547896, 103.72922674452104, 266.81359361416128, 145.18640638583875)
#
#
# ------------------
# 13 Chelsea Norwich
# (1248.3401410344954, 1756.6598589655041, 133.94349868377427, 144.05650131622576)
#
#
# ------------------
# 13 Everton Villa
# (404.75911544565986, 500.24088455434014, 387.17916791026607, 999.82083208973393)
#
#
# ------------------
# 13 WestBromwich Arsenal
# (114.05633404570059, 185.94366595429941, 1600.873199014366, 1719.126800985634)
#
#
# ------------------
# 13 Newcastle Leicester
# (401.52814145193952, 619.47185854806048, 676.80672311004207, 186.19327688995799)
#
#
# ------------------
# 13 Southampton Stoke
# (96.042986780857518, 106.95701321914248, 111.29063121811403, 83.709368781885971)
#
#
# ------------------
# 13 City Liverpool
# (1001.0381751906234, 1027.9618248093766, 6450.4497081141089, 5186.5502918858911)
#
#
# ------------------
# 13 Tottenham WestHam
# (1839.655906541338, 1264.3440934586617, 322.02194348583441, 342.97805651416559)
#
#
# ------------------
# 13 Crystal Sunderland
# (258.80660706556796, 188.1933929344321, 194.38352794697244, 222.61647205302762)
#
#
# ------------------
# 14 Sunderland Stoke
# (135.038642035316, 98.961357964683998, 62.114665433014338, 68.885334566985648)
#
#
# ------------------
# 14 Bournemouth Everton
# (100.18969401823129, 88.810305981768721, 356.29916503021434, 218.70083496978566)
#
#
# ------------------
# 14 Villa Watford
# (397.51569571833886, 637.48430428166125, 86.397806738596927, 119.60219326140306)
#
#
# ------------------
# 14 Crystal Newcastle
# (309.9664695660382, 177.03353043396183, 831.1456538695827, 1733.8543461304173)
#
#
# ------------------
# 14 City Southampton
# (689.78685960769258, 363.21314039230731, 243.56662380099704, 289.43337619900296)
#
#
# ------------------
# 14 Leicester United
# (1854.2299375773498, 519.7700624226502, 5272.1889053401592, 5157.8110946598408)
#
#
# ------------------
# 14 Tottenham Chelsea
# (642.39358332872882, 469.60641667127106, 999.58816931369745, 976.41183068630244)
#
#
# ------------------
# 14 WestHam WestBromwich
# (278.63456791110235, 135.36543208889765, 100.70391173671298, 363.29608826328706)
#
#
# ------------------
# 14 Liverpool Swansea
# (1228.8122829544668, 1240.1877170455332, 59.838227327501265, 30.161772672498742)
#
#
# ------------------
# 14 Norwich Arsenal
# (232.66665890766399, 342.33334109233601, 1500.4528201558799, 1693.5471798441199)
#
#
# ------------------
# 15 Stoke City
# (522.85086435893038, 398.14913564106962, 681.58258064451866, 1025.4174193554813)
#
#
# ------------------
# 15 Arsenal Sunderland
# (1413.6905048172739, 1106.3094951827261, 198.35954966887488, 152.64045033112512)
#
#
# ------------------
# 15 WestBromwich Tottenham
# (123.15193954157455, 178.84806045842544, 830.80740425582871, 351.19259574417129)
#
#
# ------------------
# 15 Watford Norwich
# (104.07817721077987, 111.92182278922013, 157.08853887439568, 276.91146112560432)
#
#
# ------------------
# 15 United WestHam
# (1765.8624490729644, 2205.1375509270356, 205.87974970124588, 167.12025029875409)
#
#
# ------------------
# 15 Swansea Leicester
# (139.09542500824122, 73.904574991758807, 502.9088738211284, 244.09112617887158)
#
#
# ------------------
# 15 Southampton Villa
# (146.91666260476472, 175.08333739523525, 459.20564581874112, 654.79435418125888)
#
#
# ------------------
# 15 Chelsea Bournemouth
# (917.71889254750067, 1043.2811074524993, 203.94963904853566, 76.050360951464341)
#
#
# ------------------
# 15 Newcastle Liverpool
# (514.06338670173818, 704.93661329826182, 1606.2459135755817, 2024.7540864244186)
#
#
# ------------------
# 15 Everton Crystal
# (247.45330823364853, 260.5466917663515, 262.75468881485062, 192.2453111851494)
#
#
# ------------------
# 16 Norwich Everton
# (191.39228489060639, 423.60771510939361, 450.95739609429086, 569.04260390570903)
#
#
# ------------------
# 16 WestHam Stoke
# (102.7575353512037, 109.24246464879631, 43.106914085108748, 43.893085914891252)
#
#
# ------------------
# 16 Sunderland Watford
# (166.95707260322462, 177.04292739677538, 139.65261135316882, 155.34738864683118)
#
#
# ------------------
# 16 City Swansea
# (456.72381939478169, 331.27618060521831, 133.45711736098295, 57.542882639017044)
#
#
# ------------------
# 16 Crystal Southampton
# (202.53715010469821, 88.462849895301787, 147.05536646443772, 123.94463353556226)
#
#
# ------------------
# 16 Bournemouth United
# (331.38734500000214, 150.61265499999786, 3361.8301139468567, 3787.1698860531433)
#
#
# ------------------
# 16 Villa Arsenal
# (533.6743989895399, 1379.3256010104603, 2181.0320594513887, 1167.9679405486115)
#
#
# ------------------
# 16 Liverpool WestBromwich
# (2324.1362484786587, 2324.8637515213413, 96.965321591084489, 203.03467840891551)
#
#
# ------------------
# 16 Tottenham Newcastle
# (1116.4406993083749, 516.55930069162514, 746.14322478432905, 1042.856775215671)
#
#
# ------------------
# 16 Leicester Chelsea
# [Not Game Exists]: Check your inputs
# None None
# None
#
#
# ------------------
# 17 Stoke Crystal
# (58.098202167166335, 57.901797832833665, 233.68028980657135, 99.31971019342862)
#
#
# ------------------
# 17 WestBromwich Bournemouth
# (102.09121762636541, 202.90878237363461, 98.050551989687108, 53.949448010312892)
#
#
# ------------------
# 17 Chelsea Sunderland
# (3636.1486900470118, 4395.8513099529882, 259.00488959761998, 324.99511040237996)
#
#
# ------------------
# 17 Everton Leicester
# (233.72959586710914, 206.27040413289086, 359.44386824988635, 182.55613175011365)
#
#
# ------------------
# 17 United Norwich
# (2716.3060548933777, 4906.6939451066219, 255.86425156687568, 337.13574843312438)
#
#
# ------------------
# 17 Southampton Tottenham
# (241.94092122568782, 274.05907877431218, 1232.0617948814149, 704.93820511858507)
#
#
# ------------------
# 17 Newcastle Villa
# (729.14009756337964, 822.85990243662036, 445.14088503593121, 1170.8591149640688)
#
#
# ------------------
# 17 Watford Liverpool
# (416.16506577132537, 391.83493422867463, 3633.1086042729621, 6042.8913957270379)
#
#
# ------------------
# 17 Swansea WestHam
# (177.01158867658074, 60.988411323419228, 261.76260777081478, 195.23739222918522)
#
#
# ------------------
# 17 Arsenal City
# (4769.1164881255845, 2793.883511874415, 897.40694687290136, 809.59305312709853)
#
#
# ------------------
# 18 Stoke United
# (530.22451460675234, 573.77548539324766, 6232.6949761183287, 11419.305023881669)
#
#
# ------------------
# 18 Tottenham Norwich
# (979.71890183492008, 861.28109816507992, 154.22427063123345, 235.77572936876655)
#
#
# ------------------
# 18 Swansea WestBromwich
# (95.4547354917338, 31.545264508266193, 96.92843253563862, 228.07156746436141)
#
#
# ------------------
# 18 City Sunderland
# (945.36487524120923, 765.63512475879077, 273.86300394982914, 407.13699605017081)
#
#
# ------------------
# 18 Liverpool Leicester
# (1569.7436222572605, 1681.2563777427395, 278.53029421116617, 121.46970578883388)
#
#
# ------------------
# 18 Chelsea Watford
# (1307.6298362773678, 1291.3701637226322, 187.68602070528434, 157.31397929471569)
#
#
# ------------------
# 18 Villa WestHam
# (189.76686945675181, 380.23313054324819, 211.27057956838422, 131.72942043161578)
#
#
# ------------------
# 18 Bournemouth Crystal
# (76.52387156388339, 56.476128436116618, 124.2850307335318, 97.714969266468202)
#
#
# ------------------
# 18 Newcastle Everton
# (398.40110776389116, 677.5988922361089, 318.95797880068028, 344.04202119931972)
#
#
# ------------------
# 18 Southampton Arsenal
# (685.90990753204346, 345.09009246795654, 1952.0278277723019, 1572.9721722276981)
#
#
# ------------------
# 19 Crystal Swansea
# (115.29406193074192, 131.70593806925808, 59.23105324178924, 33.768946758210753)
#
#
# ------------------
# 19 Everton Stoke
# (267.48999555115336, 307.51000444884664, 239.53350922466379, 248.46649077533621)
#
#
# ------------------
# 19 Norwich Villa
# (120.26458137337711, 181.7354186266229, 293.75478043405928, 774.24521956594072)
#
#
# ------------------
# 19 Watford Tottenham
# (213.88350245356338, 219.11649754643662, 947.94652405628472, 558.05347594371528)
#
#
# ------------------
# 19 WestBromwich Newcastle
# (73.166397495558499, 162.8336025044415, 377.01103677417029, 579.98896322582971)
#
#
# ------------------
# 19 WestHam Southampton
# (197.72184086709154, 152.27815913290846, 257.62489462983763, 148.37510537016237)
#
#
# ------------------
# 19 Arsenal Bournemouth
# (1846.0292045588496, 915.97079544115036, 196.32847169932117, 69.671528300678858)
#
#
# ------------------
# 19 United Chelsea
# (5367.7888078575079, 5680.2111921424921, 1632.2780910220374, 1935.7219089779621)
#
#
# ------------------
# 19 Leicester City
# (429.22639273749377, 227.77360726250623, 709.18525652126709, 562.81474347873291)
#
#
# ------------------
# 19 Sunderland Liverpool
# (282.56049182629647, 208.43950817370356, 1696.8216470263164, 1806.1783529736836)
#
#
# ------------------
# 20 WestHam Liverpool
# (485.9538552731849, 288.04614472681504, 2498.4113838019575, 4189.5886161980425)
#
#
# ------------------
# 20 Arsenal Newcastle
# (1654.5851708344401, 1148.4148291655599, 512.98049540630473, 665.01950459369527)
#
#
# ------------------
# 20 WestBromwich Stoke
# (113.1858333442414, 81.814166655758612, 44.791490813826194, 62.208509186173792)
#
#
# ------------------
# 20 Sunderland Villa
# (235.9369481774969, 199.0630518225031, 402.44126969352772, 890.5587303064724)
#
#
# ------------------
# 20 Norwich Southampton
# (262.30141291307024, 163.69858708692976, 159.77635109735084, 144.22364890264913)
#
#
# ------------------
# 20 United Swansea
# (2895.2275962931972, 4579.7724037068028, 118.12473478378016, 54.87526521621983)
#
#
# ------------------
# 20 Leicester Bournemouth
# (199.68300929962979, 130.31699070037021, 167.24738837778438, 46.752611622215603)
#
#
# ------------------
# 20 Watford City
# (115.20778933010671, 144.79221066989328, 546.653956442084, 626.34604355791589)
#
#
# ------------------
# 20 Crystal Chelsea
# (333.50678447869126, 304.49321552130868, 1843.4100803263177, 1916.5899196736825)
#
#
# ------------------
# 20 Everton Tottenham
# (871.81547546388845, 1146.1845245361114, 2970.5175124349635, 1490.482487565037)
#
#
# ------------------
# 21 Villa Crystal
# (281.67435908005382, 381.32564091994618, 192.21278898630112, 155.78721101369888)
#
#
# ------------------
# 21 Newcastle United
# (1176.0027422903274, 1821.9972577096726, 6295.8930708544967, 6029.1069291455042)
#
#
# ------------------
# 21 Bournemouth WestHam
# (167.96570623425256, 97.034293765747435, 184.07835815413617, 260.9216418458638)
#
#
# ------------------
# 21 Stoke Norwich
# (79.343041982607673, 81.656958017392327, 217.48772240294841, 433.51227759705159)
#
#
# ------------------
# 21 Southampton Watford
# (290.51970972672405, 147.48029027327595, 138.84463550617824, 175.15536449382176)
#
#
# ------------------
# 21 City Everton
# (318.04938736916279, 303.95061263083721, 191.58357837400334, 175.41642162599666)
#
#
# ------------------
# 21 Chelsea WestBromwich
# (974.56131364376006, 836.43868635623994, 155.43187352074943, 263.56812647925057)
#
#
# ------------------
# 21 Swansea Sunderland
# (206.8348882303967, 98.1651117696033, 394.11020042653786, 478.88979957346214)
#
#
# ------------------
# 21 Tottenham Leicester
# (526.70443670788927, 348.29556329211073, 207.90286564538729, 101.09713435461271)
#
#
# ------------------
# 21 Liverpool Arsenal
# (5470.2014826054492, 4890.7985173945508, 2751.4981775614056, 1957.5018224385947)
#
#
# ------------------
# 22 Tottenham Sunderland
# (899.55986621173918, 678.44013378826082, 450.52328582183372, 402.47671417816628)
#
#
# ------------------
# 22 Newcastle WestHam
# (1312.1352975371974, 1337.8647024628024, 248.85835574183471, 202.14164425816529)
#
#
# ------------------
# 22 Bournemouth Norwich
# (141.55636906485702, 104.44363093514295, 252.02697595644887, 346.97302404355116)
#
#
# ------------------
# 22 Chelsea Everton
# (968.78413191420361, 1365.2158680857965, 137.60643824348818, 163.39356175651182)
#
#
# ------------------
# 22 Southampton WestBromwich
# (514.96059696455882, 258.03940303544124, 97.228709915151541, 225.77129008484849)
#
#
# ------------------
# 22 City Crystal
# (690.4497173535799, 401.5502826464201, 339.10056179265609, 272.89943820734391)
#
#
# ------------------
# 22 Villa Leicester
# (446.68112160848068, 704.31887839151932, 503.62077452640187, 294.37922547359813)
#
#
# ------------------
# 22 Liverpool United
# (2572.7950476006108, 2586.2049523993892, 3895.7691853582737, 5517.2308146417263)
#
#
# ------------------
# 22 Stoke Arsenal
# (225.83849983085202, 348.16150016914804, 1345.2571238601149, 1191.7428761398851)
#
#
# ------------------
# 22 Swansea Watford
# (225.61212091858283, 71.387879081417168, 203.3282129348209, 393.67178706517916)
# [Done:] 2215.04

# %%
pn_home_pos = []
pn_home_neg = []
pn_away_pos = []
pn_away_neg = []

for pn_scores in counted_game_emolex:
    if pn_scores is None:
        pn_home_pos.append(-1)
        pn_home_neg.append(-1)
        pn_away_pos.append(-1)
        pn_away_neg.append(-1)
    else:
        pn_home_pos.append(pn_scores[0])
        pn_home_neg.append(pn_scores[1])
        pn_away_pos.append(pn_scores[2])
        pn_away_neg.append(pn_scores[3])


dfGameInfos['pn_home_pos'] = pn_home_pos
dfGameInfos['pn_home_neg'] = pn_home_neg
dfGameInfos['pn_away_pos'] = pn_away_pos
dfGameInfos['pn_away_neg'] = pn_away_neg

dfGameInfos
# Out:
#      GW     away_team           date     home_team  score_ft_away  \
# 0     1     Tottenham   Sat. 8 Aug.         United              0
# 1     1       Watford   Sat. 8 Aug.        Everton              2
# 2     1    Sunderland   Sat. 8 Aug.      Leicester              2
# 3     1       Crystal   Sat. 8 Aug.        Norwich              3
# 4     1         Villa   Sat. 8 Aug.    Bournemouth              1
# 5     1       Swansea   Sat. 8 Aug.        Chelsea              2
# 6     1       WestHam   Sun. 9 Aug.        Arsenal              2
# 7     1   Southampton   Sun. 9 Aug.      Newcastle              2
# 8     1     Liverpool   Sun. 9 Aug.          Stoke              1
# 9     1          City  Mon. 10 Aug.   WestBromwich              3
# 10    2        United  Fri. 14 Aug.          Villa              1
# 11    2       Everton  Sat. 15 Aug.    Southampton              3
# 12    2         Stoke  Sat. 15 Aug.      Tottenham              2
# 13    2     Leicester  Sat. 15 Aug.        WestHam              2
# 14    2  WestBromwich  Sat. 15 Aug.        Watford              0
# 15    2       Norwich  Sat. 15 Aug.     Sunderland              3
# 16    2     Newcastle  Sat. 15 Aug.        Swansea              0
# 17    2       Arsenal  Sun. 16 Aug.        Crystal              2
# 18    2       Chelsea  Sun. 16 Aug.           City              0
# 19    2   Bournemouth  Mon. 17 Aug.      Liverpool              0
# 20    3     Newcastle  Sat. 22 Aug.         United              0
# 21    3         Villa  Sat. 22 Aug.        Crystal              1
# 22    3   Bournemouth  Sat. 22 Aug.        WestHam              4
# 23    3       Swansea  Sat. 22 Aug.     Sunderland              1
# 24    3         Stoke  Sat. 22 Aug.        Norwich              1
# 25    3     Tottenham  Sat. 22 Aug.      Leicester              1
# 26    3       Chelsea  Sun. 23 Aug.   WestBromwich              3
# 27    3   Southampton  Sun. 23 Aug.        Watford              0
# 28    3          City  Sun. 23 Aug.        Everton              2
# 29    3     Liverpool  Mon. 24 Aug.        Arsenal              0
# ..   ..           ...            ...           ...            ...
# 190  20     Liverpool   Sat. 2 Jan.        WestHam              0
# 191  20     Newcastle   Sat. 2 Jan.        Arsenal              0
# 192  20         Stoke   Sat. 2 Jan.   WestBromwich              1
# 193  20         Villa   Sat. 2 Jan.     Sunderland              1
# 194  20   Southampton   Sat. 2 Jan.        Norwich              0
# 195  20       Swansea   Sat. 2 Jan.         United              1
# 196  20   Bournemouth   Sat. 2 Jan.      Leicester              0
# 197  20          City   Sat. 2 Jan.        Watford              2
# 198  20       Chelsea   Sun. 3 Jan.        Crystal              3
# 199  20     Tottenham   Sun. 3 Jan.        Everton              1
# 200  21       Crystal  Tue. 12 Jan.          Villa              0
# 201  21        United  Tue. 12 Jan.      Newcastle              3
# 202  21       WestHam  Tue. 12 Jan.    Bournemouth              3
# 203  21       Norwich  Wed. 13 Jan.          Stoke              1
# 204  21       Watford  Wed. 13 Jan.    Southampton              0
# 205  21       Everton  Wed. 13 Jan.           City              0
# 206  21  WestBromwich  Wed. 13 Jan.        Chelsea              2
# 207  21    Sunderland  Wed. 13 Jan.        Swansea              4
# 208  21     Leicester  Wed. 13 Jan.      Tottenham              1
# 209  21       Arsenal  Wed. 13 Jan.      Liverpool              3
# 210  22    Sunderland  Sat. 16 Jan.      Tottenham              1
# 211  22       WestHam  Sat. 16 Jan.      Newcastle              1
# 212  22       Norwich  Sat. 16 Jan.    Bournemouth              0
# 213  22       Everton  Sat. 16 Jan.        Chelsea              3
# 214  22  WestBromwich  Sat. 16 Jan.    Southampton              0
# 215  22       Crystal  Sat. 16 Jan.           City              0
# 216  22     Leicester  Sat. 16 Jan.          Villa              1
# 217  22        United  Sun. 17 Jan.      Liverpool              1
# 218  22       Arsenal  Sun. 17 Jan.          Stoke              0
# 219  22       Watford  Mon. 18 Jan.        Swansea              0
#
#      score_ft_home  score_ht_away  score_ht_home   time  pn_home_pos  \
# 0                1              0              1  11:45    -1.000000
# 1                2              1              0  14:00    -1.000000
# 2                4              0              3  14:00    -1.000000
# 3                1              1              0  14:00    -1.000000
# 4                0              0              0  14:00    -1.000000
# 5                2              1              2  16:30    -1.000000
# 6                0              1              0  12:30    -1.000000
# 7                2              1              1  12:30    -1.000000
# 8                0              0              0  15:00    -1.000000
# 9                0              2              0  19:00    -1.000000
# 10               0              1              0  18:45    -1.000000
# 11               0              2              0  11:45    -1.000000
# 12               2              0              2  14:00    -1.000000
# 13               1              2              0  14:00    -1.000000
# 14               0              0              0  14:00    -1.000000
# 15               1              2              0  14:00    -1.000000
# 16               2              0              1  14:00    -1.000000
# 17               1              1              1  12:30    -1.000000
# 18               3              0              1  15:00    -1.000000
# 19               1              0              1  19:00    -1.000000
# 20               0              0              0  11:45    -1.000000
# 21               2              0              0  14:00    -1.000000
# 22               3              2              0  14:00    -1.000000
# 23               1              1              0  14:00    -1.000000
# 24               1              1              1  14:00    -1.000000
# 25               1              0              0  14:00    -1.000000
# 26               2              3              1  12:30    -1.000000
# 27               0              0              0  15:00    -1.000000
# 28               0              0              0  15:00    -1.000000
# 29               0              0              0  19:00    -1.000000
# ..             ...            ...            ...    ...          ...
# 190              2              0              1  12:45   485.953855
# 191              1              0              0  15:00  1654.585171
# 192              2              0              0  15:00   113.185833
# 193              3              0              1  15:00   235.936948
# 194              1              0              0  15:00   262.301413
# 195              2              0              0  15:00  2895.227596
# 196              0              0              0  15:00   199.683009
# 197              1              0              0  17:30   115.207789
# 198              0              1              0  13:30   333.506784
# 199              1              1              1  16:00   871.815475
# 200              1              0              0  19:45   281.674359
# 201              3              2              1  19:45  1176.002742
# 202              1              0              1  19:45   167.965706
# 203              3              0              0  19:45    79.343042
# 204              2              0              1  19:45   290.519710
# 205              0              0              0  19:45   318.049387
# 206              2              1              1  19:45   974.561314
# 207              2              1              2  19:45   206.834888
# 208              0              0              0  20:00   526.704437
# 209              3              2              2  20:00  5470.201483
# 210              4              1              1  12:45   899.559866
# 211              2              0              2  15:00  1312.135298
# 212              3              0              1  15:00   141.556369
# 213              3              0              0  15:00   968.784132
# 214              3              0              2  15:00   514.960597
# 215              4              0              2  15:00   690.449717
# 216              1              1              0  17:30   446.681122
# 217              0              0              0  14:05  2572.795048
# 218              0              0              0  16:15   225.838500
# 219              1              0              1  20:00   225.612121
#
#      pn_home_neg  pn_away_pos  pn_away_neg
# 0      -1.000000    -1.000000    -1.000000
# 1      -1.000000    -1.000000    -1.000000
# 2      -1.000000    -1.000000    -1.000000
# 3      -1.000000    -1.000000    -1.000000
# 4      -1.000000    -1.000000    -1.000000
# 5      -1.000000    -1.000000    -1.000000
# 6      -1.000000    -1.000000    -1.000000
# 7      -1.000000    -1.000000    -1.000000
# 8      -1.000000    -1.000000    -1.000000
# 9      -1.000000    -1.000000    -1.000000
# 10     -1.000000    -1.000000    -1.000000
# 11     -1.000000    -1.000000    -1.000000
# 12     -1.000000    -1.000000    -1.000000
# 13     -1.000000    -1.000000    -1.000000
# 14     -1.000000    -1.000000    -1.000000
# 15     -1.000000    -1.000000    -1.000000
# 16     -1.000000    -1.000000    -1.000000
# 17     -1.000000    -1.000000    -1.000000
# 18     -1.000000    -1.000000    -1.000000
# 19     -1.000000    -1.000000    -1.000000
# 20     -1.000000    -1.000000    -1.000000
# 21     -1.000000    -1.000000    -1.000000
# 22     -1.000000    -1.000000    -1.000000
# 23     -1.000000    -1.000000    -1.000000
# 24     -1.000000    -1.000000    -1.000000
# 25     -1.000000    -1.000000    -1.000000
# 26     -1.000000    -1.000000    -1.000000
# 27     -1.000000    -1.000000    -1.000000
# 28     -1.000000    -1.000000    -1.000000
# 29     -1.000000    -1.000000    -1.000000
# ..           ...          ...          ...
# 190   288.046145  2498.411384  4189.588616
# 191  1148.414829   512.980495   665.019505
# 192    81.814167    44.791491    62.208509
# 193   199.063052   402.441270   890.558730
# 194   163.698587   159.776351   144.223649
# 195  4579.772404   118.124735    54.875265
# 196   130.316991   167.247388    46.752612
# 197   144.792211   546.653956   626.346044
# 198   304.493216  1843.410080  1916.589920
# 199  1146.184525  2970.517512  1490.482488
# 200   381.325641   192.212789   155.787211
# 201  1821.997258  6295.893071  6029.106929
# 202    97.034294   184.078358   260.921642
# 203    81.656958   217.487722   433.512278
# 204   147.480290   138.844636   175.155364
# 205   303.950613   191.583578   175.416422
# 206   836.438686   155.431874   263.568126
# 207    98.165112   394.110200   478.889800
# 208   348.295563   207.902866   101.097134
# 209  4890.798517  2751.498178  1957.501822
# 210   678.440134   450.523286   402.476714
# 211  1337.864702   248.858356   202.141644
# 212   104.443631   252.026976   346.973024
# 213  1365.215868   137.606438   163.393562
# 214   258.039403    97.228710   225.771290
# 215   401.550283   339.100562   272.899438
# 216   704.318878   503.620775   294.379225
# 217  2586.204952  3895.769185  5517.230815
# 218   348.161500  1345.257124  1191.742876
# 219    71.387879   203.328213   393.671787
#
# [220 rows x 13 columns]

# %%
# Save as CSV
useful_methods.DFtoCSV(dfGameInfos, paths.DATA_HOME + "EPL/", 'all_game_hash_emolex_pn_score', index=False)
print("[Saved in]: %s" % (paths.DATA_HOME + "EPL/" + 'all_game_hash_emolex_pn_score.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/all_game_hash_emolex_pn_score.csv
