# %%
import tweepy
import csv

import os
import sys

path = str(os.path.expanduser('~')) + '/git'
sys.path.append(path)
import twitter_api_tokens as tokens

#Twitter API credentials
consumer_key = tokens.consumer_key
consumer_secret = tokens.consumer_secret
access_key = tokens.access_token
access_secret = tokens.access_token_secret

# %%
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
	
	#authorize twitter, initialize tweepy
	auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
	auth.set_access_token(access_key, access_secret)
	api = tweepy.API(auth)
	
	#initialize a list to hold all the tweepy Tweets
	alltweets = []	
	
	#make initial request for most recent tweets (200 is the maximum allowed count)
	new_tweets = api.user_timeline(screen_name = screen_name,count=200)
	
	#save most recent tweets
	alltweets.extend(new_tweets)
	
	#save the id of the oldest tweet less one
	oldest = alltweets[-1].id - 1
	
	#keep grabbing tweets until there are no tweets left to grab
	while len(new_tweets) > 0:
		print "getting tweets before %s" % (oldest)
		
		#all subsiquent requests use the max_id param to prevent duplicates
		new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
		
		#save most recent tweets
		alltweets.extend(new_tweets)
		
		#update the id of the oldest tweet less one
		oldest = alltweets[-1].id - 1
		
		print "...%s tweets downloaded so far" % (len(alltweets))
	
	#transform the tweepy tweets into a 2D array that will populate the csv	
	outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
	os.chdir("/Users/Bya/git/wordle-me/WordExtract/DownloadedTweets/")
	#write the csv	
	with open('%s_tweets.csv' % screen_name, 'wb') as f:
		writer = csv.writer(f)
		writer.writerow(["id","created_at","text"])
		writer.writerows(outtweets)
	
	pass

# %%
#pass in the username of the account you want to download
list5persons = ["byambaa_swiss",
                "batchunag",
                "uundaa",
                "barbayar",
                "enqush"]

for person in list5persons:
    get_all_tweets(person)
# Out:
# getting tweets before 638653846617624576
# ...400 tweets downloaded so far
# getting tweets before 561095269563895808
# ...598 tweets downloaded so far
# getting tweets before 436571850630365183
# ...798 tweets downloaded so far
# getting tweets before 404222283553595392
# ...996 tweets downloaded so far
# getting tweets before 379256130007883776
# ...1195 tweets downloaded so far
# getting tweets before 366838492275290111
# ...1395 tweets downloaded so far
# getting tweets before 340806432419110911
# ...1595 tweets downloaded so far
# getting tweets before 324279911516884991
# ...1795 tweets downloaded so far
# getting tweets before 306819692750852096
# ...1994 tweets downloaded so far
# getting tweets before 300596406794727423
# ...2193 tweets downloaded so far
# getting tweets before 295522383392014335
# ...2393 tweets downloaded so far
# getting tweets before 289620229082988543
# ...2593 tweets downloaded so far
# getting tweets before 266182739319988223
# ...2793 tweets downloaded so far
# getting tweets before 254968102771621887
# ...2993 tweets downloaded so far
# getting tweets before 241929597090947071
# ...3192 tweets downloaded so far
# getting tweets before 231051269907828736
# ...3197 tweets downloaded so far
# getting tweets before 231049595466166271
# ...3197 tweets downloaded so far
# getting tweets before 513313829992665087
# ...396 tweets downloaded so far
# getting tweets before 390708262859194367
# ...591 tweets downloaded so far
# getting tweets before 344434102772051967
# ...787 tweets downloaded so far
# getting tweets before 327331666223837183
# ...983 tweets downloaded so far
# getting tweets before 277944327567704063
# ...1183 tweets downloaded so far
# getting tweets before 222222335447539711
# ...1378 tweets downloaded so far
# getting tweets before 178366884322869247
# ...1578 tweets downloaded so far
# getting tweets before 138193694124818431
# ...1690 tweets downloaded so far
# getting tweets before 28800719702
# ...1690 tweets downloaded so far
# getting tweets before 637117609209532415
# ...397 tweets downloaded so far
# getting tweets before 620541137799901183
# ...597 tweets downloaded so far
# getting tweets before 571865684042362879
# ...796 tweets downloaded so far
# getting tweets before 565067078596456448
# ...995 tweets downloaded so far
# getting tweets before 532380455773806592
# ...1190 tweets downloaded so far
# getting tweets before 440812057739280383
# ...1389 tweets downloaded so far
# getting tweets before 431864922897539071
# ...1586 tweets downloaded so far
# getting tweets before 415303924782870527
# ...1781 tweets downloaded so far
# getting tweets before 409025982474231807
# ...1977 tweets downloaded so far
# getting tweets before 401464360683319295
# ...2176 tweets downloaded so far
# getting tweets before 391563241299533823
# ...2376 tweets downloaded so far
# getting tweets before 358862171775565823
# ...2576 tweets downloaded so far
# getting tweets before 309256547920396287
# ...2776 tweets downloaded so far
# getting tweets before 294686678315057152
# ...2976 tweets downloaded so far
# getting tweets before 250225583911485439
# ...3176 tweets downloaded so far
# getting tweets before 236394839355301887
# ...3179 tweets downloaded so far
# getting tweets before 236371577850195968
# ...3179 tweets downloaded so far
# getting tweets before 627304058114576383
# ...399 tweets downloaded so far
# getting tweets before 590722792821301247
# ...599 tweets downloaded so far
# getting tweets before 569159160949944321
# ...798 tweets downloaded so far
# getting tweets before 555183455105871871
# ...998 tweets downloaded so far
# getting tweets before 541776542913687552
# ...1197 tweets downloaded so far
# getting tweets before 528854969655779327
# ...1397 tweets downloaded so far
# getting tweets before 516816306037735424
# ...1597 tweets downloaded so far
# getting tweets before 504619723410010111
# ...1797 tweets downloaded so far
# getting tweets before 489047291706109952
# ...1996 tweets downloaded so far
# getting tweets before 478871981991800833
# ...2195 tweets downloaded so far
# getting tweets before 466162167008342015
# ...2393 tweets downloaded so far
# getting tweets before 448636881442320383
# ...2592 tweets downloaded so far
# getting tweets before 434234480010612735
# ...2789 tweets downloaded so far
# getting tweets before 425861863687979007
# ...2989 tweets downloaded so far
# getting tweets before 415354742660141055
# ...3188 tweets downloaded so far
# getting tweets before 403843947359109119
# ...3189 tweets downloaded so far
# getting tweets before 403587008095731712
# ...3189 tweets downloaded so far
# getting tweets before 640815493486514175
# ...400 tweets downloaded so far
# getting tweets before 620537442290937855
# ...599 tweets downloaded so far
# getting tweets before 609362971404296191
# ...799 tweets downloaded so far
# getting tweets before 595540583109697535
# ...999 tweets downloaded so far
# getting tweets before 583510407127531521
# ...1199 tweets downloaded so far
# getting tweets before 553791793255292927
# ...1399 tweets downloaded so far
# getting tweets before 520793685035077631
# ...1596 tweets downloaded so far
# getting tweets before 482501291390672895
# ...1785 tweets downloaded so far
# getting tweets before 463319064375345151
# ...1980 tweets downloaded so far
# getting tweets before 439643724901933055
# ...2174 tweets downloaded so far
# getting tweets before 412068286344339455
# ...2364 tweets downloaded so far
# getting tweets before 399018463160578047
# ...2557 tweets downloaded so far
# getting tweets before 377643218638483455
# ...2752 tweets downloaded so far
# getting tweets before 321470046025170943
# ...2949 tweets downloaded so far
# getting tweets before 300881123439955967
# ...3142 tweets downloaded so far
# getting tweets before 292834575778983935
# ...3143 tweets downloaded so far
# getting tweets before 292831458870059007
# ...3143 tweets downloaded so far
