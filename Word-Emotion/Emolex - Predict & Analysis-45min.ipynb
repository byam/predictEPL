# %%
# %pylab inline
# %matplotlib inline

import os
import time
import collections
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/Bya/git/predictEPL/utils/")
sys.path.append("/Users/Bya/git/predictEPL/config/")
sys.path.append("/Users/Bya/git/predictEPL/WebScrapping/")

import paths
import espn_urls
import my_plot
import scrap_espn_gamecast
import emolex
import useful_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')

# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]

dfGameInfos.head()
# Out:
#    GW   away_team          date    home_team  score_ft_away  score_ft_home  \
# 0   1   Tottenham  Sat. 8 Aug.        United              0              1
# 1   1     Watford  Sat. 8 Aug.       Everton              2              2
# 2   1  Sunderland  Sat. 8 Aug.     Leicester              2              4
# 3   1     Crystal  Sat. 8 Aug.       Norwich              3              1
# 4   1       Villa  Sat. 8 Aug.   Bournemouth              1              0
#
#    score_ht_away  score_ht_home   time
# 0              0              1  11:45
# 1              1              0  14:00
# 2              0              3  14:00
# 3              1              0  14:00
# 4              0              0  14:00

# %%
# HT: Equal games
# dfGameInfosEqual = dfGameInfos[(dfGameInfos['score_ht_home'] == dfGameInfos['score_ht_away']) &
#                                (dfGameInfos['GW'] >= 4)].copy()

weeks = list(dfGameInfos['GW'])
home_teams = list(dfGameInfos['home_team'])
away_teams = list(dfGameInfos['away_team'])
score_ht_homes = list(dfGameInfos['score_ht_home'])
score_ht_aways = list(dfGameInfos['score_ht_away'])
score_ft_homes = list(dfGameInfos['score_ft_home'])
score_ft_aways = list(dfGameInfos['score_ft_away'])

# %%
# Read Emotion-Lexicon-Soccer as Dictionary
dic_emolex_soccer, dic_emolex_stemmed_soccer = emolex.EmolexSoccerDic()
# Out:
# All Words: 14163

# %%
def EmolexPN(df, start=1, end=45):
    dfEmolex = df.copy()
    
    # set interval
    ith_minute_start = start
    ith_minute_end = end

    # convert to integer
    dfEmolex['ith_minute'] = [int(number) for number in dfEmolex['ith_minute']]
    dfEmolex['positive'] = [int(number) for number in dfEmolex['positive']]
    dfEmolex['negative'] = [int(number) for number in dfEmolex['negative']]

    # Minute Interval's DF
    dfEmolex = dfEmolex[
        (dfEmolex['ith_minute'] >= ith_minute_start) &
        (dfEmolex['ith_minute'] <= ith_minute_end)
    ].copy()

    # Counting pos, neg
    positive = sum(list(dfEmolex['positive']))
    negative = sum(list(dfEmolex['negative']))
    
    # Return Positve Percentage
    return (positive / (positive + negative))

# %%
res_ht_rt = []

start_time = time.time()

for index in range(len(weeks)):
    try:
        # Read Single Game as DF
        filename = home_teams[index] + '_vs_' + away_teams[index] + '.csv'
        os.chdir(paths.READ_PATH_EXTRACTED_CSV + 'GW' + str(weeks[index]) + '/SingleGames/')
        df = useful_methods.csv_dic_df(filename)

        # Filter DF: remove tweets of stream, bots ...
        dfFilter = useful_methods.FilterDF(df)

        # Count Emolex cateries on Tweets by minutes
        dfFilterEmolexSoccerHome = emolex.CreateEmolexDF(dfFilter[dfFilter['side'] == 'home'], dic_emolex_soccer, dic_emolex_stemmed_soccer)
        dfFilterEmolexSoccerAway = emolex.CreateEmolexDF(dfFilter[dfFilter['side'] == 'away'], dic_emolex_soccer, dic_emolex_stemmed_soccer)

        # Calculate PN %
        emolex_pn_home = EmolexPN(dfFilterEmolexSoccerHome)
        emolex_pn_away = EmolexPN(dfFilterEmolexSoccerAway)

        # Append Resulst
        res_ht_rt.append([index, emolex_pn_home, emolex_pn_away])
    except:
        continue

print("[Done]: %.2f" % (time.time() - start_time))
# Out:
# [Done]: 1388.42
# /Users/Bya/.virtualenvs/py3/lib/python3.4/site-packages/pandas/core/ops.py:680: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)

# %%
ok = 0
ng = 0
eq = 0

for res in res_ht_rt:
    index, pn_home, pn_away = res
    
    if (pn_home > pn_away) and (score_ft_homes[index] > score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("\t[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))

    elif (pn_home < pn_away) and (score_ft_homes[index] < score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))
    
    elif score_ft_homes[index] == score_ft_aways[index]:
        eq += 1
    else:
        ng += 1

print("\n\n\nOK: %s, NG: %s, EQ: %s" % (ok, ng, eq))
# Out:
# ------------------------------
# [GAME]: GW4 Newcastle vs Arsenal
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.358732191452 vs 0.461318051576
#
# ------------------------------
# [GAME]: GW4 Stoke vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.134433962264 vs 0.509881422925
#
# ------------------------------
# [GAME]: GW4 Liverpool vs WestHam
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.545269394557 vs 0.816371681416
#
# ------------------------------
# [GAME]: GW4 Chelsea vs Crystal
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.582383419689 vs 0.837067209776
#
# ------------------------------
# [GAME]: GW4 City vs Watford
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.751351351351 vs 0.702702702703
#
# ------------------------------
# [GAME]: GW4 Southampton vs Norwich
# [SCORE]: HT(1-0) => FT(3-0)
# 	[Emolex PN Score]: 0.669230769231 vs 0.497446373851
#
# ------------------------------
# [GAME]: GW4 Swansea vs United
# [SCORE]: HT(0-0) => FT(2-1)
# 	[Emolex PN Score]: 0.804801670146 vs 0.616076423254
#
# ------------------------------
# [GAME]: GW5 Everton vs Chelsea
# [SCORE]: HT(2-1) => FT(3-1)
# 	[Emolex PN Score]: 0.590772917915 vs 0.458459094519
#
# ------------------------------
# [GAME]: GW5 Norwich vs Bournemouth
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.803738317757 vs 0.696551724138
#
# ------------------------------
# [GAME]: GW5 Arsenal vs Stoke
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.724406779661 vs 0.658536585366
#
# ------------------------------
# [GAME]: GW5 United vs Liverpool
# [SCORE]: HT(0-0) => FT(3-1)
# 	[Emolex PN Score]: 0.660312714134 vs 0.60453436648
#
# ------------------------------
# [GAME]: GW5 Sunderland vs Tottenham
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.546374367622 vs 0.634586466165
#
# ------------------------------
# [GAME]: GW5 WestHam vs Newcastle
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.712534059946 vs 0.572435050638
#
# ------------------------------
# [GAME]: GW6 Bournemouth vs Sunderland
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.852348993289 vs 0.492654260529
#
# ------------------------------
# [GAME]: GW6 Villa vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.612994350282 vs 0.66976744186
#
# ------------------------------
# [GAME]: GW6 Newcastle vs Watford
# [SCORE]: HT(0-2) => FT(1-2)
# [Emolex PN Score]: 0.507595772787 vs 0.774038461538
#
# ------------------------------
# [GAME]: GW6 City vs WestHam
# [SCORE]: HT(1-2) => FT(1-2)
# [Emolex PN Score]: 0.542404473439 vs 0.728832951945
#
# ------------------------------
# [GAME]: GW7 Stoke vs Bournemouth
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.65 vs 0.466950959488
#
# ------------------------------
# [GAME]: GW7 Southampton vs Swansea
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.792682926829 vs 0.684210526316
#
# ------------------------------
# [GAME]: GW7 Liverpool vs Villa
# [SCORE]: HT(1-0) => FT(3-2)
# 	[Emolex PN Score]: 0.71916138469 vs 0.465517241379
#
# ------------------------------
# [GAME]: GW8 Crystal vs WestBromwich
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.542553191489 vs 0.372634643377
#
# ------------------------------
# [GAME]: GW8 Norwich vs Leicester
# [SCORE]: HT(0-1) => FT(1-2)
# [Emolex PN Score]: 0.545751633987 vs 0.642076502732
#
# ------------------------------
# [GAME]: GW8 City vs Newcastle
# [SCORE]: HT(1-1) => FT(6-1)
# 	[Emolex PN Score]: 0.723789249601 vs 0.698954320308
#
# ------------------------------
# [GAME]: GW8 Villa vs Stoke
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.586538461538 vs 0.709090909091
#
# ------------------------------
# [GAME]: GW9 Chelsea vs Villa
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.538232373386 vs 0.402966625464
#
# ------------------------------
# [GAME]: GW9 City vs Bournemouth
# [SCORE]: HT(4-1) => FT(5-1)
# 	[Emolex PN Score]: 0.816489361702 vs 0.626728110599
#
# ------------------------------
# [GAME]: GW9 Watford vs Arsenal
# [SCORE]: HT(0-0) => FT(0-3)
# [Emolex PN Score]: 0.569832402235 vs 0.663665594855
#
# ------------------------------
# [GAME]: GW9 Newcastle vs Norwich
# [SCORE]: HT(3-2) => FT(6-2)
# 	[Emolex PN Score]: 0.641865958075 vs 0.552136752137
#
# ------------------------------
# [GAME]: GW9 Swansea vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.556291390728 vs 0.55773955774
#
# ------------------------------
# [GAME]: GW10 Norwich vs WestBromwich
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.645962732919 vs 0.686335403727
#
# ------------------------------
# [GAME]: GW10 Leicester vs Crystal
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.8125 vs 0.566929133858
#
# ------------------------------
# [GAME]: GW10 Villa vs Swansea
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.583783783784 vs 0.758865248227
#
# ------------------------------
# [GAME]: GW10 WestHam vs Chelsea
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.744537815126 vs 0.488834505965
#
# ------------------------------
# [GAME]: GW10 Arsenal vs Everton
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.79938786867 vs 0.518
#
# ------------------------------
# [GAME]: GW10 Bournemouth vs Tottenham
# [SCORE]: HT(1-3) => FT(1-5)
# [Emolex PN Score]: 0.499501495513 vs 0.545323741007
#
# ------------------------------
# [GAME]: GW11 Everton vs Sunderland
# [SCORE]: HT(2-1) => FT(6-2)
# 	[Emolex PN Score]: 0.657622739018 vs 0.637203166227
#
# ------------------------------
# [GAME]: GW11 Southampton vs Bournemouth
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.809829059829 vs 0.528205128205
#
# ------------------------------
# [GAME]: GW11 Tottenham vs Villa
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.66689373297 vs 0.569444444444
#
# ------------------------------
# [GAME]: GW13 Everton vs Villa
# [SCORE]: HT(3-0) => FT(4-0)
# 	[Emolex PN Score]: 0.743944636678 vs 0.501988862371
#
# ------------------------------
# [GAME]: GW13 WestBromwich vs Arsenal
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.740625 vs 0.627072402938
#
# ------------------------------
# [GAME]: GW13 Newcastle vs Leicester
# [SCORE]: HT(0-1) => FT(0-3)
# [Emolex PN Score]: 0.537439613527 vs 0.652173913043
#
# ------------------------------
# [GAME]: GW13 Southampton vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.573221757322 vs 0.775119617225
#
# ------------------------------
# [GAME]: GW13 City vs Liverpool
# [SCORE]: HT(1-3) => FT(1-4)
# [Emolex PN Score]: 0.432707993475 vs 0.76582761251
#
# ------------------------------
# [GAME]: GW13 Tottenham vs WestHam
# [SCORE]: HT(2-0) => FT(4-1)
# 	[Emolex PN Score]: 0.616803953871 vs 0.526315789474
#
# ------------------------------
# [GAME]: GW13 Crystal vs Sunderland
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.603988603989 vs 0.652173913043
#
# ------------------------------
# [GAME]: GW14 Sunderland vs Stoke
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.693811074919 vs 0.663366336634
#
# ------------------------------
# [GAME]: GW14 Crystal vs Newcastle
# [SCORE]: HT(3-1) => FT(5-1)
# 	[Emolex PN Score]: 0.724431818182 vs 0.528122956181
#
# ------------------------------
# [GAME]: GW14 City vs Southampton
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.582040816327 vs 0.573726541555
#
# ------------------------------
# [GAME]: GW15 Stoke vs City
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.734113712375 vs 0.546930134086
#
# ------------------------------
# [GAME]: GW15 Arsenal vs Sunderland
# [SCORE]: HT(1-1) => FT(3-1)
# 	[Emolex PN Score]: 0.775150472915 vs 0.672514619883
#
# ------------------------------
# [GAME]: GW15 Swansea vs Leicester
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.700906344411 vs 0.767383059418
#
# ------------------------------
# [GAME]: GW15 Chelsea vs Bournemouth
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.530925013684 vs 0.772486772487
#
# ------------------------------
# [GAME]: GW15 Newcastle vs Liverpool
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.560625814863 vs 0.483204134367
#
# ------------------------------
# [GAME]: GW16 Sunderland vs Watford
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.583547557841 vs 0.782978723404
#
# ------------------------------
# [GAME]: GW16 Crystal vs Southampton
# [SCORE]: HT(1-0) => FT(1-0)
# 	[Emolex PN Score]: 0.779279279279 vs 0.744382022472
#
# ------------------------------
# [GAME]: GW16 Bournemouth vs United
# [SCORE]: HT(1-1) => FT(2-1)
# 	[Emolex PN Score]: 0.651336898396 vs 0.61926238452
#
# ------------------------------
# [GAME]: GW16 Villa vs Arsenal
# [SCORE]: HT(0-2) => FT(0-2)
# [Emolex PN Score]: 0.456697149005 vs 0.795847750865
#
#
#
# OK: 57, NG: 28, EQ: 31

# %%
# Save Resulst as CSV
dfResult = dfGameInfos.copy()

def PnScore(index, side):
    for res in res_ht_rt:
        if index == res[0]:
            return res[side]
    return -1

dfResult['pn_away'] = [PnScore(index, 2) for index in range(len(weeks))]
dfResult['pn_home'] = [PnScore(index, 1) for index in range(len(weeks))]


# Save as CSV
useful_methods.DFtoCSV(dfResult, paths.READ_PATH_GAME_INFO, 'Predict-Emolex-45min', index=False)
print("[Saved in]: %s" % (paths.READ_PATH_GAME_INFO + 'Predict-Emolex-45min.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/Predict-Emolex-45min.csv
