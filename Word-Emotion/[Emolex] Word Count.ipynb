# %%
# %pylab inline
# %matplotlib inline

import os
from time import time
import pandas as pd

# Local Imports
path = str(os.path.expanduser('~')) + '/git/predictEPL/config'
sys.path.append(path)
import paths

sys.path.append(paths.UTILS)
import emolex
import useful_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Data Loads & Defnings

# %%
# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')


# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]


# Read Emotion-Lexicon-Soccer as Dictionary
dic_emolex_soccer = emolex.EmolexSoccerDic()


# Limitations
time_limit = 60
retweet = True
start_time = 1
end_time = 60
# Out:
# [Emolex Dic's All Words]: 14136

# %% [markdown]
# ### Emolex Count Functions

# %%
# Summing counted emolex
def EmolexSumList(dfEmolex, start=1, end=60):
    # Time Interval
    dfEmolex.ith_minute = [int(ith_minute) for ith_minute in list(dfEmolex.ith_minute)]
    dfEmolex = dfEmolex[(dfEmolex.ith_minute >= start) & (dfEmolex.ith_minute <= end)]
    
    # Sum Emolex Count
    anger = dfEmolex.anger.sum()
    fear = dfEmolex.fear.sum()
    disgust = dfEmolex.disgust.sum()
    sadness = dfEmolex.sadness.sum()
    surprise = dfEmolex.surprise.sum()
    trust = dfEmolex.trust.sum()
    joy = dfEmolex.joy.sum()
    anticipation = dfEmolex.anticipation.sum()
    positive = dfEmolex.positive.sum()
    negative = dfEmolex.negative.sum()
    
    return {'anger': anger,
            'fear': fear,
            'disgust': disgust,
            'sadness': sadness,
            'surprise': surprise,
            'trust': trust,
            'joy': joy,
            'anticipation': anticipation,
            'positive': positive,
            'negative': negative}


# Count Home, Away Emolex
def CountGameEmolex(week, team_home, team_away):

    # Read Single as DF
    dfGame = useful_methods.SingleGameDf(week, team_home, team_away, filtering=True, retweet=retweet)
    if dfGame is None:
        return (None, None)

    dfGame.ith_minute = [int(ith_minute) for ith_minute in list(dfGame.ith_minute)]

    # Count Emolex Words
    dfEmolexHome = emolex.CreateEmolexDF(dfGame[(dfGame.side == 'home') & (dfGame.ith_minute <= time_limit)], dic_emolex_soccer)
    dfEmolexAway = emolex.CreateEmolexDF(dfGame[(dfGame.side == 'away') & (dfGame.ith_minute <= time_limit)], dic_emolex_soccer)

    # Sum Emolex
    dic_emolex_home = EmolexSumList(dfEmolexHome, start=start_time, end=end_time)
    dic_emolex_away = EmolexSumList(dfEmolexAway, start=start_time, end=end_time)

    return (dic_emolex_home, dic_emolex_away)

# %%
# Add Emolex Counted Columns
def CreateDfEmolexCounted(counted_game_emolex):
    pos_home = []
    neg_home = []
    pos_away = []
    neg_away = []
    
    emolex_home = []
    emolex_away = []

    for game_emolex in counted_game_emolex:
        home_emolex = game_emolex[0]
        away_emolex = game_emolex[1]

        if home_emolex and away_emolex:
            pos_home.append(home_emolex['positive'])
            pos_away.append(away_emolex['positive'])
            neg_home.append(home_emolex['negative'])
            neg_away.append(away_emolex['negative'])
            
            emolex_home.append([
                    home_emolex['anger'],
                    home_emolex['fear'],
                    home_emolex['disgust'],
                    home_emolex['sadness'],
                    home_emolex['surprise'],
                    home_emolex['trust'],
                    home_emolex['joy'],
                    home_emolex['anticipation'],
                ])
            
            emolex_away.append([
                    away_emolex['anger'],
                    away_emolex['fear'],
                    away_emolex['disgust'],
                    away_emolex['sadness'],
                    away_emolex['surprise'],
                    away_emolex['trust'],
                    away_emolex['joy'],
                    away_emolex['anticipation'],
                ])
            
        else:
            pos_home.append(0)
            pos_away.append(0)
            neg_home.append(0)
            neg_away.append(0)
            
            emolex_home.append([0])
            emolex_away.append([0])

    
    df = dfGameInfos.copy()
    df['pos_home'] = pos_home
    df['pos_away'] = pos_away
    df['neg_home'] = neg_home
    df['neg_away'] = neg_away
    
    df['emolex_home'] = emolex_home
    df['emolex_away'] = emolex_away
    
    return df

# %% [markdown]
# ### All Game Count Start

# %%
counted_game_emolex = []

for week in set(dfGameInfos.GW):
    for index in range((week - 1) * 10, week * 10):
        # Team names
        team_home = dfGameInfos[dfGameInfos.GW == week].loc[index]['home_team']
        team_away = dfGameInfos[dfGameInfos.GW == week].loc[index]['away_team']

        print("\n\n------------------")
        print(week, team_home, team_away)
        counted_game_emolex.append(CountGameEmolex(week, team_home, team_away))
# Out:
# ------------------
# 1 United Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Everton Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Leicester Sunderland
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Norwich Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Bournemouth Villa
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Chelsea Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Arsenal WestHam
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Newcastle Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Stoke Liverpool
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 WestBromwich City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Villa United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Southampton Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Tottenham Stoke
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 WestHam Leicester
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Watford WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Sunderland Norwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Swansea Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Crystal Arsenal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 City Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Liverpool Bournemouth
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 United Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Crystal Villa
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 WestHam Bournemouth
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Sunderland Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Norwich Stoke
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Leicester Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 WestBromwich Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Watford Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Everton City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Arsenal Liverpool
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Newcastle Arsenal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Stoke WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Liverpool WestHam
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Chelsea Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Villa Sunderland
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Bournemouth Leicester
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 City Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Tottenham Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Southampton Norwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Swansea United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 5 Everton Chelsea
#
#
# ------------------
# 5 Norwich Bournemouth
#
#
# ------------------
# 5 Watford Swansea
#
#
# ------------------
# 5 WestBromwich Southampton
#
#
# ------------------
# 5 Arsenal Stoke
#
#
# ------------------
# 5 Crystal City
#
#
# ------------------
# 5 United Liverpool
#
#
# ------------------
# 5 Sunderland Tottenham
#
#
# ------------------
# 5 Leicester Villa
#
#
# ------------------
# 5 WestHam Newcastle
#
#
# ------------------
# 6 Chelsea Arsenal
#
#
# ------------------
# 6 Swansea Everton
#
#
# ------------------
# 6 Bournemouth Sunderland
#
#
# ------------------
# 6 Villa WestBromwich
#
#
# ------------------
# 6 Newcastle Watford
#
#
# ------------------
# 6 Stoke Leicester
#
#
# ------------------
# 6 City WestHam
#
#
# ------------------
# 6 Tottenham Crystal
#
#
# ------------------
# 6 Southampton United
#
#
# ------------------
# 6 Liverpool Norwich
#
#
# ------------------
# 7 Tottenham City
#
#
# ------------------
# 7 Leicester Arsenal
#
#
# ------------------
# 7 Stoke Bournemouth
#
#
# ------------------
# 7 WestHam Norwich
#
#
# ------------------
# 7 Southampton Swansea
#
#
# ------------------
# 7 United Sunderland
#
#
# ------------------
# 7 Liverpool Villa
#
#
# ------------------
# 7 Newcastle Chelsea
#
#
# ------------------
# 7 Watford Crystal
#
#
# ------------------
# 7 WestBromwich Everton
#
#
# ------------------
# 8 Crystal WestBromwich
#
#
# ------------------
# 8 Norwich Leicester
#
#
# ------------------
# 8 Sunderland WestHam
#
#
# ------------------
# 8 City Newcastle
#
#
# ------------------
# 8 Villa Stoke
#
#
# ------------------
# 8 Bournemouth Watford
#
#
# ------------------
# 8 Chelsea Southampton
#
#
# ------------------
# 8 Everton Liverpool
#
#
# ------------------
# 8 Swansea Tottenham
#
#
# ------------------
# 8 Arsenal United
#
#
# ------------------
# 9 Tottenham Liverpool
#
#
# ------------------
# 9 Southampton Leicester
#
#
# ------------------
# 9 WestBromwich Sunderland
#
#
# ------------------
# 9 Chelsea Villa
#
#
# ------------------
# 9 Crystal WestHam
#
#
# ------------------
# 9 Everton United
#
#
# ------------------
# 9 City Bournemouth
#
#
# ------------------
# 9 Watford Arsenal
#
#
# ------------------
# 9 Newcastle Norwich
#
#
# ------------------
# 9 Swansea Stoke
#
#
# ------------------
# 10 Norwich WestBromwich
#
#
# ------------------
# 10 Leicester Crystal
#
#
# ------------------
# 10 Villa Swansea
#
#
# ------------------
# 10 WestHam Chelsea
#
#
# ------------------
# 10 Stoke Watford
#
#
# ------------------
# 10 Arsenal Everton
#
#
# ------------------
# 10 Sunderland Newcastle
#
#
# ------------------
# 10 United City
#
#
# ------------------
# 10 Bournemouth Tottenham
#
#
# ------------------
# 10 Liverpool Southampton
#
#
# ------------------
# 11 Chelsea Liverpool
#
#
# ------------------
# 11 Swansea Arsenal
#
#
# ------------------
# 11 WestBromwich Leicester
#
#
# ------------------
# 11 Watford WestHam
#
#
# ------------------
# 11 Newcastle Stoke
#
#
# ------------------
# 11 City Norwich
#
#
# ------------------
# 11 Crystal United
#
#
# ------------------
# 11 Everton Sunderland
#
#
# ------------------
# 11 Southampton Bournemouth
#
#
# ------------------
# 11 Tottenham Villa
#
#
# ------------------
# 12 Bournemouth Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Leicester Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Norwich Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 WestHam Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Sunderland Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 United WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Stoke Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Villa City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Liverpool Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Arsenal Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 13 Watford United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 13 Swansea Bournemouth
#
#
# ------------------
# 13 Chelsea Norwich
#
#
# ------------------
# 13 Everton Villa
#
#
# ------------------
# 13 WestBromwich Arsenal
#
#
# ------------------
# 13 Newcastle Leicester
#
#
# ------------------
# 13 Southampton Stoke
#
#
# ------------------
# 13 City Liverpool
#
#
# ------------------
# 13 Tottenham WestHam
#
#
# ------------------
# 13 Crystal Sunderland
#
#
# ------------------
# 14 Sunderland Stoke
#
#
# ------------------
# 14 Bournemouth Everton
#
#
# ------------------
# 14 Villa Watford
#
#
# ------------------
# 14 Crystal Newcastle
#
#
# ------------------
# 14 City Southampton
#
#
# ------------------
# 14 Leicester United
#
#
# ------------------
# 14 Tottenham Chelsea
#
#
# ------------------
# 14 WestHam WestBromwich
#
#
# ------------------
# 14 Liverpool Swansea
#
#
# ------------------
# 14 Norwich Arsenal
#
#
# ------------------
# 15 Stoke City
#
#
# ------------------
# 15 Arsenal Sunderland
#
#
# ------------------
# 15 WestBromwich Tottenham
#
#
# ------------------
# 15 Watford Norwich
#
#
# ------------------
# 15 United WestHam
#
#
# ------------------
# 15 Swansea Leicester
#
#
# ------------------
# 15 Southampton Villa
#
#
# ------------------
# 15 Chelsea Bournemouth
#
#
# ------------------
# 15 Newcastle Liverpool
#
#
# ------------------
# 15 Everton Crystal
#
#
# ------------------
# 16 Norwich Everton
#
#
# ------------------
# 16 WestHam Stoke
#
#
# ------------------
# 16 Sunderland Watford
#
#
# ------------------
# 16 City Swansea
#
#
# ------------------
# 16 Crystal Southampton
#
#
# ------------------
# 16 Bournemouth United
#
#
# ------------------
# 16 Villa Arsenal
#
#
# ------------------
# 16 Liverpool WestBromwich
#
#
# ------------------
# 16 Tottenham Newcastle
#
#
# ------------------
# 16 Leicester Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 17 Stoke Crystal
#
#
# ------------------
# 17 WestBromwich Bournemouth
#
#
# ------------------
# 17 Chelsea Sunderland
#
#
# ------------------
# 17 Everton Leicester
#
#
# ------------------
# 17 United Norwich
#
#
# ------------------
# 17 Southampton Tottenham
#
#
# ------------------
# 17 Newcastle Villa
#
#
# ------------------
# 17 Watford Liverpool
#
#
# ------------------
# 17 Swansea WestHam
#
#
# ------------------
# 17 Arsenal City
#
#
# ------------------
# 18 Stoke United
#
#
# ------------------
# 18 Tottenham Norwich
#
#
# ------------------
# 18 Swansea WestBromwich
#
#
# ------------------
# 18 City Sunderland
#
#
# ------------------
# 18 Liverpool Leicester
#
#
# ------------------
# 18 Chelsea Watford
#
#
# ------------------
# 18 Villa WestHam
#
#
# ------------------
# 18 Bournemouth Crystal
#
#
# ------------------
# 18 Newcastle Everton
#
#
# ------------------
# 18 Southampton Arsenal
#
#
# ------------------
# 19 Crystal Swansea
#
#
# ------------------
# 19 Everton Stoke
#
#
# ------------------
# 19 Norwich Villa
#
#
# ------------------
# 19 Watford Tottenham
#
#
# ------------------
# 19 WestBromwich Newcastle
#
#
# ------------------
# 19 WestHam Southampton
#
#
# ------------------
# 19 Arsenal Bournemouth
#
#
# ------------------
# 19 United Chelsea
#
#
# ------------------
# 19 Leicester City
#
#
# ------------------
# 19 Sunderland Liverpool
#
#
# ------------------
# 20 WestHam Liverpool
#
#
# ------------------
# 20 Arsenal Newcastle
#
#
# ------------------
# 20 WestBromwich Stoke
#
#
# ------------------
# 20 Sunderland Villa
#
#
# ------------------
# 20 Norwich Southampton
#
#
# ------------------
# 20 United Swansea
#
#
# ------------------
# 20 Leicester Bournemouth
#
#
# ------------------
# 20 Watford City
#
#
# ------------------
# 20 Crystal Chelsea
#
#
# ------------------
# 20 Everton Tottenham

# %% [markdown]
# ### Create DF and Save

# %%
# Create DF
df = CreateDfEmolexCounted(counted_game_emolex)
df = df[df.pos_home != 0].copy()
df
# Out:
#      GW     away_team           date     home_team  score_ft_away  \
# 40    5       Chelsea  Sat. 12 Sep.        Everton              1
# 41    5   Bournemouth  Sat. 12 Sep.        Norwich              1
# 42    5       Swansea  Sat. 12 Sep.        Watford              0
# 43    5   Southampton  Sat. 12 Sep.   WestBromwich              0
# 44    5         Stoke  Sat. 12 Sep.        Arsenal              0
# 45    5          City  Sat. 12 Sep.        Crystal              1
# 46    5     Liverpool  Sat. 12 Sep.         United              1
# 47    5     Tottenham  Sun. 13 Sep.     Sunderland              1
# 48    5         Villa  Sun. 13 Sep.      Leicester              2
# 49    5     Newcastle  Mon. 14 Sep.        WestHam              0
# 50    6       Arsenal  Sat. 19 Sep.        Chelsea              0
# 51    6       Everton  Sat. 19 Sep.        Swansea              0
# 52    6    Sunderland  Sat. 19 Sep.    Bournemouth              0
# 53    6  WestBromwich  Sat. 19 Sep.          Villa              1
# 54    6       Watford  Sat. 19 Sep.      Newcastle              2
# 55    6     Leicester  Sat. 19 Sep.          Stoke              2
# 56    6       WestHam  Sat. 19 Sep.           City              2
# 57    6       Crystal  Sun. 20 Sep.      Tottenham              0
# 58    6        United  Sun. 20 Sep.    Southampton              3
# 59    6       Norwich  Sun. 20 Sep.      Liverpool              1
# 60    7          City  Sat. 26 Sep.      Tottenham              1
# 61    7       Arsenal  Sat. 26 Sep.      Leicester              5
# 62    7   Bournemouth  Sat. 26 Sep.          Stoke              1
# 63    7       Norwich  Sat. 26 Sep.        WestHam              2
# 64    7       Swansea  Sat. 26 Sep.    Southampton              1
# 65    7    Sunderland  Sat. 26 Sep.         United              0
# 66    7         Villa  Sat. 26 Sep.      Liverpool              2
# 67    7       Chelsea  Sat. 26 Sep.      Newcastle              2
# 69    7       Everton  Mon. 28 Sep.   WestBromwich              3
# 70    8  WestBromwich   Sat. 3 Oct.        Crystal              0
# ..   ..           ...            ...           ...            ...
# 170  18        United  Sat. 26 Dec.          Stoke              0
# 171  18       Norwich  Sat. 26 Dec.      Tottenham              0
# 172  18  WestBromwich  Sat. 26 Dec.        Swansea              0
# 173  18    Sunderland  Sat. 26 Dec.           City              1
# 174  18     Leicester  Sat. 26 Dec.      Liverpool              0
# 175  18       Watford  Sat. 26 Dec.        Chelsea              2
# 176  18       WestHam  Sat. 26 Dec.          Villa              1
# 177  18       Crystal  Sat. 26 Dec.    Bournemouth              0
# 178  18       Everton  Sat. 26 Dec.      Newcastle              1
# 179  18       Arsenal  Sat. 26 Dec.    Southampton              0
# 180  19       Swansea  Mon. 28 Dec.        Crystal              0
# 181  19         Stoke  Mon. 28 Dec.        Everton              4
# 182  19         Villa  Mon. 28 Dec.        Norwich              0
# 183  19     Tottenham  Mon. 28 Dec.        Watford              2
# 184  19     Newcastle  Mon. 28 Dec.   WestBromwich              0
# 185  19   Southampton  Mon. 28 Dec.        WestHam              1
# 186  19   Bournemouth  Mon. 28 Dec.        Arsenal              0
# 187  19       Chelsea  Mon. 28 Dec.         United              0
# 188  19          City  Tue. 29 Dec.      Leicester              0
# 189  19     Liverpool  Wed. 30 Dec.     Sunderland              1
# 190  20     Liverpool   Sat. 2 Jan.        WestHam              0
# 191  20     Newcastle   Sat. 2 Jan.        Arsenal              0
# 192  20         Stoke   Sat. 2 Jan.   WestBromwich              1
# 193  20         Villa   Sat. 2 Jan.     Sunderland              1
# 194  20   Southampton   Sat. 2 Jan.        Norwich              0
# 195  20       Swansea   Sat. 2 Jan.         United              1
# 196  20   Bournemouth   Sat. 2 Jan.      Leicester              0
# 197  20          City   Sat. 2 Jan.        Watford              2
# 198  20       Chelsea   Sun. 3 Jan.        Crystal              3
# 199  20     Tottenham   Sun. 3 Jan.        Everton              1
#
#      score_ft_home  score_ht_away  score_ht_home   time  pos_home  pos_away  \
# 40               3              1              2  11:45      1009      3901
# 41               3              0              1  14:00       331       112
# 42               1              0              0  14:00        98        78
# 43               0              0              0  14:00       116       154
# 44               2              0              1  14:00      2529       255
# 45               0              0              0  14:00       299       975
# 46               3              0              0  16:30     11807      4881
# 47               0              0              0  12:30       498      1117
# 48               3              1              0  15:00       276      1550
# 49               2              0              1  19:00       655      1560
# 50               2              0              0  11:45      3493      1927
# 51               0              0              0  14:00        65       195
# 52               2              0              2  14:00       743       555
# 53               0              1              0  14:00       342       245
# 54               1              2              0  14:00      1508       648
# 55               2              0              2  14:00       183       285
# 56               1              2              1  16:30      1485      1310
# 57               1              0              0  12:30      1228        22
# 58               2              1              1  15:00       646     12191
# 59               1              0              0  15:00      3980       232
# 60               4              1              1  11:45      1743      2683
# 61               2              2              1  14:00       257      1793
# 62               2              0              1  14:00        53       211
# 63               2              1              1  14:00       352       311
# 64               3              0              1  14:00       225        63
# 65               3              0              1  14:00     11865       238
# 66               3              0              1  14:00      3908       433
# 67               2              0              1  16:30      2086      1926
# 69               2              0              1  19:00       347       406
# 70               2              0              0  11:45       259       356
# ..             ...            ...            ...    ...       ...       ...
# 170              2              0              2  12:45      1475     15155
# 171              3              0              2  15:00      2016       278
# 172              1              0              1  15:00        88       211
# 173              4              0              3  15:00      2928       389
# 174              1              0              0  15:00      4619       305
# 175              2              1              1  15:00      1037       209
# 176              1              1              0  15:00       426       281
# 177              0              0              0  15:00        73       108
# 178              0              0              0  17:30       757       413
# 179              4              0              1  19:45      1224      2705
# 180              0              0              0  15:00       128        86
# 181              3              2              1  15:00       312       300
# 182              2              0              1  15:00       196       653
# 183              1              1              1  15:00       436      1531
# 184              1              0              0  15:00       265       656
# 185              2              1              0  17:30       233       319
# 186              2              0              1  17:30      3284       130
# 187              0              0              0  17:30     13114      2379
# 188              0              0              0  19:45       915      1573
# 189              0              0              0  19:45       494      2995
# 190              2              0              1  12:45       782      4753
# 191              1              0              0  15:00      1342      1237
# 192              2              0              0  15:00       139        44
# 193              3              0              1  15:00       372       906
# 194              1              0              0  15:00       161       343
# 195              2              0              0  15:00      7515       146
# 196              0              0              0  15:00       315       152
# 197              1              0              0  17:30       193      1779
# 198              0              1              0  13:30       421      3410
# 199              1              1              1  16:00      1009      3085
#
#      neg_home  neg_away                                        emolex_home  \
# 40        647      3699  [405.0, 287.0, 192.0, 322.0, 291.0, 484.0, 530...
# 41        100        53  [67.0, 64.0, 22.0, 54.0, 122.0, 194.0, 122.0, ...
# 42         55        36   [38.0, 22.0, 18.0, 20.0, 57.0, 66.0, 52.0, 58.0]
# 43        116        62   [56.0, 30.0, 38.0, 32.0, 43.0, 80.0, 48.0, 94.0]
# 44        938       113  [603.0, 445.0, 421.0, 432.0, 1039.0, 1681.0, 1...
# 45        225      1708  [146.0, 113.0, 60.0, 80.0, 100.0, 190.0, 145.0...
# 46       9999      4464  [5228.0, 3026.0, 2403.0, 2447.0, 2705.0, 7167....
# 47        330       815  [158.0, 152.0, 87.0, 120.0, 205.0, 329.0, 218....
# 48        163       480  [70.0, 75.0, 74.0, 65.0, 99.0, 122.0, 99.0, 10...
# 49        202      1563  [96.0, 92.0, 64.0, 68.0, 147.0, 401.0, 297.0, ...
# 50       2705      2767  [1272.0, 1071.0, 1371.0, 1003.0, 924.0, 1707.0...
# 51         33       176     [16.0, 7.0, 11.0, 7.0, 43.0, 39.0, 44.0, 44.0]
# 52        136       640  [79.0, 66.0, 43.0, 42.0, 42.0, 389.0, 105.0, 2...
# 53        394       160  [170.0, 171.0, 122.0, 156.0, 72.0, 185.0, 143....
# 54       1978        84  [847.0, 796.0, 792.0, 899.0, 500.0, 752.0, 562...
# 55         56       169    [46.0, 51.0, 7.0, 32.0, 32.0, 89.0, 94.0, 78.0]
# 56       1412       510  [676.0, 838.0, 239.0, 797.0, 689.0, 702.0, 657...
# 57        474         8  [251.0, 237.0, 119.0, 174.0, 346.0, 563.0, 596...
# 58        176      8295  [84.0, 87.0, 49.0, 70.0, 267.0, 339.0, 336.0, ...
# 59       2079       116  [804.0, 831.0, 855.0, 747.0, 1598.0, 1998.0, 1...
# 60       1016      1549  [636.0, 619.0, 205.0, 362.0, 352.0, 831.0, 952...
# 61        137      1549  [72.0, 51.0, 60.0, 57.0, 65.0, 112.0, 92.0, 10...
# 62         42       330   [29.0, 29.0, 10.0, 22.0, 19.0, 30.0, 17.0, 24.0]
# 63        167       160  [94.0, 64.0, 38.0, 82.0, 49.0, 214.0, 69.0, 96.0]
# 64         72        23  [34.0, 27.0, 22.0, 23.0, 152.0, 147.0, 164.0, ...
# 65       5636       164  [2618.0, 1429.0, 1409.0, 1259.0, 4046.0, 5408....
# 66       1415       475  [882.0, 547.0, 267.0, 568.0, 1201.0, 1298.0, 1...
# 67        762      2036  [448.0, 403.0, 245.0, 241.0, 540.0, 1058.0, 98...
# 69        199       402  [96.0, 80.0, 55.0, 76.0, 111.0, 175.0, 169.0, ...
# 70        247       641  [124.0, 98.0, 73.0, 95.0, 74.0, 139.0, 121.0, ...
# ..        ...       ...                                                ...
# 170       430     18727  [334.0, 133.0, 191.0, 144.0, 836.0, 344.0, 393...
# 171      2038       326  [1703.0, 495.0, 95.0, 1380.0, 578.0, 889.0, 11...
# 172        33       355    [19.0, 21.0, 10.0, 8.0, 19.0, 37.0, 37.0, 29.0]
# 173       904       464  [904.0, 336.0, 287.0, 647.0, 508.0, 3054.0, 12...
# 174      3192       150  [1694.0, 1809.0, 744.0, 1518.0, 1467.0, 2764.0...
# 175      1087       142  [536.0, 321.0, 282.0, 535.0, 428.0, 624.0, 537...
# 176       464       184  [152.0, 151.0, 104.0, 172.0, 118.0, 251.0, 136...
# 177        59       103   [37.0, 30.0, 16.0, 21.0, 38.0, 52.0, 40.0, 34.0]
# 178       787       249  [491.0, 416.0, 310.0, 371.0, 289.0, 427.0, 406...
# 179       701      2279  [211.0, 214.0, 117.0, 348.0, 198.0, 256.0, 838...
# 180       182        74  [108.0, 96.0, 85.0, 37.0, 22.0, 67.0, 30.0, 49.0]
# 181       281       160  [99.0, 84.0, 69.0, 75.0, 57.0, 188.0, 116.0, 1...
# 182       116       816  [47.0, 44.0, 30.0, 50.0, 49.0, 132.0, 66.0, 89.0]
# 183       193       513  [113.0, 103.0, 25.0, 88.0, 112.0, 328.0, 132.0...
# 184       178       860  [83.0, 91.0, 25.0, 85.0, 95.0, 97.0, 134.0, 90.0]
# 185       223       136  [118.0, 90.0, 47.0, 80.0, 74.0, 139.0, 86.0, 1...
# 186      1341       131  [584.0, 614.0, 466.0, 835.0, 1120.0, 2487.0, 8...
# 187     10007      2082  [4958.0, 4255.0, 3734.0, 3652.0, 3536.0, 8618....
# 188       348      1073  [153.0, 109.0, 72.0, 143.0, 155.0, 366.0, 463....
# 189       263      2026  [130.0, 183.0, 82.0, 118.0, 112.0, 315.0, 260....
# 190       544      5440  [342.0, 291.0, 161.0, 297.0, 270.0, 439.0, 361...
# 191      1864       832  [663.0, 631.0, 544.0, 810.0, 607.0, 958.0, 618...
# 192        92        39   [40.0, 54.0, 24.0, 38.0, 20.0, 83.0, 49.0, 46.0]
# 193       223       857  [98.0, 118.0, 79.0, 102.0, 159.0, 193.0, 193.0...
# 194        97       191   [36.0, 34.0, 24.0, 45.0, 63.0, 94.0, 68.0, 82.0]
# 195      7543        90  [2830.0, 2974.0, 2299.0, 2598.0, 3033.0, 3575....
# 196       105        61  [64.0, 81.0, 271.0, 258.0, 107.0, 186.0, 73.0,...
# 197       115       810  [47.0, 58.0, 29.0, 38.0, 99.0, 113.0, 101.0, 1...
# 198       378      2808  [228.0, 188.0, 123.0, 153.0, 110.0, 212.0, 196...
# 199       665      1595  [317.0, 257.0, 197.0, 233.0, 265.0, 582.0, 444...
#
#                                            emolex_away
# 40   [1732.0, 1670.0, 1436.0, 1569.0, 1079.0, 2217....
# 41    [36.0, 36.0, 25.0, 22.0, 27.0, 50.0, 37.0, 37.0]
# 42    [24.0, 23.0, 10.0, 20.0, 22.0, 51.0, 33.0, 46.0]
# 43    [23.0, 28.0, 17.0, 23.0, 75.0, 65.0, 68.0, 67.0]
# 44   [82.0, 59.0, 40.0, 47.0, 75.0, 130.0, 107.0, 8...
# 45   [1029.0, 1358.0, 538.0, 805.0, 441.0, 378.0, 3...
# 46   [1743.0, 1955.0, 1644.0, 1838.0, 1207.0, 2875....
# 47   [379.0, 365.0, 248.0, 315.0, 297.0, 511.0, 421...
# 48   [195.0, 233.0, 203.0, 191.0, 384.0, 725.0, 881...
# 49   [589.0, 697.0, 473.0, 643.0, 418.0, 919.0, 574...
# 50   [1466.0, 999.0, 1449.0, 1072.0, 649.0, 1182.0,...
# 51   [68.0, 57.0, 50.0, 57.0, 71.0, 112.0, 117.0, 1...
# 52   [309.0, 265.0, 263.0, 266.0, 166.0, 278.0, 235...
# 53   [106.0, 50.0, 55.0, 52.0, 81.0, 127.0, 131.0, ...
# 54   [45.0, 38.0, 14.0, 29.0, 48.0, 422.0, 114.0, 3...
# 55   [68.0, 94.0, 53.0, 83.0, 75.0, 116.0, 104.0, 1...
# 56   [257.0, 299.0, 158.0, 213.0, 257.0, 563.0, 549...
# 57         [7.0, 4.0, 3.0, 6.0, 8.0, 11.0, 13.0, 13.0]
# 58   [5618.0, 3971.0, 2348.0, 4808.0, 2367.0, 4454....
# 59   [38.0, 45.0, 32.0, 48.0, 66.0, 128.0, 111.0, 1...
# 60   [418.0, 687.0, 201.0, 883.0, 748.0, 1444.0, 13...
# 61   [535.0, 868.0, 435.0, 870.0, 507.0, 1083.0, 76...
# 62   [207.0, 255.0, 90.0, 259.0, 60.0, 108.0, 101.0...
# 63   [60.0, 72.0, 42.0, 83.0, 82.0, 175.0, 118.0, 1...
# 64       [12.0, 4.0, 3.0, 8.0, 23.0, 21.0, 22.0, 18.0]
# 65   [88.0, 71.0, 47.0, 73.0, 63.0, 131.0, 94.0, 11...
# 66   [173.0, 165.0, 145.0, 191.0, 114.0, 184.0, 174...
# 67   [875.0, 804.0, 638.0, 834.0, 613.0, 991.0, 819...
# 69   [151.0, 145.0, 130.0, 179.0, 118.0, 149.0, 130...
# 70   [316.0, 301.0, 172.0, 246.0, 116.0, 193.0, 155...
# ..                                                 ...
# 170  [8328.0, 6917.0, 7213.0, 7755.0, 4585.0, 8006....
# 171  [245.0, 104.0, 63.0, 205.0, 94.0, 148.0, 120.0...
# 172  [132.0, 114.0, 70.0, 202.0, 51.0, 89.0, 68.0, ...
# 173  [223.0, 178.0, 193.0, 190.0, 142.0, 191.0, 162...
# 174  [82.0, 70.0, 24.0, 60.0, 100.0, 152.0, 150.0, ...
# 175  [44.0, 46.0, 24.0, 76.0, 82.0, 123.0, 96.0, 14...
# 176  [113.0, 95.0, 42.0, 69.0, 84.0, 111.0, 143.0, ...
# 177   [70.0, 53.0, 38.0, 37.0, 50.0, 52.0, 51.0, 59.0]
# 178  [133.0, 113.0, 83.0, 85.0, 120.0, 223.0, 139.0...
# 179  [1380.0, 1066.0, 1042.0, 1164.0, 1079.0, 1759....
# 180   [21.0, 44.0, 53.0, 18.0, 40.0, 46.0, 30.0, 29.0]
# 181  [79.0, 52.0, 64.0, 56.0, 67.0, 161.0, 151.0, 1...
# 182  [364.0, 361.0, 305.0, 358.0, 197.0, 272.0, 211...
# 183  [239.0, 243.0, 132.0, 249.0, 255.0, 490.0, 437...
# 184  [409.0, 380.0, 253.0, 412.0, 248.0, 389.0, 329...
# 185  [56.0, 67.0, 28.0, 45.0, 108.0, 193.0, 153.0, ...
# 186   [82.0, 37.0, 22.0, 40.0, 29.0, 64.0, 46.0, 68.0]
# 187  [1675.0, 822.0, 806.0, 1007.0, 902.0, 1214.0, ...
# 188  [331.0, 591.0, 198.0, 335.0, 1004.0, 718.0, 59...
# 189  [762.0, 1052.0, 823.0, 700.0, 636.0, 1648.0, 9...
# 190  [2738.0, 2358.0, 1811.0, 2024.0, 1852.0, 2938....
# 191  [525.0, 492.0, 297.0, 335.0, 496.0, 667.0, 647...
# 192     [11.0, 15.0, 9.0, 9.0, 26.0, 24.0, 19.0, 22.0]
# 193  [386.0, 304.0, 340.0, 323.0, 248.0, 494.0, 400...
# 194  [59.0, 64.0, 33.0, 118.0, 239.0, 109.0, 251.0,...
# 195   [51.0, 64.0, 37.0, 26.0, 30.0, 59.0, 37.0, 46.0]
# 196   [33.0, 34.0, 18.0, 35.0, 63.0, 78.0, 60.0, 77.0]
# 197  [332.0, 356.0, 170.0, 307.0, 337.0, 972.0, 618...
# 198  [1257.0, 1373.0, 1323.0, 669.0, 1004.0, 1873.0...
# 199  [762.0, 596.0, 439.0, 748.0, 768.0, 1478.0, 14...
#
# [147 rows x 15 columns]

# %%
# Save as CSV
useful_methods.DFtoCSV(df, paths.DATA_HOME + "EPL/", 'all_game_emolex_counted', index=False)
print("[Saved in]: %s" % (paths.DATA_HOME + "EPL/" + 'all_game_emolex_counted.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/all_game_emolex_counted.csv
