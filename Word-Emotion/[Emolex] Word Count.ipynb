# %%
# %pylab inline
# %matplotlib inline

import os
from time import time
import pandas as pd

# Local Imports
path = str(os.path.expanduser('~')) + '/git/predictEPL/config'
sys.path.append(path)
import paths

sys.path.append(paths.UTILS)
import emolex
import useful_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Data Loads & Defnings

# %%
# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')


# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]


# Read Emotion-Lexicon-Soccer as Dictionary
dic_emolex_soccer = emolex.EmolexSoccerDic()


# Limitations
TIME_LIMIT = 60
RETWEET_STATUS = False
FILTER_STATUS = True
START_TIME = 1
END_TIME = 60
# Out:
# [Emolex Dic's All Words]: 14136

# %% [markdown]
# ### Emolex Count Functions

# %%
# Summing counted emolex
def EmolexSumList(dfEmolex, start=1, end=60):
    # Time Interval
    dfEmolex.ith_minute = [int(ith_minute) for ith_minute in list(dfEmolex.ith_minute)]
    dfEmolex = dfEmolex[(dfEmolex.ith_minute >= start) & (dfEmolex.ith_minute <= end)]
    
    # Sum Emolex Count
    anger = dfEmolex.anger.sum()
    fear = dfEmolex.fear.sum()
    disgust = dfEmolex.disgust.sum()
    sadness = dfEmolex.sadness.sum()
    surprise = dfEmolex.surprise.sum()
    trust = dfEmolex.trust.sum()
    joy = dfEmolex.joy.sum()
    anticipation = dfEmolex.anticipation.sum()
    positive = dfEmolex.positive.sum()
    negative = dfEmolex.negative.sum()
    
    return {'anger': anger,
            'fear': fear,
            'disgust': disgust,
            'sadness': sadness,
            'surprise': surprise,
            'trust': trust,
            'joy': joy,
            'anticipation': anticipation,
            'positive': positive,
            'negative': negative}


# Count Home, Away Emolex
def CountGameEmolex(week, team_home, team_away):

    # Read Single as DF
    dfGame = useful_methods.SingleGameDf(week, team_home, team_away, filtering=FILTER_STATUS, retweet=RETWEET_STATUS)
    if dfGame is None:
        return (None, None)

    dfGame.ith_minute = [int(ith_minute) for ith_minute in list(dfGame.ith_minute)]

    # Count Emolex Words
    dfEmolexHome = emolex.CreateEmolexDF(dfGame[(dfGame.side == 'home') & (dfGame.ith_minute <= TIME_LIMIT)], dic_emolex_soccer)
    dfEmolexAway = emolex.CreateEmolexDF(dfGame[(dfGame.side == 'away') & (dfGame.ith_minute <= TIME_LIMIT)], dic_emolex_soccer)

    # Sum Emolex
    dic_emolex_home = EmolexSumList(dfEmolexHome, start=START_TIME, end=END_TIME)
    dic_emolex_away = EmolexSumList(dfEmolexAway, start=START_TIME, end=END_TIME)

    return (dic_emolex_home, dic_emolex_away)

# %%
# Add Emolex Counted Columns
def CreateDfEmolexCounted(counted_game_emolex):
    pn_home = []
    pn_away = []
    
    emolex_home = []
    emolex_away = []

    for game_emolex in counted_game_emolex:
        home_emolex = game_emolex[0]
        away_emolex = game_emolex[1]

        if home_emolex and away_emolex:
            pn_home.append([
                    home_emolex['positive'],
                    home_emolex['negative']
                ])
            
            pn_away.append([
                    away_emolex['positive'],
                    away_emolex['negative']
                ])

            emolex_home.append([
                    home_emolex['anger'],
                    home_emolex['fear'],
                    home_emolex['disgust'],
                    home_emolex['sadness'],
                    home_emolex['surprise'],
                    home_emolex['trust'],
                    home_emolex['joy'],
                    home_emolex['anticipation'],
                ])
            
            emolex_away.append([
                    away_emolex['anger'],
                    away_emolex['fear'],
                    away_emolex['disgust'],
                    away_emolex['sadness'],
                    away_emolex['surprise'],
                    away_emolex['trust'],
                    away_emolex['joy'],
                    away_emolex['anticipation'],
                ])
            
        else:
            pn_home.append(0)
            pn_away.append(0)
            
            emolex_home.append([0])
            emolex_away.append([0])

    
    df = dfGameInfos.copy()
    df['pn_home'] = pn_home
    df['pn_away'] = pn_away
    
    df['emolex_home'] = emolex_home
    df['emolex_away'] = emolex_away
    
    return df

# %% [markdown]
# ### All Game Count Start

# %%
taken_time = time()

counted_game_emolex = []

for week in set(dfGameInfos.GW):
    for index in range((week - 1) * 10, week * 10):
        # Team names
        team_home = dfGameInfos[dfGameInfos.GW == week].loc[index]['home_team']
        team_away = dfGameInfos[dfGameInfos.GW == week].loc[index]['away_team']

        print("\n\n------------------")
        print(week, team_home, team_away)
        counted_game_emolex.append(CountGameEmolex(week, team_home, team_away))

print("[Done:] %.2f" % (time() - taken_time))
# Out:
# ------------------
# 1 United Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Everton Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Leicester Sunderland
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Norwich Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Bournemouth Villa
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Chelsea Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Arsenal WestHam
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Newcastle Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Stoke Liverpool
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 WestBromwich City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Villa United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Southampton Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Tottenham Stoke
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 WestHam Leicester
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Watford WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Sunderland Norwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Swansea Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Crystal Arsenal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 City Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Liverpool Bournemouth
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 United Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Crystal Villa
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 WestHam Bournemouth
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Sunderland Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Norwich Stoke
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Leicester Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 WestBromwich Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Watford Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Everton City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Arsenal Liverpool
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Newcastle Arsenal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Stoke WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Liverpool WestHam
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Chelsea Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Villa Sunderland
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Bournemouth Leicester
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 City Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Tottenham Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Southampton Norwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Swansea United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 5 Everton Chelsea
#
#
# ------------------
# 5 Norwich Bournemouth
#
#
# ------------------
# 5 Watford Swansea
#
#
# ------------------
# 5 WestBromwich Southampton
#
#
# ------------------
# 5 Arsenal Stoke
#
#
# ------------------
# 5 Crystal City
#
#
# ------------------
# 5 United Liverpool
#
#
# ------------------
# 5 Sunderland Tottenham
#
#
# ------------------
# 5 Leicester Villa
#
#
# ------------------
# 5 WestHam Newcastle
#
#
# ------------------
# 6 Chelsea Arsenal
#
#
# ------------------
# 6 Swansea Everton
#
#
# ------------------
# 6 Bournemouth Sunderland
#
#
# ------------------
# 6 Villa WestBromwich
#
#
# ------------------
# 6 Newcastle Watford
#
#
# ------------------
# 6 Stoke Leicester
#
#
# ------------------
# 6 City WestHam
#
#
# ------------------
# 6 Tottenham Crystal
#
#
# ------------------
# 6 Southampton United
#
#
# ------------------
# 6 Liverpool Norwich
#
#
# ------------------
# 7 Tottenham City
#
#
# ------------------
# 7 Leicester Arsenal
#
#
# ------------------
# 7 Stoke Bournemouth
#
#
# ------------------
# 7 WestHam Norwich
#
#
# ------------------
# 7 Southampton Swansea
#
#
# ------------------
# 7 United Sunderland
#
#
# ------------------
# 7 Liverpool Villa
#
#
# ------------------
# 7 Newcastle Chelsea
#
#
# ------------------
# 7 Watford Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 7 WestBromwich Everton
#
#
# ------------------
# 8 Crystal WestBromwich
#
#
# ------------------
# 8 Norwich Leicester
#
#
# ------------------
# 8 Sunderland WestHam
#
#
# ------------------
# 8 City Newcastle
#
#
# ------------------
# 8 Villa Stoke
#
#
# ------------------
# 8 Bournemouth Watford
#
#
# ------------------
# 8 Chelsea Southampton
#
#
# ------------------
# 8 Everton Liverpool
#
#
# ------------------
# 8 Swansea Tottenham
#
#
# ------------------
# 8 Arsenal United
#
#
# ------------------
# 9 Tottenham Liverpool
#
#
# ------------------
# 9 Southampton Leicester
#
#
# ------------------
# 9 WestBromwich Sunderland
#
#
# ------------------
# 9 Chelsea Villa
#
#
# ------------------
# 9 Crystal WestHam
#
#
# ------------------
# 9 Everton United
#
#
# ------------------
# 9 City Bournemouth
#
#
# ------------------
# 9 Watford Arsenal
#
#
# ------------------
# 9 Newcastle Norwich
#
#
# ------------------
# 9 Swansea Stoke
#
#
# ------------------
# 10 Norwich WestBromwich
#
#
# ------------------
# 10 Leicester Crystal
#
#
# ------------------
# 10 Villa Swansea
#
#
# ------------------
# 10 WestHam Chelsea
#
#
# ------------------
# 10 Stoke Watford
#
#
# ------------------
# 10 Arsenal Everton
#
#
# ------------------
# 10 Sunderland Newcastle
#
#
# ------------------
# 10 United City
#
#
# ------------------
# 10 Bournemouth Tottenham
#
#
# ------------------
# 10 Liverpool Southampton
#
#
# ------------------
# 11 Chelsea Liverpool
#
#
# ------------------
# 11 Swansea Arsenal
#
#
# ------------------
# 11 WestBromwich Leicester
#
#
# ------------------
# 11 Watford WestHam
#
#
# ------------------
# 11 Newcastle Stoke
#
#
# ------------------
# 11 City Norwich
#
#
# ------------------
# 11 Crystal United
#
#
# ------------------
# 11 Everton Sunderland
#
#
# ------------------
# 11 Southampton Bournemouth
#
#
# ------------------
# 11 Tottenham Villa
#
#
# ------------------
# 12 Bournemouth Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Leicester Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Norwich Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 WestHam Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Sunderland Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 United WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Stoke Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Villa City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Liverpool Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Arsenal Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 13 Watford United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 13 Swansea Bournemouth
#
#
# ------------------
# 13 Chelsea Norwich
#
#
# ------------------
# 13 Everton Villa
#
#
# ------------------
# 13 WestBromwich Arsenal
#
#
# ------------------
# 13 Newcastle Leicester
#
#
# ------------------
# 13 Southampton Stoke
#
#
# ------------------
# 13 City Liverpool
#
#
# ------------------
# 13 Tottenham WestHam
#
#
# ------------------
# 13 Crystal Sunderland
#
#
# ------------------
# 14 Sunderland Stoke
#
#
# ------------------
# 14 Bournemouth Everton
#
#
# ------------------
# 14 Villa Watford
#
#
# ------------------
# 14 Crystal Newcastle
#
#
# ------------------
# 14 City Southampton
#
#
# ------------------
# 14 Leicester United
#
#
# ------------------
# 14 Tottenham Chelsea
#
#
# ------------------
# 14 WestHam WestBromwich
#
#
# ------------------
# 14 Liverpool Swansea
#
#
# ------------------
# 14 Norwich Arsenal
#
#
# ------------------
# 15 Stoke City
#
#
# ------------------
# 15 Arsenal Sunderland
#
#
# ------------------
# 15 WestBromwich Tottenham
#
#
# ------------------
# 15 Watford Norwich
#
#
# ------------------
# 15 United WestHam
#
#
# ------------------
# 15 Swansea Leicester
#
#
# ------------------
# 15 Southampton Villa
#
#
# ------------------
# 15 Chelsea Bournemouth
#
#
# ------------------
# 15 Newcastle Liverpool
#
#
# ------------------
# 15 Everton Crystal
#
#
# ------------------
# 16 Norwich Everton
#
#
# ------------------
# 16 WestHam Stoke
#
#
# ------------------
# 16 Sunderland Watford
#
#
# ------------------
# 16 City Swansea
#
#
# ------------------
# 16 Crystal Southampton
#
#
# ------------------
# 16 Bournemouth United
#
#
# ------------------
# 16 Villa Arsenal
#
#
# ------------------
# 16 Liverpool WestBromwich
#
#
# ------------------
# 16 Tottenham Newcastle
#
#
# ------------------
# 16 Leicester Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 17 Stoke Crystal
#
#
# ------------------
# 17 WestBromwich Bournemouth
#
#
# ------------------
# 17 Chelsea Sunderland
#
#
# ------------------
# 17 Everton Leicester
#
#
# ------------------
# 17 United Norwich
#
#
# ------------------
# 17 Southampton Tottenham
#
#
# ------------------
# 17 Newcastle Villa
#
#
# ------------------
# 17 Watford Liverpool
#
#
# ------------------
# 17 Swansea WestHam
#
#
# ------------------
# 17 Arsenal City
#
#
# ------------------
# 18 Stoke United
#
#
# ------------------
# 18 Tottenham Norwich
#
#
# ------------------
# 18 Swansea WestBromwich
#
#
# ------------------
# 18 City Sunderland
#
#
# ------------------
# 18 Liverpool Leicester
#
#
# ------------------
# 18 Chelsea Watford
#
#
# ------------------
# 18 Villa WestHam
#
#
# ------------------
# 18 Bournemouth Crystal
#
#
# ------------------
# 18 Newcastle Everton
#
#
# ------------------
# 18 Southampton Arsenal
#
#
# ------------------
# 19 Crystal Swansea
#
#
# ------------------
# 19 Everton Stoke
#
#
# ------------------
# 19 Norwich Villa
#
#
# ------------------
# 19 Watford Tottenham
#
#
# ------------------
# 19 WestBromwich Newcastle
#
#
# ------------------
# 19 WestHam Southampton
#
#
# ------------------
# 19 Arsenal Bournemouth
#
#
# ------------------
# 19 United Chelsea
#
#
# ------------------
# 19 Leicester City
#
#
# ------------------
# 19 Sunderland Liverpool
#
#
# ------------------
# 20 WestHam Liverpool
#
#
# ------------------
# 20 Arsenal Newcastle
#
#
# ------------------
# 20 WestBromwich Stoke
#
#
# ------------------
# 20 Sunderland Villa
#
#
# ------------------
# 20 Norwich Southampton
#
#
# ------------------
# 20 United Swansea
#
#
# ------------------
# 20 Leicester Bournemouth
#
#
# ------------------
# 20 Watford City
#
#
# ------------------
# 20 Crystal Chelsea
#
#
# ------------------
# 20 Everton Tottenham
#
#
# ------------------
# 21 Villa Crystal
#
#
# ------------------
# 21 Newcastle United
#
#
# ------------------
# 21 Bournemouth WestHam
#
#
# ------------------
# 21 Stoke Norwich
#
#
# ------------------
# 21 Southampton Watford
#
#
# ------------------
# 21 City Everton
#
#
# ------------------
# 21 Chelsea WestBromwich
#
#
# ------------------
# 21 Swansea Sunderland
#
#
# ------------------
# 21 Tottenham Leicester
#
#
# ------------------
# 21 Liverpool Arsenal
#
#
# ------------------
# 22 Tottenham Sunderland
#
#
# ------------------
# 22 Newcastle WestHam
#
#
# ------------------
# 22 Bournemouth Norwich
#
#
# ------------------
# 22 Chelsea Everton
#
#
# ------------------
# 22 Southampton WestBromwich
#
#
# ------------------
# 22 City Crystal
#
#
# ------------------
# 22 Villa Leicester
#
#
# ------------------
# 22 Liverpool United
#
#
# ------------------
# 22 Stoke Arsenal
#
#
# ------------------
# 22 Swansea Watford
# [Done:] 697.80

# %% [markdown]
# ### Create DF and Save

# %%
# Create DF
df = CreateDfEmolexCounted(counted_game_emolex)
df = df[df.pn_home != 0].copy().reset_index(drop=True)
df
# Out:
#      GW     away_team           date     home_team  score_ft_away  \
# 0     5       Chelsea  Sat. 12 Sep.        Everton              1
# 1     5   Bournemouth  Sat. 12 Sep.        Norwich              1
# 2     5       Swansea  Sat. 12 Sep.        Watford              0
# 3     5   Southampton  Sat. 12 Sep.   WestBromwich              0
# 4     5         Stoke  Sat. 12 Sep.        Arsenal              0
# 5     5          City  Sat. 12 Sep.        Crystal              1
# 6     5     Liverpool  Sat. 12 Sep.         United              1
# 7     5     Tottenham  Sun. 13 Sep.     Sunderland              1
# 8     5         Villa  Sun. 13 Sep.      Leicester              2
# 9     5     Newcastle  Mon. 14 Sep.        WestHam              0
# 10    6       Arsenal  Sat. 19 Sep.        Chelsea              0
# 11    6       Everton  Sat. 19 Sep.        Swansea              0
# 12    6    Sunderland  Sat. 19 Sep.    Bournemouth              0
# 13    6  WestBromwich  Sat. 19 Sep.          Villa              1
# 14    6       Watford  Sat. 19 Sep.      Newcastle              2
# 15    6     Leicester  Sat. 19 Sep.          Stoke              2
# 16    6       WestHam  Sat. 19 Sep.           City              2
# 17    6       Crystal  Sun. 20 Sep.      Tottenham              0
# 18    6        United  Sun. 20 Sep.    Southampton              3
# 19    6       Norwich  Sun. 20 Sep.      Liverpool              1
# 20    7          City  Sat. 26 Sep.      Tottenham              1
# 21    7       Arsenal  Sat. 26 Sep.      Leicester              5
# 22    7   Bournemouth  Sat. 26 Sep.          Stoke              1
# 23    7       Norwich  Sat. 26 Sep.        WestHam              2
# 24    7       Swansea  Sat. 26 Sep.    Southampton              1
# 25    7    Sunderland  Sat. 26 Sep.         United              0
# 26    7         Villa  Sat. 26 Sep.      Liverpool              2
# 27    7       Chelsea  Sat. 26 Sep.      Newcastle              2
# 28    7       Everton  Mon. 28 Sep.   WestBromwich              3
# 29    8  WestBromwich   Sat. 3 Oct.        Crystal              0
# ..   ..           ...            ...           ...            ...
# 137  20     Liverpool   Sat. 2 Jan.        WestHam              0
# 138  20     Newcastle   Sat. 2 Jan.        Arsenal              0
# 139  20         Stoke   Sat. 2 Jan.   WestBromwich              1
# 140  20         Villa   Sat. 2 Jan.     Sunderland              1
# 141  20   Southampton   Sat. 2 Jan.        Norwich              0
# 142  20       Swansea   Sat. 2 Jan.         United              1
# 143  20   Bournemouth   Sat. 2 Jan.      Leicester              0
# 144  20          City   Sat. 2 Jan.        Watford              2
# 145  20       Chelsea   Sun. 3 Jan.        Crystal              3
# 146  20     Tottenham   Sun. 3 Jan.        Everton              1
# 147  21       Crystal  Tue. 12 Jan.          Villa              0
# 148  21        United  Tue. 12 Jan.      Newcastle              3
# 149  21       WestHam  Tue. 12 Jan.    Bournemouth              3
# 150  21       Norwich  Wed. 13 Jan.          Stoke              1
# 151  21       Watford  Wed. 13 Jan.    Southampton              0
# 152  21       Everton  Wed. 13 Jan.           City              0
# 153  21  WestBromwich  Wed. 13 Jan.        Chelsea              2
# 154  21    Sunderland  Wed. 13 Jan.        Swansea              4
# 155  21     Leicester  Wed. 13 Jan.      Tottenham              1
# 156  21       Arsenal  Wed. 13 Jan.      Liverpool              3
# 157  22    Sunderland  Sat. 16 Jan.      Tottenham              1
# 158  22       WestHam  Sat. 16 Jan.      Newcastle              1
# 159  22       Norwich  Sat. 16 Jan.    Bournemouth              0
# 160  22       Everton  Sat. 16 Jan.        Chelsea              3
# 161  22  WestBromwich  Sat. 16 Jan.    Southampton              0
# 162  22       Crystal  Sat. 16 Jan.           City              0
# 163  22     Leicester  Sat. 16 Jan.          Villa              1
# 164  22        United  Sun. 17 Jan.      Liverpool              1
# 165  22       Arsenal  Sun. 17 Jan.          Stoke              0
# 166  22       Watford  Mon. 18 Jan.        Swansea              0
#
#      score_ft_home  score_ht_away  score_ht_home   time           pn_home  \
# 0                3              1              2  11:45    [871.0, 549.0]
# 1                3              0              1  14:00     [206.0, 57.0]
# 2                1              0              0  14:00      [64.0, 35.0]
# 3                0              0              0  14:00      [62.0, 89.0]
# 4                2              0              1  14:00   [1600.0, 736.0]
# 5                0              0              0  14:00    [205.0, 138.0]
# 6                3              0              0  16:30  [4447.0, 4497.0]
# 7                0              0              0  12:30    [381.0, 243.0]
# 8                3              1              0  15:00    [219.0, 143.0]
# 9                2              0              1  19:00    [418.0, 128.0]
# 10               2              0              0  11:45  [1768.0, 1828.0]
# 11               0              0              0  14:00      [36.0, 29.0]
# 12               2              0              2  14:00     [228.0, 75.0]
# 13               0              1              0  14:00    [249.0, 334.0]
# 14               1              2              0  14:00  [1044.0, 1456.0]
# 15               2              0              2  14:00     [139.0, 47.0]
# 16               1              2              1  16:30    [902.0, 579.0]
# 17               1              0              0  12:30    [737.0, 337.0]
# 18               2              1              1  15:00    [305.0, 123.0]
# 19               1              0              0  15:00   [1628.0, 965.0]
# 20               4              1              1  11:45    [976.0, 568.0]
# 21               2              2              1  14:00    [180.0, 102.0]
# 22               2              0              1  14:00      [41.0, 35.0]
# 23               2              1              1  14:00     [122.0, 73.0]
# 24               3              0              1  14:00     [107.0, 55.0]
# 25               3              0              1  14:00  [3290.0, 1843.0]
# 26               3              0              1  14:00   [1373.0, 687.0]
# 27               2              0              1  16:30   [1352.0, 528.0]
# 28               2              0              1  19:00    [265.0, 157.0]
# 29               2              0              0  11:45    [194.0, 185.0]
# ..             ...            ...            ...    ...               ...
# 137              2              0              1  12:45    [338.0, 236.0]
# 138              1              0              0  15:00    [962.0, 967.0]
# 139              2              0              0  15:00      [97.0, 74.0]
# 140              3              0              1  15:00    [222.0, 163.0]
# 141              1              0              0  15:00     [124.0, 79.0]
# 142              2              0              0  15:00  [2782.0, 3414.0]
# 143              0              0              0  15:00     [183.0, 75.0]
# 144              1              0              0  17:30     [115.0, 84.0]
# 145              0              1              0  13:30    [305.0, 297.0]
# 146              1              1              1  16:00    [748.0, 493.0]
# 147              1              0              0  19:45    [413.0, 232.0]
# 148              3              2              1  19:45  [1222.0, 1257.0]
# 149              1              0              1  19:45     [130.0, 86.0]
# 150              3              0              0  19:45      [73.0, 48.0]
# 151              2              0              1  19:45    [266.0, 104.0]
# 152              0              0              0  19:45    [229.0, 169.0]
# 153              2              1              1  19:45    [634.0, 420.0]
# 154              2              1              2  19:45     [110.0, 84.0]
# 155              0              0              0  20:00    [438.0, 235.0]
# 156              3              2              2  20:00  [4746.0, 3175.0]
# 157              4              1              1  12:45    [714.0, 559.0]
# 158              2              0              2  15:00   [1409.0, 565.0]
# 159              3              0              1  15:00     [102.0, 92.0]
# 160              3              0              0  15:00    [694.0, 668.0]
# 161              3              0              2  15:00    [372.0, 187.0]
# 162              4              0              2  15:00    [430.0, 203.0]
# 163              1              1              0  17:30    [587.0, 469.0]
# 164              0              0              0  14:05  [2311.0, 1715.0]
# 165              0              0              0  16:15    [306.0, 462.0]
# 166              1              0              1  20:00     [208.0, 76.0]
#
#               pn_away                                        emolex_home  \
# 0    [2525.0, 2564.0]  [344.0, 244.0, 170.0, 239.0, 254.0, 425.0, 485...
# 1        [78.0, 34.0]  [32.0, 27.0, 18.0, 21.0, 72.0, 115.0, 95.0, 95.0]
# 2        [41.0, 21.0]   [24.0, 15.0, 11.0, 14.0, 33.0, 40.0, 34.0, 35.0]
# 3        [96.0, 46.0]   [38.0, 30.0, 35.0, 32.0, 29.0, 35.0, 28.0, 41.0]
# 4       [137.0, 79.0]  [459.0, 348.0, 381.0, 341.0, 813.0, 1009.0, 87...
# 5      [470.0, 590.0]  [81.0, 79.0, 36.0, 51.0, 59.0, 115.0, 91.0, 96.0]
# 6    [2667.0, 3225.0]  [1760.0, 1544.0, 1346.0, 1516.0, 1235.0, 2628....
# 7      [704.0, 654.0]  [127.0, 126.0, 86.0, 100.0, 163.0, 211.0, 161....
# 8      [922.0, 334.0]   [62.0, 65.0, 68.0, 59.0, 62.0, 92.0, 81.0, 84.0]
# 9    [1064.0, 1062.0]  [62.0, 61.0, 45.0, 59.0, 101.0, 235.0, 208.0, ...
# 10   [1302.0, 1773.0]  [988.0, 771.0, 950.0, 714.0, 548.0, 908.0, 882...
# 11     [135.0, 127.0]      [16.0, 6.0, 8.0, 7.0, 23.0, 20.0, 22.0, 25.0]
# 12     [398.0, 506.0]  [57.0, 47.0, 29.0, 30.0, 37.0, 115.0, 81.0, 98.0]
# 13      [166.0, 91.0]  [144.0, 137.0, 110.0, 132.0, 55.0, 113.0, 94.0...
# 14      [208.0, 63.0]  [635.0, 538.0, 603.0, 601.0, 312.0, 522.0, 385...
# 15     [177.0, 139.0]    [41.0, 41.0, 7.0, 25.0, 23.0, 73.0, 72.0, 65.0]
# 16     [651.0, 300.0]  [304.0, 298.0, 182.0, 288.0, 291.0, 450.0, 433...
# 17        [19.0, 7.0]  [167.0, 151.0, 87.0, 137.0, 256.0, 394.0, 390....
# 18   [5487.0, 3817.0]  [62.0, 50.0, 40.0, 49.0, 107.0, 154.0, 171.0, ...
# 19      [177.0, 95.0]  [436.0, 438.0, 339.0, 385.0, 558.0, 865.0, 765...
# 20     [991.0, 617.0]  [288.0, 232.0, 190.0, 248.0, 265.0, 495.0, 496...
# 21    [1164.0, 711.0]   [51.0, 43.0, 39.0, 46.0, 52.0, 78.0, 72.0, 75.0]
# 22     [139.0, 179.0]   [21.0, 21.0, 10.0, 19.0, 16.0, 21.0, 11.0, 18.0]
# 23     [211.0, 108.0]   [36.0, 35.0, 22.0, 36.0, 30.0, 71.0, 33.0, 45.0]
# 24       [47.0, 19.0]   [29.0, 25.0, 19.0, 20.0, 41.0, 57.0, 67.0, 57.0]
# 25     [151.0, 116.0]  [809.0, 639.0, 716.0, 655.0, 914.0, 2131.0, 14...
# 26     [325.0, 332.0]  [315.0, 316.0, 210.0, 299.0, 477.0, 767.0, 740...
# 27   [1084.0, 1194.0]  [254.0, 236.0, 174.0, 181.0, 345.0, 722.0, 696...
# 28     [287.0, 297.0]  [82.0, 61.0, 51.0, 58.0, 83.0, 137.0, 127.0, 1...
# 29     [212.0, 378.0]  [101.0, 84.0, 53.0, 62.0, 62.0, 91.0, 90.0, 88.0]
# ..                ...                                                ...
# 137  [2861.0, 3580.0]  [147.0, 124.0, 78.0, 109.0, 125.0, 175.0, 150....
# 138    [646.0, 475.0]  [424.0, 409.0, 327.0, 441.0, 340.0, 654.0, 430...
# 139      [32.0, 29.0]   [31.0, 29.0, 24.0, 31.0, 20.0, 49.0, 33.0, 35.0]
# 140    [619.0, 655.0]  [72.0, 85.0, 62.0, 71.0, 100.0, 107.0, 104.0, ...
# 141    [151.0, 117.0]   [35.0, 31.0, 23.0, 35.0, 52.0, 72.0, 55.0, 64.0]
# 142      [87.0, 53.0]  [1280.0, 1201.0, 1140.0, 1208.0, 1037.0, 1529....
# 143      [94.0, 43.0]  [39.0, 47.0, 99.0, 100.0, 59.0, 105.0, 51.0, 1...
# 144    [537.0, 489.0]   [32.0, 35.0, 25.0, 30.0, 58.0, 70.0, 59.0, 54.0]
# 145  [1683.0, 1195.0]  [159.0, 137.0, 83.0, 126.0, 91.0, 153.0, 131.0...
# 146  [2253.0, 1063.0]  [224.0, 211.0, 142.0, 184.0, 223.0, 392.0, 327...
# 147    [146.0, 117.0]  [106.0, 115.0, 75.0, 95.0, 121.0, 195.0, 160.0...
# 148  [5546.0, 3354.0]  [663.0, 464.0, 594.0, 463.0, 421.0, 668.0, 499...
# 149    [249.0, 337.0]   [53.0, 28.0, 12.0, 45.0, 51.0, 82.0, 78.0, 66.0]
# 150    [328.0, 460.0]   [23.0, 24.0, 15.0, 16.0, 23.0, 43.0, 31.0, 30.0]
# 151     [98.0, 123.0]  [36.0, 49.0, 37.0, 47.0, 112.0, 143.0, 131.0, ...
# 152     [211.0, 97.0]  [99.0, 92.0, 42.0, 72.0, 100.0, 130.0, 106.0, ...
# 153    [161.0, 116.0]  [199.0, 189.0, 171.0, 179.0, 177.0, 381.0, 298...
# 154    [381.0, 436.0]   [37.0, 40.0, 32.0, 42.0, 27.0, 68.0, 46.0, 36.0]
# 155    [147.0, 126.0]  [113.0, 113.0, 61.0, 83.0, 151.0, 267.0, 252.0...
# 156  [1789.0, 1237.0]  [1490.0, 1385.0, 1291.0, 1383.0, 1265.0, 2390....
# 157    [550.0, 281.0]  [277.0, 240.0, 197.0, 258.0, 205.0, 417.0, 349...
# 158    [215.0, 182.0]  [231.0, 245.0, 215.0, 242.0, 332.0, 746.0, 722...
# 159    [327.0, 257.0]   [71.0, 56.0, 33.0, 29.0, 47.0, 60.0, 39.0, 54.0]
# 160    [177.0, 106.0]  [312.0, 278.0, 234.0, 254.0, 214.0, 348.0, 300...
# 161    [126.0, 147.0]  [126.0, 59.0, 62.0, 60.0, 126.0, 221.0, 219.0,...
# 162    [259.0, 269.0]  [86.0, 95.0, 50.0, 77.0, 121.0, 235.0, 216.0, ...
# 163    [365.0, 182.0]  [236.0, 208.0, 192.0, 214.0, 156.0, 323.0, 257...
# 164  [3820.0, 4420.0]  [828.0, 806.0, 656.0, 679.0, 1033.0, 1200.0, 1...
# 165  [1340.0, 1256.0]  [204.0, 216.0, 157.0, 186.0, 84.0, 162.0, 144....
# 166    [252.0, 326.0]  [21.0, 29.0, 17.0, 28.0, 58.0, 116.0, 76.0, 91.0]
#
#                                            emolex_away
# 0    [1238.0, 1128.0, 983.0, 1093.0, 749.0, 1405.0,...
# 1     [21.0, 21.0, 15.0, 15.0, 17.0, 37.0, 25.0, 27.0]
# 2      [15.0, 13.0, 9.0, 11.0, 15.0, 29.0, 20.0, 22.0]
# 3     [18.0, 17.0, 14.0, 17.0, 39.0, 48.0, 51.0, 45.0]
# 4     [49.0, 47.0, 28.0, 39.0, 49.0, 79.0, 61.0, 60.0]
# 5    [324.0, 375.0, 162.0, 330.0, 202.0, 270.0, 212...
# 6    [1348.0, 1341.0, 1282.0, 1368.0, 728.0, 1431.0...
# 7    [298.0, 266.0, 225.0, 263.0, 242.0, 362.0, 312...
# 8    [138.0, 156.0, 127.0, 138.0, 271.0, 417.0, 498...
# 9    [444.0, 419.0, 370.0, 387.0, 267.0, 530.0, 376...
# 10   [924.0, 690.0, 922.0, 725.0, 420.0, 727.0, 538...
# 11    [47.0, 38.0, 34.0, 43.0, 51.0, 82.0, 80.0, 77.0]
# 12   [244.0, 215.0, 213.0, 221.0, 116.0, 196.0, 165...
# 13    [51.0, 35.0, 38.0, 27.0, 49.0, 85.0, 79.0, 78.0]
# 14   [34.0, 30.0, 12.0, 23.0, 37.0, 115.0, 93.0, 83.0]
# 15    [59.0, 77.0, 50.0, 76.0, 55.0, 75.0, 60.0, 85.0]
# 16   [168.0, 180.0, 110.0, 143.0, 156.0, 308.0, 343...
# 17         [6.0, 4.0, 3.0, 6.0, 8.0, 11.0, 13.0, 12.0]
# 18   [1798.0, 1505.0, 1406.0, 1550.0, 1518.0, 2723....
# 19    [32.0, 35.0, 26.0, 41.0, 57.0, 99.0, 83.0, 89.0]
# 20   [276.0, 252.0, 163.0, 283.0, 254.0, 581.0, 454...
# 21   [346.0, 352.0, 295.0, 352.0, 375.0, 679.0, 577...
# 22   [119.0, 135.0, 56.0, 139.0, 49.0, 69.0, 73.0, ...
# 23   [37.0, 50.0, 30.0, 50.0, 73.0, 114.0, 82.0, 89.0]
# 24        [9.0, 4.0, 3.0, 8.0, 15.0, 16.0, 17.0, 13.0]
# 25    [48.0, 45.0, 34.0, 52.0, 30.0, 87.0, 57.0, 61.0]
# 26   [119.0, 136.0, 111.0, 150.0, 97.0, 147.0, 131....
# 27   [589.0, 504.0, 475.0, 527.0, 313.0, 574.0, 432...
# 28   [126.0, 113.0, 106.0, 126.0, 101.0, 128.0, 110...
# 29   [177.0, 153.0, 113.0, 168.0, 70.0, 122.0, 105....
# ..                                                 ...
# 137  [1767.0, 1506.0, 1415.0, 1363.0, 891.0, 1502.0...
# 138  [258.0, 254.0, 185.0, 177.0, 263.0, 362.0, 290...
# 139      [8.0, 11.0, 9.0, 7.0, 12.0, 15.0, 12.0, 12.0]
# 140  [307.0, 249.0, 266.0, 262.0, 192.0, 291.0, 251...
# 141  [35.0, 34.0, 21.0, 60.0, 86.0, 73.0, 89.0, 115.0]
# 142   [32.0, 22.0, 21.0, 21.0, 20.0, 32.0, 26.0, 30.0]
# 143   [28.0, 23.0, 17.0, 21.0, 44.0, 48.0, 40.0, 45.0]
# 144  [191.0, 210.0, 148.0, 197.0, 145.0, 278.0, 169...
# 145  [566.0, 595.0, 444.0, 513.0, 583.0, 976.0, 854...
# 146  [612.0, 477.0, 355.0, 493.0, 551.0, 1143.0, 10...
# 147   [49.0, 51.0, 35.0, 51.0, 44.0, 72.0, 52.0, 66.0]
# 148  [1687.0, 1612.0, 1308.0, 1115.0, 1816.0, 3156....
# 149  [164.0, 254.0, 61.0, 208.0, 155.0, 165.0, 150....
# 150  [251.0, 187.0, 163.0, 131.0, 146.0, 157.0, 132...
# 151   [78.0, 64.0, 58.0, 62.0, 39.0, 60.0, 54.0, 77.0]
# 152  [55.0, 39.0, 45.0, 42.0, 79.0, 133.0, 114.0, 7...
# 153   [78.0, 53.0, 34.0, 46.0, 48.0, 89.0, 81.0, 83.0]
# 154  [236.0, 197.0, 202.0, 177.0, 124.0, 211.0, 121...
# 155   [88.0, 35.0, 36.0, 38.0, 47.0, 75.0, 73.0, 69.0]
# 156  [660.0, 643.0, 491.0, 555.0, 518.0, 959.0, 788...
# 157  [125.0, 132.0, 100.0, 95.0, 148.0, 323.0, 254....
# 158   [95.0, 96.0, 69.0, 99.0, 63.0, 98.0, 73.0, 86.0]
# 159  [113.0, 124.0, 92.0, 100.0, 88.0, 152.0, 130.0...
# 160  [59.0, 50.0, 37.0, 39.0, 78.0, 116.0, 84.0, 87.0]
# 161   [63.0, 63.0, 61.0, 67.0, 39.0, 57.0, 47.0, 76.0]
# 162  [108.0, 109.0, 76.0, 150.0, 86.0, 144.0, 108.0...
# 163  [96.0, 78.0, 73.0, 72.0, 96.0, 206.0, 165.0, 1...
# 164  [2105.0, 1838.0, 1838.0, 1718.0, 1246.0, 2094....
# 165  [690.0, 592.0, 359.0, 626.0, 507.0, 619.0, 696...
# 166  [162.0, 134.0, 155.0, 144.0, 73.0, 127.0, 98.0...
#
# [167 rows x 13 columns]

# %%
# Save as CSV
useful_methods.DFtoCSV(df, paths.DATA_HOME + "EPL/", 'all_game_emolex_counted_nonretweet', index=False)
print("[Saved in]: %s" % (paths.DATA_HOME + "EPL/" + 'all_game_emolex_counted_nonretweet.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/all_game_emolex_counted_nonretweet.csv
