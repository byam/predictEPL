# %%
# %pylab inline
# %matplotlib inline

import os
from time import time
import pandas as pd

# Local Imports
path = str(os.path.expanduser('~')) + '/git/predictEPL/config'
sys.path.append(path)
import paths

sys.path.append(paths.UTILS)
import emolex
import useful_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Data Loads & Defnings

# %%
# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')


# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]


# Read Emotion-Lexicon-Soccer as Dictionary
dic_emolex_soccer = emolex.EmolexSoccerDic()


# Limitations
time_limit = 60
retweet = True
start_time = 1
end_time = 60
# Out:
# [Emolex Dic's All Words]: 14136

# %% [markdown]
# ### Emolex Count Functions

# %%
# Summing counted emolex
def EmolexSumList(dfEmolex, start=1, end=60):
    # Time Interval
    dfEmolex.ith_minute = [int(ith_minute) for ith_minute in list(dfEmolex.ith_minute)]
    dfEmolex = dfEmolex[(dfEmolex.ith_minute >= start) & (dfEmolex.ith_minute <= end)]
    
    # Sum Emolex Count
    anger = dfEmolex.anger.sum()
    fear = dfEmolex.fear.sum()
    disgust = dfEmolex.disgust.sum()
    sadness = dfEmolex.sadness.sum()
    surprise = dfEmolex.surprise.sum()
    trust = dfEmolex.trust.sum()
    joy = dfEmolex.joy.sum()
    anticipation = dfEmolex.anticipation.sum()
    positive = dfEmolex.positive.sum()
    negative = dfEmolex.negative.sum()
    
    return {'anger': anger,
            'fear': fear,
            'disgust': disgust,
            'sadness': sadness,
            'surprise': surprise,
            'trust': trust,
            'joy': joy,
            'anticipation': anticipation,
            'positive': positive,
            'negative': negative}


# Count Home, Away Emolex
def CountGameEmolex(week, team_home, team_away):

    # Read Single as DF
    dfGame = useful_methods.SingleGameDf(week, team_home, team_away, filtering=True, retweet=retweet)
    if dfGame is None:
        return (None, None)

    dfGame.ith_minute = [int(ith_minute) for ith_minute in list(dfGame.ith_minute)]

    # Count Emolex Words
    dfEmolexHome = emolex.CreateEmolexDF(dfGame[(dfGame.side == 'home') & (dfGame.ith_minute <= time_limit)], dic_emolex_soccer)
    dfEmolexAway = emolex.CreateEmolexDF(dfGame[(dfGame.side == 'away') & (dfGame.ith_minute <= time_limit)], dic_emolex_soccer)

    # Sum Emolex
    dic_emolex_home = EmolexSumList(dfEmolexHome, start=start_time, end=end_time)
    dic_emolex_away = EmolexSumList(dfEmolexAway, start=start_time, end=end_time)

    return (dic_emolex_home, dic_emolex_away)

# %%
# Add Emolex Counted Columns
def CreateDfEmolexCounted(counted_game_emolex):
    pn_home = []
    pn_away = []
    
    emolex_home = []
    emolex_away = []

    for game_emolex in counted_game_emolex:
        home_emolex = game_emolex[0]
        away_emolex = game_emolex[1]

        if home_emolex and away_emolex:
            pn_home.append([
                    home_emolex['positive'],
                    home_emolex['negative']
                ])
            
            pn_away.append([
                    away_emolex['positive'],
                    away_emolex['negative']
                ])

            emolex_home.append([
                    home_emolex['anger'],
                    home_emolex['fear'],
                    home_emolex['disgust'],
                    home_emolex['sadness'],
                    home_emolex['surprise'],
                    home_emolex['trust'],
                    home_emolex['joy'],
                    home_emolex['anticipation'],
                ])
            
            emolex_away.append([
                    away_emolex['anger'],
                    away_emolex['fear'],
                    away_emolex['disgust'],
                    away_emolex['sadness'],
                    away_emolex['surprise'],
                    away_emolex['trust'],
                    away_emolex['joy'],
                    away_emolex['anticipation'],
                ])
            
        else:
            pn_home.append(0)
            pn_away.append(0)
            
            emolex_home.append([0])
            emolex_away.append([0])

    
    df = dfGameInfos.copy()
    df['pn_home'] = pn_home
    df['pn_away'] = pn_away
    
    df['emolex_home'] = emolex_home
    df['emolex_away'] = emolex_away
    
    return df

# %% [markdown]
# ### All Game Count Start

# %%
taken_time = time()

counted_game_emolex = []

for week in set(dfGameInfos.GW):
    for index in range((week - 1) * 10, week * 10):
        # Team names
        team_home = dfGameInfos[dfGameInfos.GW == week].loc[index]['home_team']
        team_away = dfGameInfos[dfGameInfos.GW == week].loc[index]['away_team']

        print("\n\n------------------")
        print(week, team_home, team_away)
        counted_game_emolex.append(CountGameEmolex(week, team_home, team_away))

print("[Done:] %.2f" % (time() - taken_time))
# Out:
# ------------------
# 1 United Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Everton Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Leicester Sunderland
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Norwich Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Bournemouth Villa
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Chelsea Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Arsenal WestHam
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Newcastle Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 Stoke Liverpool
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 1 WestBromwich City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Villa United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Southampton Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Tottenham Stoke
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 WestHam Leicester
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Watford WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Sunderland Norwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Swansea Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Crystal Arsenal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 City Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 2 Liverpool Bournemouth
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 United Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Crystal Villa
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 WestHam Bournemouth
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Sunderland Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Norwich Stoke
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Leicester Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 WestBromwich Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Watford Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Everton City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 3 Arsenal Liverpool
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Newcastle Arsenal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Stoke WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Liverpool WestHam
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Chelsea Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Villa Sunderland
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Bournemouth Leicester
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 City Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Tottenham Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Southampton Norwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 4 Swansea United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 5 Everton Chelsea
#
#
# ------------------
# 5 Norwich Bournemouth
#
#
# ------------------
# 5 Watford Swansea
#
#
# ------------------
# 5 WestBromwich Southampton
#
#
# ------------------
# 5 Arsenal Stoke
#
#
# ------------------
# 5 Crystal City
#
#
# ------------------
# 5 United Liverpool
#
#
# ------------------
# 5 Sunderland Tottenham
#
#
# ------------------
# 5 Leicester Villa
#
#
# ------------------
# 5 WestHam Newcastle
#
#
# ------------------
# 6 Chelsea Arsenal
#
#
# ------------------
# 6 Swansea Everton
#
#
# ------------------
# 6 Bournemouth Sunderland
#
#
# ------------------
# 6 Villa WestBromwich
#
#
# ------------------
# 6 Newcastle Watford
#
#
# ------------------
# 6 Stoke Leicester
#
#
# ------------------
# 6 City WestHam
#
#
# ------------------
# 6 Tottenham Crystal
#
#
# ------------------
# 6 Southampton United
#
#
# ------------------
# 6 Liverpool Norwich
#
#
# ------------------
# 7 Tottenham City
#
#
# ------------------
# 7 Leicester Arsenal
#
#
# ------------------
# 7 Stoke Bournemouth
#
#
# ------------------
# 7 WestHam Norwich
#
#
# ------------------
# 7 Southampton Swansea
#
#
# ------------------
# 7 United Sunderland
#
#
# ------------------
# 7 Liverpool Villa
#
#
# ------------------
# 7 Newcastle Chelsea
#
#
# ------------------
# 7 Watford Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 7 WestBromwich Everton
#
#
# ------------------
# 8 Crystal WestBromwich
#
#
# ------------------
# 8 Norwich Leicester
#
#
# ------------------
# 8 Sunderland WestHam
#
#
# ------------------
# 8 City Newcastle
#
#
# ------------------
# 8 Villa Stoke
#
#
# ------------------
# 8 Bournemouth Watford
#
#
# ------------------
# 8 Chelsea Southampton
#
#
# ------------------
# 8 Everton Liverpool
#
#
# ------------------
# 8 Swansea Tottenham
#
#
# ------------------
# 8 Arsenal United
#
#
# ------------------
# 9 Tottenham Liverpool
#
#
# ------------------
# 9 Southampton Leicester
#
#
# ------------------
# 9 WestBromwich Sunderland
#
#
# ------------------
# 9 Chelsea Villa
#
#
# ------------------
# 9 Crystal WestHam
#
#
# ------------------
# 9 Everton United
#
#
# ------------------
# 9 City Bournemouth
#
#
# ------------------
# 9 Watford Arsenal
#
#
# ------------------
# 9 Newcastle Norwich
#
#
# ------------------
# 9 Swansea Stoke
#
#
# ------------------
# 10 Norwich WestBromwich
#
#
# ------------------
# 10 Leicester Crystal
#
#
# ------------------
# 10 Villa Swansea
#
#
# ------------------
# 10 WestHam Chelsea
#
#
# ------------------
# 10 Stoke Watford
#
#
# ------------------
# 10 Arsenal Everton
#
#
# ------------------
# 10 Sunderland Newcastle
#
#
# ------------------
# 10 United City
#
#
# ------------------
# 10 Bournemouth Tottenham
#
#
# ------------------
# 10 Liverpool Southampton
#
#
# ------------------
# 11 Chelsea Liverpool
#
#
# ------------------
# 11 Swansea Arsenal
#
#
# ------------------
# 11 WestBromwich Leicester
#
#
# ------------------
# 11 Watford WestHam
#
#
# ------------------
# 11 Newcastle Stoke
#
#
# ------------------
# 11 City Norwich
#
#
# ------------------
# 11 Crystal United
#
#
# ------------------
# 11 Everton Sunderland
#
#
# ------------------
# 11 Southampton Bournemouth
#
#
# ------------------
# 11 Tottenham Villa
#
#
# ------------------
# 12 Bournemouth Newcastle
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Leicester Watford
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Norwich Swansea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 WestHam Everton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Sunderland Southampton
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 United WestBromwich
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Stoke Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Villa City
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Liverpool Crystal
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 12 Arsenal Tottenham
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 13 Watford United
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 13 Swansea Bournemouth
#
#
# ------------------
# 13 Chelsea Norwich
#
#
# ------------------
# 13 Everton Villa
#
#
# ------------------
# 13 WestBromwich Arsenal
#
#
# ------------------
# 13 Newcastle Leicester
#
#
# ------------------
# 13 Southampton Stoke
#
#
# ------------------
# 13 City Liverpool
#
#
# ------------------
# 13 Tottenham WestHam
#
#
# ------------------
# 13 Crystal Sunderland
#
#
# ------------------
# 14 Sunderland Stoke
#
#
# ------------------
# 14 Bournemouth Everton
#
#
# ------------------
# 14 Villa Watford
#
#
# ------------------
# 14 Crystal Newcastle
#
#
# ------------------
# 14 City Southampton
#
#
# ------------------
# 14 Leicester United
#
#
# ------------------
# 14 Tottenham Chelsea
#
#
# ------------------
# 14 WestHam WestBromwich
#
#
# ------------------
# 14 Liverpool Swansea
#
#
# ------------------
# 14 Norwich Arsenal
#
#
# ------------------
# 15 Stoke City
#
#
# ------------------
# 15 Arsenal Sunderland
#
#
# ------------------
# 15 WestBromwich Tottenham
#
#
# ------------------
# 15 Watford Norwich
#
#
# ------------------
# 15 United WestHam
#
#
# ------------------
# 15 Swansea Leicester
#
#
# ------------------
# 15 Southampton Villa
#
#
# ------------------
# 15 Chelsea Bournemouth
#
#
# ------------------
# 15 Newcastle Liverpool
#
#
# ------------------
# 15 Everton Crystal
#
#
# ------------------
# 16 Norwich Everton
#
#
# ------------------
# 16 WestHam Stoke
#
#
# ------------------
# 16 Sunderland Watford
#
#
# ------------------
# 16 City Swansea
#
#
# ------------------
# 16 Crystal Southampton
#
#
# ------------------
# 16 Bournemouth United
#
#
# ------------------
# 16 Villa Arsenal
#
#
# ------------------
# 16 Liverpool WestBromwich
#
#
# ------------------
# 16 Tottenham Newcastle
#
#
# ------------------
# 16 Leicester Chelsea
# [Not Game Exists]: Check your inputs
#
#
# ------------------
# 17 Stoke Crystal
#
#
# ------------------
# 17 WestBromwich Bournemouth
#
#
# ------------------
# 17 Chelsea Sunderland
#
#
# ------------------
# 17 Everton Leicester
#
#
# ------------------
# 17 United Norwich
#
#
# ------------------
# 17 Southampton Tottenham
#
#
# ------------------
# 17 Newcastle Villa
#
#
# ------------------
# 17 Watford Liverpool
#
#
# ------------------
# 17 Swansea WestHam
#
#
# ------------------
# 17 Arsenal City
#
#
# ------------------
# 18 Stoke United
#
#
# ------------------
# 18 Tottenham Norwich
#
#
# ------------------
# 18 Swansea WestBromwich
#
#
# ------------------
# 18 City Sunderland
#
#
# ------------------
# 18 Liverpool Leicester
#
#
# ------------------
# 18 Chelsea Watford
#
#
# ------------------
# 18 Villa WestHam
#
#
# ------------------
# 18 Bournemouth Crystal
#
#
# ------------------
# 18 Newcastle Everton
#
#
# ------------------
# 18 Southampton Arsenal
#
#
# ------------------
# 19 Crystal Swansea
#
#
# ------------------
# 19 Everton Stoke
#
#
# ------------------
# 19 Norwich Villa
#
#
# ------------------
# 19 Watford Tottenham
#
#
# ------------------
# 19 WestBromwich Newcastle
#
#
# ------------------
# 19 WestHam Southampton
#
#
# ------------------
# 19 Arsenal Bournemouth
#
#
# ------------------
# 19 United Chelsea
#
#
# ------------------
# 19 Leicester City
#
#
# ------------------
# 19 Sunderland Liverpool
#
#
# ------------------
# 20 WestHam Liverpool
#
#
# ------------------
# 20 Arsenal Newcastle
#
#
# ------------------
# 20 WestBromwich Stoke
#
#
# ------------------
# 20 Sunderland Villa
#
#
# ------------------
# 20 Norwich Southampton
#
#
# ------------------
# 20 United Swansea
#
#
# ------------------
# 20 Leicester Bournemouth
#
#
# ------------------
# 20 Watford City
#
#
# ------------------
# 20 Crystal Chelsea
#
#
# ------------------
# 20 Everton Tottenham
#
#
# ------------------
# 21 Villa Crystal
#
#
# ------------------
# 21 Newcastle United
#
#
# ------------------
# 21 Bournemouth WestHam
#
#
# ------------------
# 21 Stoke Norwich
#
#
# ------------------
# 21 Southampton Watford
#
#
# ------------------
# 21 City Everton
#
#
# ------------------
# 21 Chelsea WestBromwich
#
#
# ------------------
# 21 Swansea Sunderland
#
#
# ------------------
# 21 Tottenham Leicester
#
#
# ------------------
# 21 Liverpool Arsenal
#
#
# ------------------
# 22 Tottenham Sunderland
#
#
# ------------------
# 22 Newcastle WestHam
#
#
# ------------------
# 22 Bournemouth Norwich
#
#
# ------------------
# 22 Chelsea Everton
#
#
# ------------------
# 22 Southampton WestBromwich
#
#
# ------------------
# 22 City Crystal
#
#
# ------------------
# 22 Villa Leicester
#
#
# ------------------
# 22 Liverpool United
#
#
# ------------------
# 22 Stoke Arsenal
#
#
# ------------------
# 22 Swansea Watford
# [Done:] 1427.82

# %% [markdown]
# ### Create DF and Save

# %%
# Create DF
df = CreateDfEmolexCounted(counted_game_emolex)
df = df[df.pn_home != 0].copy().reset_index(drop=True)
df
# Out:
#      GW     away_team           date     home_team  score_ft_away  \
# 0     5       Chelsea  Sat. 12 Sep.        Everton              1
# 1     5   Bournemouth  Sat. 12 Sep.        Norwich              1
# 2     5       Swansea  Sat. 12 Sep.        Watford              0
# 3     5   Southampton  Sat. 12 Sep.   WestBromwich              0
# 4     5         Stoke  Sat. 12 Sep.        Arsenal              0
# 5     5          City  Sat. 12 Sep.        Crystal              1
# 6     5     Liverpool  Sat. 12 Sep.         United              1
# 7     5     Tottenham  Sun. 13 Sep.     Sunderland              1
# 8     5         Villa  Sun. 13 Sep.      Leicester              2
# 9     5     Newcastle  Mon. 14 Sep.        WestHam              0
# 10    6       Arsenal  Sat. 19 Sep.        Chelsea              0
# 11    6       Everton  Sat. 19 Sep.        Swansea              0
# 12    6    Sunderland  Sat. 19 Sep.    Bournemouth              0
# 13    6  WestBromwich  Sat. 19 Sep.          Villa              1
# 14    6       Watford  Sat. 19 Sep.      Newcastle              2
# 15    6     Leicester  Sat. 19 Sep.          Stoke              2
# 16    6       WestHam  Sat. 19 Sep.           City              2
# 17    6       Crystal  Sun. 20 Sep.      Tottenham              0
# 18    6        United  Sun. 20 Sep.    Southampton              3
# 19    6       Norwich  Sun. 20 Sep.      Liverpool              1
# 20    7          City  Sat. 26 Sep.      Tottenham              1
# 21    7       Arsenal  Sat. 26 Sep.      Leicester              5
# 22    7   Bournemouth  Sat. 26 Sep.          Stoke              1
# 23    7       Norwich  Sat. 26 Sep.        WestHam              2
# 24    7       Swansea  Sat. 26 Sep.    Southampton              1
# 25    7    Sunderland  Sat. 26 Sep.         United              0
# 26    7         Villa  Sat. 26 Sep.      Liverpool              2
# 27    7       Chelsea  Sat. 26 Sep.      Newcastle              2
# 28    7       Everton  Mon. 28 Sep.   WestBromwich              3
# 29    8  WestBromwich   Sat. 3 Oct.        Crystal              0
# ..   ..           ...            ...           ...            ...
# 137  20     Liverpool   Sat. 2 Jan.        WestHam              0
# 138  20     Newcastle   Sat. 2 Jan.        Arsenal              0
# 139  20         Stoke   Sat. 2 Jan.   WestBromwich              1
# 140  20         Villa   Sat. 2 Jan.     Sunderland              1
# 141  20   Southampton   Sat. 2 Jan.        Norwich              0
# 142  20       Swansea   Sat. 2 Jan.         United              1
# 143  20   Bournemouth   Sat. 2 Jan.      Leicester              0
# 144  20          City   Sat. 2 Jan.        Watford              2
# 145  20       Chelsea   Sun. 3 Jan.        Crystal              3
# 146  20     Tottenham   Sun. 3 Jan.        Everton              1
# 147  21       Crystal  Tue. 12 Jan.          Villa              0
# 148  21        United  Tue. 12 Jan.      Newcastle              3
# 149  21       WestHam  Tue. 12 Jan.    Bournemouth              3
# 150  21       Norwich  Wed. 13 Jan.          Stoke              1
# 151  21       Watford  Wed. 13 Jan.    Southampton              0
# 152  21       Everton  Wed. 13 Jan.           City              0
# 153  21  WestBromwich  Wed. 13 Jan.        Chelsea              2
# 154  21    Sunderland  Wed. 13 Jan.        Swansea              4
# 155  21     Leicester  Wed. 13 Jan.      Tottenham              1
# 156  21       Arsenal  Wed. 13 Jan.      Liverpool              3
# 157  22    Sunderland  Sat. 16 Jan.      Tottenham              1
# 158  22       WestHam  Sat. 16 Jan.      Newcastle              1
# 159  22       Norwich  Sat. 16 Jan.    Bournemouth              0
# 160  22       Everton  Sat. 16 Jan.        Chelsea              3
# 161  22  WestBromwich  Sat. 16 Jan.    Southampton              0
# 162  22       Crystal  Sat. 16 Jan.           City              0
# 163  22     Leicester  Sat. 16 Jan.          Villa              1
# 164  22        United  Sun. 17 Jan.      Liverpool              1
# 165  22       Arsenal  Sun. 17 Jan.          Stoke              0
# 166  22       Watford  Mon. 18 Jan.        Swansea              0
#
#      score_ft_home  score_ht_away  score_ht_home   time            pn_home  \
# 0                3              1              2  11:45    [1009.0, 647.0]
# 1                3              0              1  14:00     [331.0, 100.0]
# 2                1              0              0  14:00       [98.0, 55.0]
# 3                0              0              0  14:00     [116.0, 116.0]
# 4                2              0              1  14:00    [2529.0, 938.0]
# 5                0              0              0  14:00     [299.0, 225.0]
# 6                3              0              0  16:30  [11807.0, 9999.0]
# 7                0              0              0  12:30     [498.0, 330.0]
# 8                3              1              0  15:00     [276.0, 163.0]
# 9                2              0              1  19:00     [655.0, 202.0]
# 10               2              0              0  11:45   [3493.0, 2705.0]
# 11               0              0              0  14:00       [65.0, 33.0]
# 12               2              0              2  14:00     [743.0, 136.0]
# 13               0              1              0  14:00     [342.0, 394.0]
# 14               1              2              0  14:00   [1508.0, 1978.0]
# 15               2              0              2  14:00      [183.0, 56.0]
# 16               1              2              1  16:30   [1485.0, 1412.0]
# 17               1              0              0  12:30    [1228.0, 474.0]
# 18               2              1              1  15:00     [646.0, 176.0]
# 19               1              0              0  15:00   [3980.0, 2079.0]
# 20               4              1              1  11:45   [1743.0, 1016.0]
# 21               2              2              1  14:00     [257.0, 137.0]
# 22               2              0              1  14:00       [53.0, 42.0]
# 23               2              1              1  14:00     [352.0, 167.0]
# 24               3              0              1  14:00      [225.0, 72.0]
# 25               3              0              1  14:00  [11865.0, 5636.0]
# 26               3              0              1  14:00   [3908.0, 1415.0]
# 27               2              0              1  16:30    [2086.0, 762.0]
# 28               2              0              1  19:00     [347.0, 199.0]
# 29               2              0              0  11:45     [259.0, 247.0]
# ..             ...            ...            ...    ...                ...
# 137              2              0              1  12:45     [782.0, 544.0]
# 138              1              0              0  15:00   [1342.0, 1864.0]
# 139              2              0              0  15:00      [139.0, 92.0]
# 140              3              0              1  15:00     [372.0, 223.0]
# 141              1              0              0  15:00      [161.0, 97.0]
# 142              2              0              0  15:00   [7515.0, 7543.0]
# 143              0              0              0  15:00     [315.0, 105.0]
# 144              1              0              0  17:30     [193.0, 115.0]
# 145              0              1              0  13:30     [421.0, 378.0]
# 146              1              1              1  16:00    [1009.0, 665.0]
# 147              1              0              0  19:45     [580.0, 358.0]
# 148              3              2              1  19:45   [2842.0, 2007.0]
# 149              1              0              1  19:45     [267.0, 153.0]
# 150              3              0              0  19:45       [92.0, 50.0]
# 151              2              0              1  19:45     [452.0, 117.0]
# 152              0              0              0  19:45     [500.0, 336.0]
# 153              2              1              1  19:45    [1218.0, 564.0]
# 154              2              1              2  19:45     [173.0, 131.0]
# 155              0              0              0  20:00     [904.0, 370.0]
# 156              3              2              2  20:00  [13235.0, 6038.0]
# 157              4              1              1  12:45    [1080.0, 972.0]
# 158              2              0              2  15:00    [3330.0, 987.0]
# 159              3              0              1  15:00     [153.0, 126.0]
# 160              3              0              0  15:00   [1100.0, 1017.0]
# 161              3              0              2  15:00     [716.0, 293.0]
# 162              4              0              2  15:00    [1218.0, 581.0]
# 163              1              1              0  17:30     [777.0, 562.0]
# 164              0              0              0  14:05   [4865.0, 3671.0]
# 165              0              0              0  16:15     [470.0, 658.0]
# 166              1              0              1  20:00     [696.0, 167.0]
#
#                pn_away                                        emolex_home  \
# 0     [3901.0, 3699.0]  [405.0, 287.0, 192.0, 322.0, 291.0, 484.0, 530...
# 1        [112.0, 53.0]  [67.0, 64.0, 22.0, 54.0, 122.0, 194.0, 122.0, ...
# 2         [78.0, 36.0]   [38.0, 22.0, 18.0, 20.0, 57.0, 66.0, 52.0, 58.0]
# 3        [154.0, 62.0]   [56.0, 30.0, 38.0, 32.0, 43.0, 80.0, 48.0, 94.0]
# 4       [255.0, 113.0]  [603.0, 445.0, 421.0, 432.0, 1039.0, 1681.0, 1...
# 5      [975.0, 1708.0]  [146.0, 113.0, 60.0, 80.0, 100.0, 190.0, 145.0...
# 6     [4881.0, 4464.0]  [5228.0, 3026.0, 2403.0, 2447.0, 2705.0, 7167....
# 7      [1117.0, 815.0]  [158.0, 152.0, 87.0, 120.0, 205.0, 329.0, 218....
# 8      [1550.0, 480.0]  [70.0, 75.0, 74.0, 65.0, 99.0, 122.0, 99.0, 10...
# 9     [1560.0, 1563.0]  [96.0, 92.0, 64.0, 68.0, 147.0, 401.0, 297.0, ...
# 10    [1927.0, 2767.0]  [1272.0, 1071.0, 1371.0, 1003.0, 924.0, 1707.0...
# 11      [195.0, 176.0]     [16.0, 7.0, 11.0, 7.0, 43.0, 39.0, 44.0, 44.0]
# 12      [555.0, 640.0]  [79.0, 66.0, 43.0, 42.0, 42.0, 389.0, 105.0, 2...
# 13      [245.0, 160.0]  [170.0, 171.0, 122.0, 156.0, 72.0, 185.0, 143....
# 14       [648.0, 84.0]  [847.0, 796.0, 792.0, 899.0, 500.0, 752.0, 562...
# 15      [285.0, 169.0]    [46.0, 51.0, 7.0, 32.0, 32.0, 89.0, 94.0, 78.0]
# 16     [1310.0, 510.0]  [676.0, 838.0, 239.0, 797.0, 689.0, 702.0, 657...
# 17         [22.0, 8.0]  [251.0, 237.0, 119.0, 174.0, 346.0, 563.0, 596...
# 18   [12191.0, 8295.0]  [84.0, 87.0, 49.0, 70.0, 267.0, 339.0, 336.0, ...
# 19      [232.0, 116.0]  [804.0, 831.0, 855.0, 747.0, 1598.0, 1998.0, 1...
# 20    [2683.0, 1549.0]  [636.0, 619.0, 205.0, 362.0, 352.0, 831.0, 952...
# 21    [1793.0, 1549.0]  [72.0, 51.0, 60.0, 57.0, 65.0, 112.0, 92.0, 10...
# 22      [211.0, 330.0]   [29.0, 29.0, 10.0, 22.0, 19.0, 30.0, 17.0, 24.0]
# 23      [311.0, 160.0]  [94.0, 64.0, 38.0, 82.0, 49.0, 214.0, 69.0, 96.0]
# 24        [63.0, 23.0]  [34.0, 27.0, 22.0, 23.0, 152.0, 147.0, 164.0, ...
# 25      [238.0, 164.0]  [2618.0, 1429.0, 1409.0, 1259.0, 4046.0, 5408....
# 26      [433.0, 475.0]  [882.0, 547.0, 267.0, 568.0, 1201.0, 1298.0, 1...
# 27    [1926.0, 2036.0]  [448.0, 403.0, 245.0, 241.0, 540.0, 1058.0, 98...
# 28      [406.0, 402.0]  [96.0, 80.0, 55.0, 76.0, 111.0, 175.0, 169.0, ...
# 29      [356.0, 641.0]  [124.0, 98.0, 73.0, 95.0, 74.0, 139.0, 121.0, ...
# ..                 ...                                                ...
# 137   [4753.0, 5440.0]  [342.0, 291.0, 161.0, 297.0, 270.0, 439.0, 361...
# 138    [1237.0, 832.0]  [663.0, 631.0, 544.0, 810.0, 607.0, 958.0, 618...
# 139       [44.0, 39.0]   [40.0, 54.0, 24.0, 38.0, 20.0, 83.0, 49.0, 46.0]
# 140     [906.0, 857.0]  [98.0, 118.0, 79.0, 102.0, 159.0, 193.0, 193.0...
# 141     [343.0, 191.0]   [36.0, 34.0, 24.0, 45.0, 63.0, 94.0, 68.0, 82.0]
# 142      [146.0, 90.0]  [2830.0, 2974.0, 2299.0, 2598.0, 3033.0, 3575....
# 143      [152.0, 61.0]  [64.0, 81.0, 271.0, 258.0, 107.0, 186.0, 73.0,...
# 144    [1779.0, 810.0]  [47.0, 58.0, 29.0, 38.0, 99.0, 113.0, 101.0, 1...
# 145   [3410.0, 2808.0]  [228.0, 188.0, 123.0, 153.0, 110.0, 212.0, 196...
# 146   [3085.0, 1595.0]  [317.0, 257.0, 197.0, 233.0, 265.0, 582.0, 444...
# 147     [171.0, 133.0]  [209.0, 213.0, 162.0, 115.0, 163.0, 275.0, 233...
# 148  [15746.0, 8832.0]  [974.0, 680.0, 815.0, 630.0, 802.0, 1418.0, 93...
# 149     [805.0, 863.0]  [89.0, 55.0, 12.0, 83.0, 118.0, 205.0, 177.0, ...
# 150     [466.0, 648.0]   [23.0, 24.0, 15.0, 19.0, 28.0, 53.0, 39.0, 37.0]
# 151     [183.0, 140.0]  [42.0, 53.0, 38.0, 53.0, 164.0, 221.0, 195.0, ...
# 152     [316.0, 166.0]  [201.0, 237.0, 53.0, 168.0, 272.0, 293.0, 230....
# 153     [286.0, 156.0]  [284.0, 364.0, 287.0, 231.0, 318.0, 721.0, 557...
# 154     [827.0, 909.0]  [42.0, 46.0, 47.0, 74.0, 38.0, 131.0, 59.0, 52.0]
# 155     [250.0, 149.0]  [212.0, 150.0, 82.0, 129.0, 233.0, 557.0, 554....
# 156   [2759.0, 1554.0]  [3006.0, 2243.0, 1706.0, 2143.0, 2599.0, 5764....
# 157     [934.0, 480.0]  [370.0, 320.0, 206.0, 559.0, 261.0, 631.0, 565...
# 158     [429.0, 233.0]  [418.0, 459.0, 470.0, 400.0, 680.0, 1949.0, 18...
# 159     [370.0, 294.0]  [102.0, 88.0, 48.0, 49.0, 68.0, 83.0, 56.0, 75.0]
# 160     [241.0, 165.0]  [447.0, 397.0, 327.0, 337.0, 339.0, 656.0, 552...
# 161     [146.0, 164.0]  [200.0, 95.0, 87.0, 72.0, 191.0, 455.0, 388.0,...
# 162     [320.0, 341.0]  [232.0, 320.0, 119.0, 249.0, 623.0, 609.0, 666...
# 163     [561.0, 237.0]  [272.0, 275.0, 236.0, 300.0, 199.0, 478.0, 363...
# 164  [10287.0, 9603.0]  [1727.0, 2285.0, 1823.0, 1104.0, 3032.0, 2929....
# 165   [3255.0, 2665.0]  [347.0, 370.0, 231.0, 299.0, 106.0, 282.0, 229...
# 166     [527.0, 374.0]  [24.0, 63.0, 41.0, 36.0, 168.0, 308.0, 180.0, ...
#
#                                            emolex_away
# 0    [1732.0, 1670.0, 1436.0, 1569.0, 1079.0, 2217....
# 1     [36.0, 36.0, 25.0, 22.0, 27.0, 50.0, 37.0, 37.0]
# 2     [24.0, 23.0, 10.0, 20.0, 22.0, 51.0, 33.0, 46.0]
# 3     [23.0, 28.0, 17.0, 23.0, 75.0, 65.0, 68.0, 67.0]
# 4    [82.0, 59.0, 40.0, 47.0, 75.0, 130.0, 107.0, 8...
# 5    [1029.0, 1358.0, 538.0, 805.0, 441.0, 378.0, 3...
# 6    [1743.0, 1955.0, 1644.0, 1838.0, 1207.0, 2875....
# 7    [379.0, 365.0, 248.0, 315.0, 297.0, 511.0, 421...
# 8    [195.0, 233.0, 203.0, 191.0, 384.0, 725.0, 881...
# 9    [589.0, 697.0, 473.0, 643.0, 418.0, 919.0, 574...
# 10   [1466.0, 999.0, 1449.0, 1072.0, 649.0, 1182.0,...
# 11   [68.0, 57.0, 50.0, 57.0, 71.0, 112.0, 117.0, 1...
# 12   [309.0, 265.0, 263.0, 266.0, 166.0, 278.0, 235...
# 13   [106.0, 50.0, 55.0, 52.0, 81.0, 127.0, 131.0, ...
# 14   [45.0, 38.0, 14.0, 29.0, 48.0, 422.0, 114.0, 3...
# 15   [68.0, 94.0, 53.0, 83.0, 75.0, 116.0, 104.0, 1...
# 16   [257.0, 299.0, 158.0, 213.0, 257.0, 563.0, 549...
# 17         [7.0, 4.0, 3.0, 6.0, 8.0, 11.0, 13.0, 13.0]
# 18   [5618.0, 3971.0, 2348.0, 4808.0, 2367.0, 4454....
# 19   [38.0, 45.0, 32.0, 48.0, 66.0, 128.0, 111.0, 1...
# 20   [418.0, 687.0, 201.0, 883.0, 748.0, 1444.0, 13...
# 21   [535.0, 868.0, 435.0, 870.0, 507.0, 1083.0, 76...
# 22   [207.0, 255.0, 90.0, 259.0, 60.0, 108.0, 101.0...
# 23   [60.0, 72.0, 42.0, 83.0, 82.0, 175.0, 118.0, 1...
# 24       [12.0, 4.0, 3.0, 8.0, 23.0, 21.0, 22.0, 18.0]
# 25   [88.0, 71.0, 47.0, 73.0, 63.0, 131.0, 94.0, 11...
# 26   [173.0, 165.0, 145.0, 191.0, 114.0, 184.0, 174...
# 27   [875.0, 804.0, 638.0, 834.0, 613.0, 991.0, 819...
# 28   [151.0, 145.0, 130.0, 179.0, 118.0, 149.0, 130...
# 29   [316.0, 301.0, 172.0, 246.0, 116.0, 193.0, 155...
# ..                                                 ...
# 137  [2738.0, 2358.0, 1811.0, 2024.0, 1852.0, 2938....
# 138  [525.0, 492.0, 297.0, 335.0, 496.0, 667.0, 647...
# 139     [11.0, 15.0, 9.0, 9.0, 26.0, 24.0, 19.0, 22.0]
# 140  [386.0, 304.0, 340.0, 323.0, 248.0, 494.0, 400...
# 141  [59.0, 64.0, 33.0, 118.0, 239.0, 109.0, 251.0,...
# 142   [51.0, 64.0, 37.0, 26.0, 30.0, 59.0, 37.0, 46.0]
# 143   [33.0, 34.0, 18.0, 35.0, 63.0, 78.0, 60.0, 77.0]
# 144  [332.0, 356.0, 170.0, 307.0, 337.0, 972.0, 618...
# 145  [1257.0, 1373.0, 1323.0, 669.0, 1004.0, 1873.0...
# 146  [762.0, 596.0, 439.0, 748.0, 768.0, 1478.0, 14...
# 147   [59.0, 54.0, 43.0, 55.0, 54.0, 93.0, 63.0, 98.0]
# 148  [3859.0, 3542.0, 2415.0, 2010.0, 3768.0, 6537....
# 149  [407.0, 672.0, 63.0, 495.0, 415.0, 550.0, 450....
# 150  [395.0, 281.0, 228.0, 144.0, 200.0, 234.0, 197...
# 151  [93.0, 79.0, 65.0, 71.0, 49.0, 89.0, 69.0, 165.0]
# 152  [89.0, 57.0, 74.0, 60.0, 113.0, 245.0, 173.0, ...
# 153  [104.0, 122.0, 36.0, 125.0, 110.0, 210.0, 196....
# 154  [565.0, 471.0, 497.0, 403.0, 195.0, 388.0, 232...
# 155  [107.0, 55.0, 44.0, 45.0, 67.0, 129.0, 130.0, ...
# 156  [789.0, 837.0, 587.0, 671.0, 682.0, 1353.0, 11...
# 157  [235.0, 244.0, 182.0, 140.0, 233.0, 568.0, 411...
# 158  [105.0, 118.0, 87.0, 124.0, 104.0, 156.0, 102....
# 159  [138.0, 148.0, 112.0, 121.0, 95.0, 177.0, 142....
# 160  [68.0, 57.0, 44.0, 59.0, 86.0, 147.0, 111.0, 1...
# 161   [68.0, 64.0, 67.0, 75.0, 45.0, 63.0, 57.0, 91.0]
# 162  [127.0, 129.0, 90.0, 181.0, 105.0, 186.0, 144....
# 163  [103.0, 87.0, 76.0, 99.0, 158.0, 292.0, 268.0,...
# 164  [5415.0, 4184.0, 3250.0, 3005.0, 3514.0, 5692....
# 165  [2174.0, 1139.0, 622.0, 1488.0, 1885.0, 936.0,...
# 166  [179.0, 155.0, 167.0, 161.0, 239.0, 326.0, 277...
#
# [167 rows x 13 columns]

# %%
# Save as CSV
useful_methods.DFtoCSV(df, paths.DATA_HOME + "EPL/", 'all_game_emolex_counted', index=False)
print("[Saved in]: %s" % (paths.DATA_HOME + "EPL/" + 'all_game_emolex_counted.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/all_game_emolex_counted.csv

# %%
counted_game_emolex[28]
# Out:
# (None, None)
