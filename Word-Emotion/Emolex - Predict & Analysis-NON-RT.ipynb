# %%
# %pylab inline
# %matplotlib inline

import os
import time
import collections
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/Bya/git/predictEPL/utils/")
sys.path.append("/Users/Bya/git/predictEPL/config/")
sys.path.append("/Users/Bya/git/predictEPL/WebScrapping/")

import paths
import espn_urls
import my_plot
import scrap_espn_gamecast
import emolex
import useful_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')

# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]

dfGameInfos.head()
# Out:
#    GW   away_team          date    home_team  score_ft_away  score_ft_home  \
# 0   1   Tottenham  Sat. 8 Aug.        United              0              1
# 1   1     Watford  Sat. 8 Aug.       Everton              2              2
# 2   1  Sunderland  Sat. 8 Aug.     Leicester              2              4
# 3   1     Crystal  Sat. 8 Aug.       Norwich              3              1
# 4   1       Villa  Sat. 8 Aug.   Bournemouth              1              0
#
#    score_ht_away  score_ht_home   time
# 0              0              1  11:45
# 1              1              0  14:00
# 2              0              3  14:00
# 3              1              0  14:00
# 4              0              0  14:00

# %%
# HT: Equal games
# dfGameInfosEqual = dfGameInfos[(dfGameInfos['score_ht_home'] == dfGameInfos['score_ht_away']) &
#                                (dfGameInfos['GW'] >= 4)].copy()

weeks = list(dfGameInfos['GW'])
home_teams = list(dfGameInfos['home_team'])
away_teams = list(dfGameInfos['away_team'])
score_ht_homes = list(dfGameInfos['score_ht_home'])
score_ht_aways = list(dfGameInfos['score_ht_away'])
score_ft_homes = list(dfGameInfos['score_ft_home'])
score_ft_aways = list(dfGameInfos['score_ft_away'])

# %%
# Read Emotion-Lexicon-Soccer as Dictionary
dic_emolex_soccer, dic_emolex_stemmed_soccer = emolex.EmolexSoccerDic()
# Out:
# All Words: 14162

# %%
def EmolexPN(df, start=1, end=63):
    dfEmolex = df.copy()
    
    # set interval
    ith_minute_start = start
    ith_minute_end = end

    # convert to integer
    dfEmolex['ith_minute'] = [int(number) for number in dfEmolex['ith_minute']]
    dfEmolex['positive'] = [int(number) for number in dfEmolex['positive']]
    dfEmolex['negative'] = [int(number) for number in dfEmolex['negative']]

    # Minute Interval's DF
    dfEmolex = dfEmolex[
        (dfEmolex['ith_minute'] >= ith_minute_start) &
        (dfEmolex['ith_minute'] <= ith_minute_end)
    ].copy()

    # Counting pos, neg
    positive = sum(list(dfEmolex['positive']))
    negative = sum(list(dfEmolex['negative']))
    
    # Return Positve Percentage
    return (positive / (positive + negative))

# %%
res_ht_rt = []

start_time = time.time()

for index in range(len(weeks)):
    try:
        # Read Single Game as DF
        filename = home_teams[index] + '_vs_' + away_teams[index] + '.csv'
        os.chdir(paths.READ_PATH_EXTRACTED_CSV + 'GW' + str(weeks[index]) + '/SingleGames/')
        df = useful_methods.csv_dic_df(filename)

        # Filter DF: remove tweets of stream, bots ...
        dfFilter = useful_methods.FilterDF(df)

        # Count Emolex cateries on Tweets by minutes
        dfFilterEmolexSoccerHome = emolex.CreateEmolexDF(dfFilter[(dfFilter['side'] == 'home') & (dfFilter['status'] != 'retweet')], dic_emolex_soccer, dic_emolex_stemmed_soccer)
        dfFilterEmolexSoccerAway = emolex.CreateEmolexDF(dfFilter[(dfFilter['side'] == 'away') & (dfFilter['status'] != 'retweet')], dic_emolex_soccer, dic_emolex_stemmed_soccer)

        # Calculate PN %
        emolex_pn_home = EmolexPN(dfFilterEmolexSoccerHome)
        emolex_pn_away = EmolexPN(dfFilterEmolexSoccerAway)

        # Append Resulst
        res_ht_rt.append([index, emolex_pn_home, emolex_pn_away])
    except:
        continue

print("[Done]: %.2f" % (time.time() - start_time))
# Out:
# [Done]: 1463.02

# %%
ok = 0
ng = 0
eq = 0

for res in res_ht_rt:
    index, pn_home, pn_away = res
    
    if (pn_home > pn_away) and (score_ft_homes[index] > score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("\t[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))

    elif (pn_home < pn_away) and (score_ft_homes[index] < score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))
    
    elif score_ft_homes[index] == score_ft_aways[index]:
        eq += 1
    else:
        ng += 1

print("\n\n\nOK: %s, NG: %s, EQ: %s" % (ok, ng, eq))
# Out:
# ------------------------------
# [GAME]: GW4 Newcastle vs Arsenal
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.426297357529 vs 0.490097087379
#
# ------------------------------
# [GAME]: GW4 Stoke vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.307692307692 vs 0.414201183432
#
# ------------------------------
# [GAME]: GW4 Liverpool vs WestHam
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.524477918521 vs 0.73576309795
#
# ------------------------------
# [GAME]: GW4 Chelsea vs Crystal
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.58137510879 vs 0.746478873239
#
# ------------------------------
# [GAME]: GW4 Southampton vs Norwich
# [SCORE]: HT(1-0) => FT(3-0)
# 	[Emolex PN Score]: 0.671033478894 vs 0.476410730805
#
# ------------------------------
# [GAME]: GW4 Swansea vs United
# [SCORE]: HT(0-0) => FT(2-1)
# 	[Emolex PN Score]: 0.703087885986 vs 0.665343727853
#
# ------------------------------
# [GAME]: GW5 Everton vs Chelsea
# [SCORE]: HT(2-1) => FT(3-1)
# 	[Emolex PN Score]: 0.619209809264 vs 0.485288640596
#
# ------------------------------
# [GAME]: GW5 Norwich vs Bournemouth
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.794871794872 vs 0.739130434783
#
# ------------------------------
# [GAME]: GW5 Arsenal vs Stoke
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.689093188466 vs 0.647058823529
#
# ------------------------------
# [GAME]: GW5 United vs Liverpool
# [SCORE]: HT(0-0) => FT(3-1)
# 	[Emolex PN Score]: 0.571350564252 vs 0.483317595216
#
# ------------------------------
# [GAME]: GW5 WestHam vs Newcastle
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.787021630616 vs 0.523178807947
#
# ------------------------------
# [GAME]: GW6 Chelsea vs Arsenal
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.479090433873 vs 0.424489795918
#
# ------------------------------
# [GAME]: GW6 Bournemouth vs Sunderland
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.784090909091 vs 0.440476190476
#
# ------------------------------
# [GAME]: GW6 Villa vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.433835845896 vs 0.660377358491
#
# ------------------------------
# [GAME]: GW6 Newcastle vs Watford
# [SCORE]: HT(0-2) => FT(1-2)
# [Emolex PN Score]: 0.466213800501 vs 0.780068728522
#
# ------------------------------
# [GAME]: GW6 City vs WestHam
# [SCORE]: HT(1-2) => FT(1-2)
# [Emolex PN Score]: 0.619627966645 vs 0.710280373832
#
# ------------------------------
# [GAME]: GW7 Tottenham vs City
# [SCORE]: HT(1-1) => FT(4-1)
# 	[Emolex PN Score]: 0.632380952381 vs 0.616180048662
#
# ------------------------------
# [GAME]: GW7 Stoke vs Bournemouth
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.593023255814 vs 0.474626865672
#
# ------------------------------
# [GAME]: GW7 United vs Sunderland
# [SCORE]: HT(1-0) => FT(3-0)
# 	[Emolex PN Score]: 0.616913377193 vs 0.607973421927
#
# ------------------------------
# [GAME]: GW7 Liverpool vs Villa
# [SCORE]: HT(1-0) => FT(3-2)
# 	[Emolex PN Score]: 0.667609618105 vs 0.502994011976
#
# ------------------------------
# [GAME]: GW8 Crystal vs WestBromwich
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.558891454965 vs 0.389053254438
#
# ------------------------------
# [GAME]: GW8 Norwich vs Leicester
# [SCORE]: HT(0-1) => FT(1-2)
# [Emolex PN Score]: 0.516320474777 vs 0.638036809816
#
# ------------------------------
# [GAME]: GW8 Villa vs Stoke
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.536496350365 vs 0.730769230769
#
# ------------------------------
# [GAME]: GW8 Arsenal vs United
# [SCORE]: HT(3-0) => FT(3-0)
# 	[Emolex PN Score]: 0.687337830825 vs 0.569644343999
#
# ------------------------------
# [GAME]: GW9 Chelsea vs Villa
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.621372965322 vs 0.445882352941
#
# ------------------------------
# [GAME]: GW9 Crystal vs WestHam
# [SCORE]: HT(1-1) => FT(1-3)
# [Emolex PN Score]: 0.501333333333 vs 0.566801619433
#
# ------------------------------
# [GAME]: GW9 Everton vs United
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.689473684211 vs 0.783585193401
#
# ------------------------------
# [GAME]: GW9 Newcastle vs Norwich
# [SCORE]: HT(3-2) => FT(6-2)
# 	[Emolex PN Score]: 0.608436132113 vs 0.544782251438
#
# ------------------------------
# [GAME]: GW9 Swansea vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.507772020725 vs 0.552429667519
#
# ------------------------------
# [GAME]: GW10 Norwich vs WestBromwich
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.635359116022 vs 0.730375426621
#
# ------------------------------
# [GAME]: GW10 Leicester vs Crystal
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.809160305344 vs 0.594285714286
#
# ------------------------------
# [GAME]: GW10 Villa vs Swansea
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.540772532189 vs 0.612612612613
#
# ------------------------------
# [GAME]: GW10 WestHam vs Chelsea
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.687179487179 vs 0.456135966008
#
# ------------------------------
# [GAME]: GW10 Stoke vs Watford
# [SCORE]: HT(0-1) => FT(0-2)
# [Emolex PN Score]: 0.601265822785 vs 0.728813559322
#
# ------------------------------
# [GAME]: GW10 Arsenal vs Everton
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.695891415994 vs 0.47625
#
# ------------------------------
# [GAME]: GW10 Bournemouth vs Tottenham
# [SCORE]: HT(1-3) => FT(1-5)
# [Emolex PN Score]: 0.52602739726 vs 0.563063063063
#
# ------------------------------
# [GAME]: GW11 Watford vs WestHam
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.688405797101 vs 0.606299212598
#
# ------------------------------
# [GAME]: GW11 Everton vs Sunderland
# [SCORE]: HT(2-1) => FT(6-2)
# 	[Emolex PN Score]: 0.678765880218 vs 0.562628336756
#
# ------------------------------
# [GAME]: GW11 Southampton vs Bournemouth
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.812324929972 vs 0.520348837209
#
# ------------------------------
# [GAME]: GW11 Tottenham vs Villa
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.686486486486 vs 0.505212510024
#
# ------------------------------
# [GAME]: GW13 Chelsea vs Norwich
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.640404929577 vs 0.587458745875
#
# ------------------------------
# [GAME]: GW13 Everton vs Villa
# [SCORE]: HT(3-0) => FT(4-0)
# 	[Emolex PN Score]: 0.745358090186 vs 0.434013605442
#
# ------------------------------
# [GAME]: GW13 WestBromwich vs Arsenal
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.603174603175 vs 0.55883424408
#
# ------------------------------
# [GAME]: GW13 Newcastle vs Leicester
# [SCORE]: HT(0-1) => FT(0-3)
# [Emolex PN Score]: 0.466729147142 vs 0.679214402619
#
# ------------------------------
# [GAME]: GW13 Southampton vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.490099009901 vs 0.75
#
# ------------------------------
# [GAME]: GW13 City vs Liverpool
# [SCORE]: HT(1-3) => FT(1-4)
# [Emolex PN Score]: 0.49602932193 vs 0.696806304438
#
# ------------------------------
# [GAME]: GW13 Tottenham vs WestHam
# [SCORE]: HT(2-0) => FT(4-1)
# 	[Emolex PN Score]: 0.610976594027 vs 0.549450549451
#
# ------------------------------
# [GAME]: GW13 Crystal vs Sunderland
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.560267857143 vs 0.595454545455
#
# ------------------------------
# [GAME]: GW14 Sunderland vs Stoke
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.668016194332 vs 0.613861386139
#
# ------------------------------
# [GAME]: GW14 Crystal vs Newcastle
# [SCORE]: HT(3-1) => FT(5-1)
# 	[Emolex PN Score]: 0.711627906977 vs 0.48322851153
#
# ------------------------------
# [GAME]: GW14 City vs Southampton
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.702662721893 vs 0.495327102804
#
# ------------------------------
# [GAME]: GW15 Stoke vs City
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.69340974212 vs 0.468147282291
#
# ------------------------------
# [GAME]: GW15 Watford vs Norwich
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.488479262673 vs 0.482688391039
#
# ------------------------------
# [GAME]: GW15 Swansea vs Leicester
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.619246861925 vs 0.71375464684
#
# ------------------------------
# [GAME]: GW15 Chelsea vs Bournemouth
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.499712808731 vs 0.77027027027
#
# ------------------------------
# [GAME]: GW15 Newcastle vs Liverpool
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.584478577203 vs 0.486195769093
#
# ------------------------------
# [GAME]: GW16 Sunderland vs Watford
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.512345679012 vs 0.688372093023
#
# ------------------------------
# [GAME]: GW16 Crystal vs Southampton
# [SCORE]: HT(1-0) => FT(1-0)
# 	[Emolex PN Score]: 0.790076335878 vs 0.686900958466
#
# ------------------------------
# [GAME]: GW16 Bournemouth vs United
# [SCORE]: HT(1-1) => FT(2-1)
# 	[Emolex PN Score]: 0.736616702355 vs 0.595913261051
#
# ------------------------------
# [GAME]: GW16 Villa vs Arsenal
# [SCORE]: HT(0-2) => FT(0-2)
# [Emolex PN Score]: 0.45232172471 vs 0.753197372969
#
# ------------------------------
# [GAME]: GW17 WestBromwich vs Bournemouth
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.427325581395 vs 0.581280788177
#
# ------------------------------
# [GAME]: GW17 Chelsea vs Sunderland
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.549979488582 vs 0.479452054795
#
# ------------------------------
# [GAME]: GW17 Everton vs Leicester
# [SCORE]: HT(1-1) => FT(2-3)
# [Emolex PN Score]: 0.544444444444 vs 0.659663865546
#
# ------------------------------
# [GAME]: GW17 United vs Norwich
# [SCORE]: HT(0-1) => FT(1-2)
# [Emolex PN Score]: 0.611037234043 vs 0.62037037037
#
# ------------------------------
# [GAME]: GW17 Southampton vs Tottenham
# [SCORE]: HT(0-2) => FT(0-2)
# [Emolex PN Score]: 0.503759398496 vs 0.59168241966
#
# ------------------------------
# [GAME]: GW17 Watford vs Liverpool
# [SCORE]: HT(2-0) => FT(3-0)
# 	[Emolex PN Score]: 0.631007751938 vs 0.464249544258
#
# ------------------------------
# [GAME]: GW17 Arsenal vs City
# [SCORE]: HT(2-0) => FT(2-1)
# 	[Emolex PN Score]: 0.751357577752 vs 0.515719063545
#
# ------------------------------
# [GAME]: GW18 Stoke vs United
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.66404494382 vs 0.506654835847
#
# ------------------------------
# [GAME]: GW18 Tottenham vs Norwich
# [SCORE]: HT(2-0) => FT(3-0)
# 	[Emolex PN Score]: 0.543640897756 vs 0.483606557377
#
# ------------------------------
# [GAME]: GW18 Swansea vs WestBromwich
# [SCORE]: HT(1-0) => FT(1-0)
# 	[Emolex PN Score]: 0.707692307692 vs 0.429411764706
#
# ------------------------------
# [GAME]: GW18 City vs Sunderland
# [SCORE]: HT(3-0) => FT(4-1)
# 	[Emolex PN Score]: 0.71802054155 vs 0.486409155937
#
# ------------------------------
# [GAME]: GW18 Newcastle vs Everton
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.500952380952 vs 0.55574912892
#
# ------------------------------
# [GAME]: GW18 Southampton vs Arsenal
# [SCORE]: HT(1-0) => FT(4-0)
# 	[Emolex PN Score]: 0.646848989298 vs 0.557090239411
#
# ------------------------------
# [GAME]: GW19 Everton vs Stoke
# [SCORE]: HT(1-2) => FT(3-4)
# [Emolex PN Score]: 0.55223880597 vs 0.717391304348
#
# ------------------------------
# [GAME]: GW19 Norwich vs Villa
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.654901960784 vs 0.458405545927
#
# ------------------------------
# [GAME]: GW19 Watford vs Tottenham
# [SCORE]: HT(1-1) => FT(1-2)
# [Emolex PN Score]: 0.640264026403 vs 0.643338954469
#
# ------------------------------
# [GAME]: GW19 WestBromwich vs Newcastle
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.606299212598 vs 0.501008064516
#
# ------------------------------
# [GAME]: GW19 Arsenal vs Bournemouth
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.705357142857 vs 0.622047244094
#
# ------------------------------
# [GAME]: GW20 WestHam vs Liverpool
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.625 vs 0.45565571387
#
# ------------------------------
# [GAME]: GW20 Arsenal vs Newcastle
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.617500955292 vs 0.58164983165
#
# ------------------------------
# [GAME]: GW20 WestBromwich vs Stoke
# [SCORE]: HT(0-0) => FT(2-1)
# 	[Emolex PN Score]: 0.68669527897 vs 0.67032967033
#
# ------------------------------
# [GAME]: GW20 Sunderland vs Villa
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.589371980676 vs 0.488304093567
#
# ------------------------------
# [GAME]: GW20 Norwich vs Southampton
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.832653061224 vs 0.595469255663
#
# ------------------------------
# [GAME]: GW20 Crystal vs Chelsea
# [SCORE]: HT(0-1) => FT(0-3)
# [Emolex PN Score]: 0.531914893617 vs 0.545867879112
#
#
#
# OK: 84, NG: 31, EQ: 41

# %%
# Save Resulst as CSV
dfResult = dfGameInfos.copy()

def PnScore(index, side):
    for res in res_ht_rt:
        if index == res[0]:
            return res[side]
    return -1

dfResult['pn_away'] = [PnScore(index, 2) for index in range(len(weeks))]
dfResult['pn_home'] = [PnScore(index, 1) for index in range(len(weeks))]


# Save as CSV
useful_methods.DFtoCSV(dfResult, paths.READ_PATH_GAME_INFO, 'Predict-Emolex-63min-NonRT', index=False)
print("[Saved in]: %s" % (paths.READ_PATH_GAME_INFO + 'Predict-Emolex-63min-NonRT.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/Predict-Emolex-63min-NonRT.csv
