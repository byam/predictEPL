# %%
# %pylab inline
# %matplotlib inline

import os
import time
import collections
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/Bya/git/predictEPL/utils/")
sys.path.append("/Users/Bya/git/predictEPL/config/")
sys.path.append("/Users/Bya/git/predictEPL/WebScrapping/")

import paths
import espn_urls
import my_plot
import scrap_espn_gamecast
import emolex
import useful_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')

# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]

dfGameInfos.head()
# Out:
#    GW   away_team          date    home_team  score_ft_away  score_ft_home  \
# 0   1   Tottenham  Sat. 8 Aug.        United              0              1
# 1   1     Watford  Sat. 8 Aug.       Everton              2              2
# 2   1  Sunderland  Sat. 8 Aug.     Leicester              2              4
# 3   1     Crystal  Sat. 8 Aug.       Norwich              3              1
# 4   1       Villa  Sat. 8 Aug.   Bournemouth              1              0
#
#    score_ht_away  score_ht_home   time
# 0              0              1  11:45
# 1              1              0  14:00
# 2              0              3  14:00
# 3              1              0  14:00
# 4              0              0  14:00

# %%
# HT: Equal games
# dfGameInfosEqual = dfGameInfos[(dfGameInfos['score_ht_home'] == dfGameInfos['score_ht_away']) &
#                                (dfGameInfos['GW'] >= 4)].copy()

weeks = list(dfGameInfos['GW'])
home_teams = list(dfGameInfos['home_team'])
away_teams = list(dfGameInfos['away_team'])
score_ht_homes = list(dfGameInfos['score_ht_home'])
score_ht_aways = list(dfGameInfos['score_ht_away'])
score_ft_homes = list(dfGameInfos['score_ft_home'])
score_ft_aways = list(dfGameInfos['score_ft_away'])

# %%
# Read Emotion-Lexicon-Soccer as Dictionary
dic_emolex_soccer, dic_emolex_stemmed_soccer = emolex.EmolexSoccerDic()
# Out:
# All Words: 14163

# %%
def EmolexPN(df, start=1, end=63):
    dfEmolex = df.copy()
    
    # set interval
    ith_minute_start = start
    ith_minute_end = end

    # convert to integer
    dfEmolex['ith_minute'] = [int(number) for number in dfEmolex['ith_minute']]
    dfEmolex['positive'] = [int(number) for number in dfEmolex['positive']]
    dfEmolex['negative'] = [int(number) for number in dfEmolex['negative']]

    # Minute Interval's DF
    dfEmolex = dfEmolex[
        (dfEmolex['ith_minute'] >= ith_minute_start) &
        (dfEmolex['ith_minute'] <= ith_minute_end)
    ].copy()

    # Counting pos, neg
    positive = sum(list(dfEmolex['positive']))
    negative = sum(list(dfEmolex['negative']))
    
    # Return Positve Percentage
    return (positive / (positive + negative))

# %%
res_ht_rt = []

start_time = time.time()

for index in range(len(weeks)):
    try:
        # Read Single Game as DF
        filename = home_teams[index] + '_vs_' + away_teams[index] + '.csv'
        os.chdir(paths.READ_PATH_EXTRACTED_CSV + 'GW' + str(weeks[index]) + '/SingleGames/')
        df = useful_methods.csv_dic_df(filename)

        # Filter DF: remove tweets of stream, bots ...
        dfFilter = useful_methods.FilterDF(df)

        # Count Emolex cateries on Tweets by minutes
        dfFilterEmolexSoccerHome = emolex.CreateEmolexDF(dfFilter[(dfFilter['side'] == 'home') & (dfFilter['status'] != 'retweet')], dic_emolex_soccer, dic_emolex_stemmed_soccer)
        dfFilterEmolexSoccerAway = emolex.CreateEmolexDF(dfFilter[(dfFilter['side'] == 'away') & (dfFilter['status'] != 'retweet')], dic_emolex_soccer, dic_emolex_stemmed_soccer)

        # Calculate PN %
        emolex_pn_home = EmolexPN(dfFilterEmolexSoccerHome)
        emolex_pn_away = EmolexPN(dfFilterEmolexSoccerAway)

        # Append Resulst
        res_ht_rt.append([index, emolex_pn_home, emolex_pn_away])
    except:
        continue

print("[Done]: %.2f" % (time.time() - start_time))
# Out:
# [Done]: 511.58
# /Users/Bya/.virtualenvs/py3/lib/python3.4/site-packages/pandas/core/ops.py:680: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)

# %%
ok = 0
ng = 0
eq = 0

for res in res_ht_rt:
    index, pn_home, pn_away = res
    
    if (pn_home > pn_away) and (score_ft_homes[index] > score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("\t[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))

    elif (pn_home < pn_away) and (score_ft_homes[index] < score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))
    
    elif score_ft_homes[index] == score_ft_aways[index]:
        eq += 1
    else:
        ng += 1

print("\n\n\nOK: %s, NG: %s, EQ: %s" % (ok, ng, eq))
# Out:
# ------------------------------
# [GAME]: GW4 Newcastle vs Arsenal
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.403762662808 vs 0.48243045388
#
# ------------------------------
# [GAME]: GW4 Stoke vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.291428571429 vs 0.431818181818
#
# ------------------------------
# [GAME]: GW4 Liverpool vs WestHam
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.530764248705 vs 0.691489361702
#
# ------------------------------
# [GAME]: GW4 Chelsea vs Crystal
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.54233409611 vs 0.732142857143
#
# ------------------------------
# [GAME]: GW4 Southampton vs Norwich
# [SCORE]: HT(1-0) => FT(3-0)
# 	[Emolex PN Score]: 0.685871056241 vs 0.462543554007
#
# ------------------------------
# [GAME]: GW4 Swansea vs United
# [SCORE]: HT(0-0) => FT(2-1)
# 	[Emolex PN Score]: 0.69387755102 vs 0.643840956341
#
# ------------------------------
# [GAME]: GW5 Everton vs Chelsea
# [SCORE]: HT(2-1) => FT(3-1)
# 	[Emolex PN Score]: 0.603164556962 vs 0.479454361738
#
# ------------------------------
# [GAME]: GW5 Norwich vs Bournemouth
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.780487804878 vs 0.756578947368
#
# ------------------------------
# [GAME]: GW5 Arsenal vs Stoke
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.705542725173 vs 0.638888888889
#
# ------------------------------
# [GAME]: GW5 United vs Liverpool
# [SCORE]: HT(0-0) => FT(3-1)
# 	[Emolex PN Score]: 0.579754334001 vs 0.501762114537
#
# ------------------------------
# [GAME]: GW5 WestHam vs Newcastle
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.746522411128 vs 0.528773978315
#
# ------------------------------
# [GAME]: GW6 Chelsea vs Arsenal
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.433279183105 vs 0.386284722222
#
# ------------------------------
# [GAME]: GW6 Bournemouth vs Sunderland
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.773109243697 vs 0.459183673469
#
# ------------------------------
# [GAME]: GW6 Villa vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.476708074534 vs 0.674825174825
#
# ------------------------------
# [GAME]: GW6 Newcastle vs Watford
# [SCORE]: HT(0-2) => FT(1-2)
# [Emolex PN Score]: 0.469666666667 vs 0.742857142857
#
# ------------------------------
# [GAME]: GW6 City vs WestHam
# [SCORE]: HT(1-2) => FT(1-2)
# [Emolex PN Score]: 0.609236234458 vs 0.645021645022
#
# ------------------------------
# [GAME]: GW7 Tottenham vs City
# [SCORE]: HT(1-1) => FT(4-1)
# 	[Emolex PN Score]: 0.626548672566 vs 0.60056022409
#
# ------------------------------
# [GAME]: GW7 Stoke vs Bournemouth
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.588888888889 vs 0.478527607362
#
# ------------------------------
# [GAME]: GW7 Southampton vs Swansea
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.7 vs 0.685393258427
#
# ------------------------------
# [GAME]: GW7 United vs Sunderland
# [SCORE]: HT(1-0) => FT(3-0)
# 	[Emolex PN Score]: 0.619512195122 vs 0.6
#
# ------------------------------
# [GAME]: GW7 Liverpool vs Villa
# [SCORE]: HT(1-0) => FT(3-2)
# 	[Emolex PN Score]: 0.679572763685 vs 0.513139695712
#
# ------------------------------
# [GAME]: GW8 Crystal vs WestBromwich
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.571120689655 vs 0.409153952843
#
# ------------------------------
# [GAME]: GW8 Norwich vs Leicester
# [SCORE]: HT(0-1) => FT(1-2)
# [Emolex PN Score]: 0.528735632184 vs 0.650145772595
#
# ------------------------------
# [GAME]: GW8 City vs Newcastle
# [SCORE]: HT(1-1) => FT(6-1)
# 	[Emolex PN Score]: 0.629556650246 vs 0.623104693141
#
# ------------------------------
# [GAME]: GW8 Villa vs Stoke
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.53781512605 vs 0.709302325581
#
# ------------------------------
# [GAME]: GW8 Arsenal vs United
# [SCORE]: HT(3-0) => FT(3-0)
# 	[Emolex PN Score]: 0.686483920731 vs 0.572510288066
#
# ------------------------------
# [GAME]: GW9 Chelsea vs Villa
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.586845466156 vs 0.441860465116
#
# ------------------------------
# [GAME]: GW9 Crystal vs WestHam
# [SCORE]: HT(1-1) => FT(1-3)
# [Emolex PN Score]: 0.487113402062 vs 0.544117647059
#
# ------------------------------
# [GAME]: GW9 Everton vs United
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.650085763293 vs 0.731060136392
#
# ------------------------------
# [GAME]: GW9 Newcastle vs Norwich
# [SCORE]: HT(3-2) => FT(6-2)
# 	[Emolex PN Score]: 0.62938353636 vs 0.554356206631
#
# ------------------------------
# [GAME]: GW9 Swansea vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.509433962264 vs 0.565727699531
#
# ------------------------------
# [GAME]: GW10 Norwich vs WestBromwich
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.65641025641 vs 0.714754098361
#
# ------------------------------
# [GAME]: GW10 Leicester vs Crystal
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.801470588235 vs 0.6
#
# ------------------------------
# [GAME]: GW10 Villa vs Swansea
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.534113060429 vs 0.584158415842
#
# ------------------------------
# [GAME]: GW10 WestHam vs Chelsea
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.651764705882 vs 0.436768418637
#
# ------------------------------
# [GAME]: GW10 Stoke vs Watford
# [SCORE]: HT(0-1) => FT(0-2)
# [Emolex PN Score]: 0.602209944751 vs 0.723140495868
#
# ------------------------------
# [GAME]: GW10 Arsenal vs Everton
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.704901293397 vs 0.508398656215
#
# ------------------------------
# [GAME]: GW10 Bournemouth vs Tottenham
# [SCORE]: HT(1-3) => FT(1-5)
# [Emolex PN Score]: 0.523684210526 vs 0.562125107112
#
# ------------------------------
# [GAME]: GW11 Watford vs WestHam
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.705479452055 vs 0.595419847328
#
# ------------------------------
# [GAME]: GW11 Everton vs Sunderland
# [SCORE]: HT(2-1) => FT(6-2)
# 	[Emolex PN Score]: 0.665551839465 vs 0.582720588235
#
# ------------------------------
# [GAME]: GW11 Southampton vs Bournemouth
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.828877005348 vs 0.535014005602
#
# ------------------------------
# [GAME]: GW11 Tottenham vs Villa
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.696020321761 vs 0.511322132944
#
# ------------------------------
# [GAME]: GW13 Chelsea vs Norwich
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.598275862069 vs 0.570532915361
#
# ------------------------------
# [GAME]: GW13 Everton vs Villa
# [SCORE]: HT(3-0) => FT(4-0)
# 	[Emolex PN Score]: 0.691211401425 vs 0.455562461156
#
# ------------------------------
# [GAME]: GW13 WestBromwich vs Arsenal
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.669014084507 vs 0.589996477633
#
# ------------------------------
# [GAME]: GW13 Newcastle vs Leicester
# [SCORE]: HT(0-1) => FT(0-3)
# [Emolex PN Score]: 0.467476149176 vs 0.662182361734
#
# ------------------------------
# [GAME]: GW13 Southampton vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.493212669683 vs 0.745562130178
#
# ------------------------------
# [GAME]: GW13 City vs Liverpool
# [SCORE]: HT(1-3) => FT(1-4)
# [Emolex PN Score]: 0.487165178571 vs 0.68396640341
#
# ------------------------------
# [GAME]: GW13 Tottenham vs WestHam
# [SCORE]: HT(2-0) => FT(4-1)
# 	[Emolex PN Score]: 0.612804878049 vs 0.512931034483
#
# ------------------------------
# [GAME]: GW13 Crystal vs Sunderland
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.570841889117 vs 0.602941176471
#
# ------------------------------
# [GAME]: GW14 Crystal vs Newcastle
# [SCORE]: HT(3-1) => FT(5-1)
# 	[Emolex PN Score]: 0.681720430108 vs 0.484654731458
#
# ------------------------------
# [GAME]: GW14 City vs Southampton
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.618556701031 vs 0.508050089445
#
# ------------------------------
# [GAME]: GW15 Stoke vs City
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.6801517067 vs 0.47961884595
#
# ------------------------------
# [GAME]: GW15 Swansea vs Leicester
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.627306273063 vs 0.69243697479
#
# ------------------------------
# [GAME]: GW15 Chelsea vs Bournemouth
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.489583333333 vs 0.769230769231
#
# ------------------------------
# [GAME]: GW15 Newcastle vs Liverpool
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.582297000732 vs 0.527008777853
#
# ------------------------------
# [GAME]: GW16 Sunderland vs Watford
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.540389972145 vs 0.697478991597
#
# ------------------------------
# [GAME]: GW16 Crystal vs Southampton
# [SCORE]: HT(1-0) => FT(1-0)
# 	[Emolex PN Score]: 0.80073800738 vs 0.707602339181
#
# ------------------------------
# [GAME]: GW16 Bournemouth vs United
# [SCORE]: HT(1-1) => FT(2-1)
# 	[Emolex PN Score]: 0.705494505495 vs 0.602641056423
#
# ------------------------------
# [GAME]: GW16 Villa vs Arsenal
# [SCORE]: HT(0-2) => FT(0-2)
# [Emolex PN Score]: 0.461682242991 vs 0.754220779221
#
#
#
# OK: 60, NG: 25, EQ: 31
