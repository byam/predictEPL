# %%
# %pylab inline
# %matplotlib inline

import os
import time
import collections
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sys.path.append("/Users/Bya/git/predictEPL/utils/")
sys.path.append("/Users/Bya/git/predictEPL/config/")
sys.path.append("/Users/Bya/git/predictEPL/WebScrapping/")

import paths
import espn_urls
import my_plot
import scrap_espn_gamecast
import emolex
import useful_methods
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Game Infos
os.chdir(paths.READ_PATH_GAME_INFO)
dfGameInfos = useful_methods.csv_dic_df('game_infos.csv')

# Convert number strings to integers
dfGameInfos['GW'] = [int(GW) for GW in dfGameInfos['GW']]
dfGameInfos['score_ht_home'] = [int(number) for number in dfGameInfos['score_ht_home']]
dfGameInfos['score_ht_away'] = [int(number) for number in dfGameInfos['score_ht_away']]
dfGameInfos['score_ft_home'] = [int(number) for number in dfGameInfos['score_ft_home']]
dfGameInfos['score_ft_away'] = [int(number) for number in dfGameInfos['score_ft_away']]

dfGameInfos.head()
# Out:
#    GW   away_team          date    home_team  score_ft_away  score_ft_home  \
# 0   1   Tottenham  Sat. 8 Aug.        United              0              1
# 1   1     Watford  Sat. 8 Aug.       Everton              2              2
# 2   1  Sunderland  Sat. 8 Aug.     Leicester              2              4
# 3   1     Crystal  Sat. 8 Aug.       Norwich              3              1
# 4   1       Villa  Sat. 8 Aug.   Bournemouth              1              0
#
#    score_ht_away  score_ht_home   time
# 0              0              1  11:45
# 1              1              0  14:00
# 2              0              3  14:00
# 3              1              0  14:00
# 4              0              0  14:00

# %%
# HT: Equal games
# dfGameInfosEqual = dfGameInfos[(dfGameInfos['score_ht_home'] == dfGameInfos['score_ht_away']) &
#                                (dfGameInfos['GW'] >= 4)].copy()

weeks = list(dfGameInfos['GW'])
home_teams = list(dfGameInfos['home_team'])
away_teams = list(dfGameInfos['away_team'])
score_ht_homes = list(dfGameInfos['score_ht_home'])
score_ht_aways = list(dfGameInfos['score_ht_away'])
score_ft_homes = list(dfGameInfos['score_ft_home'])
score_ft_aways = list(dfGameInfos['score_ft_away'])

# %%
# Read Emotion-Lexicon-Soccer as Dictionary
dic_emolex_soccer, dic_emolex_stemmed_soccer = emolex.EmolexSoccerDic()
# Out:
# All Words: 14163

# %%
def EmolexPN(df, start=1, end=63):
    dfEmolex = df.copy()
    
    # set interval
    ith_minute_start = start
    ith_minute_end = end

    # convert to integer
    dfEmolex['ith_minute'] = [int(number) for number in dfEmolex['ith_minute']]
    dfEmolex['positive'] = [int(number) for number in dfEmolex['positive']]
    dfEmolex['negative'] = [int(number) for number in dfEmolex['negative']]

    # Minute Interval's DF
    dfEmolex = dfEmolex[
        (dfEmolex['ith_minute'] >= ith_minute_start) &
        (dfEmolex['ith_minute'] <= ith_minute_end)
    ].copy()

    # Counting pos, neg
    positive = sum(list(dfEmolex['positive']))
    negative = sum(list(dfEmolex['negative']))
    
    # Return Positve Percentage
    return (positive / (positive + negative))

# %%
res_ht_rt = []

start_time = time.time()

for index in range(len(weeks)):
    try:
        # Read Single Game as DF
        filename = home_teams[index] + '_vs_' + away_teams[index] + '.csv'
        os.chdir(paths.READ_PATH_EXTRACTED_CSV + 'GW' + str(weeks[index]) + '/SingleGames/')
        df = useful_methods.csv_dic_df(filename)

        # Filter DF: remove tweets of stream, bots ...
        dfFilter = useful_methods.FilterDF(df)

        # Count Emolex cateries on Tweets by minutes
        dfFilterEmolexSoccerHome = emolex.CreateEmolexDF(dfFilter[(dfFilter['side'] == 'home') & (dfFilter['status'] != 'retweet')], dic_emolex_soccer, dic_emolex_stemmed_soccer)
        dfFilterEmolexSoccerAway = emolex.CreateEmolexDF(dfFilter[(dfFilter['side'] == 'away') & (dfFilter['status'] != 'retweet')], dic_emolex_soccer, dic_emolex_stemmed_soccer)

        # Calculate PN %
        emolex_pn_home = EmolexPN(dfFilterEmolexSoccerHome)
        emolex_pn_away = EmolexPN(dfFilterEmolexSoccerAway)

        # Append Resulst
        res_ht_rt.append([index, emolex_pn_home, emolex_pn_away])
    except:
        continue

print("[Done]: %.2f" % (time.time() - start_time))
# Out:
# [Done]: 1465.79

# %%
ok = 0
ng = 0
eq = 0

for res in res_ht_rt:
    index, pn_home, pn_away = res
    
    if (pn_home > pn_away) and (score_ft_homes[index] > score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("\t[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))

    elif (pn_home < pn_away) and (score_ft_homes[index] < score_ft_aways[index]):
        ok += 1
        print("\n------------------------------")
        print("[GAME]: GW%s %s vs %s" %(weeks[index], home_teams[index], away_teams[index]))
        print("[SCORE]: HT(%s-%s) => FT(%s-%s)" % (score_ht_homes[index], score_ht_aways[index],
                                          score_ft_homes[index], score_ft_aways[index]))
        print("[Emolex PN Score]: %s vs %s" % (pn_home, pn_away))
    
    elif score_ft_homes[index] == score_ft_aways[index]:
        eq += 1
    else:
        ng += 1

print("\n\n\nOK: %s, NG: %s, EQ: %s" % (ok, ng, eq))
# Out:
# ------------------------------
# [GAME]: GW4 Newcastle vs Arsenal
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.409387222947 vs 0.483864581271
#
# ------------------------------
# [GAME]: GW4 Stoke vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.308157099698 vs 0.424615384615
#
# ------------------------------
# [GAME]: GW4 Liverpool vs WestHam
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.530316267692 vs 0.718894009217
#
# ------------------------------
# [GAME]: GW4 Chelsea vs Crystal
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.564937848264 vs 0.721674876847
#
# ------------------------------
# [GAME]: GW4 Southampton vs Norwich
# [SCORE]: HT(1-0) => FT(3-0)
# 	[Emolex PN Score]: 0.683965917893 vs 0.465294399234
#
# ------------------------------
# [GAME]: GW4 Swansea vs United
# [SCORE]: HT(0-0) => FT(2-1)
# 	[Emolex PN Score]: 0.700980392157 vs 0.670122803147
#
# ------------------------------
# [GAME]: GW5 Everton vs Chelsea
# [SCORE]: HT(2-1) => FT(3-1)
# 	[Emolex PN Score]: 0.620049946486 vs 0.480763750356
#
# ------------------------------
# [GAME]: GW5 Norwich vs Bournemouth
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.8 vs 0.754940711462
#
# ------------------------------
# [GAME]: GW5 Arsenal vs Stoke
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.700470688917 vs 0.607223476298
#
# ------------------------------
# [GAME]: GW5 United vs Liverpool
# [SCORE]: HT(0-0) => FT(3-1)
# 	[Emolex PN Score]: 0.585328436614 vs 0.501245680302
#
# ------------------------------
# [GAME]: GW5 WestHam vs Newcastle
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.776068376068 vs 0.533257403189
#
# ------------------------------
# [GAME]: GW6 Chelsea vs Arsenal
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.445772058824 vs 0.393594875901
#
# ------------------------------
# [GAME]: GW6 Bournemouth vs Sunderland
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.780487804878 vs 0.449138410228
#
# ------------------------------
# [GAME]: GW6 Villa vs WestBromwich
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.464995678479 vs 0.668615984405
#
# ------------------------------
# [GAME]: GW6 Newcastle vs Watford
# [SCORE]: HT(0-2) => FT(1-2)
# [Emolex PN Score]: 0.472717351764 vs 0.772646536412
#
# ------------------------------
# [GAME]: GW6 City vs WestHam
# [SCORE]: HT(1-2) => FT(1-2)
# [Emolex PN Score]: 0.612690019828 vs 0.674451858913
#
# ------------------------------
# [GAME]: GW7 Tottenham vs City
# [SCORE]: HT(1-1) => FT(4-1)
# 	[Emolex PN Score]: 0.638554216867 vs 0.619047619048
#
# ------------------------------
# [GAME]: GW7 Stoke vs Bournemouth
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.569620253165 vs 0.465079365079
#
# ------------------------------
# [GAME]: GW7 United vs Sunderland
# [SCORE]: HT(1-0) => FT(3-0)
# 	[Emolex PN Score]: 0.623531879195 vs 0.587734241908
#
# ------------------------------
# [GAME]: GW7 Liverpool vs Villa
# [SCORE]: HT(1-0) => FT(3-2)
# 	[Emolex PN Score]: 0.68543126359 vs 0.509118541033
#
# ------------------------------
# [GAME]: GW8 Crystal vs WestBromwich
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.548619447779 vs 0.398169336384
#
# ------------------------------
# [GAME]: GW8 Norwich vs Leicester
# [SCORE]: HT(0-1) => FT(1-2)
# [Emolex PN Score]: 0.535877862595 vs 0.65141955836
#
# ------------------------------
# [GAME]: GW8 City vs Newcastle
# [SCORE]: HT(1-1) => FT(6-1)
# 	[Emolex PN Score]: 0.625613079019 vs 0.621675267963
#
# ------------------------------
# [GAME]: GW8 Villa vs Stoke
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.541395348837 vs 0.743421052632
#
# ------------------------------
# [GAME]: GW8 Arsenal vs United
# [SCORE]: HT(3-0) => FT(3-0)
# 	[Emolex PN Score]: 0.687914832096 vs 0.5791776028
#
# ------------------------------
# [GAME]: GW9 Chelsea vs Villa
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.605974395448 vs 0.433600988264
#
# ------------------------------
# [GAME]: GW9 Crystal vs WestHam
# [SCORE]: HT(1-1) => FT(1-3)
# [Emolex PN Score]: 0.486111111111 vs 0.551867219917
#
# ------------------------------
# [GAME]: GW9 Everton vs United
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.692307692308 vs 0.785357268567
#
# ------------------------------
# [GAME]: GW9 Newcastle vs Norwich
# [SCORE]: HT(3-2) => FT(6-2)
# 	[Emolex PN Score]: 0.639300411523 vs 0.570647603028
#
# ------------------------------
# [GAME]: GW9 Swansea vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.50406504065 vs 0.542281879195
#
# ------------------------------
# [GAME]: GW10 Norwich vs WestBromwich
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.666666666667 vs 0.732517482517
#
# ------------------------------
# [GAME]: GW10 Leicester vs Crystal
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.825095057034 vs 0.608187134503
#
# ------------------------------
# [GAME]: GW10 Villa vs Swansea
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.536151279199 vs 0.615
#
# ------------------------------
# [GAME]: GW10 WestHam vs Chelsea
# [SCORE]: HT(1-0) => FT(2-1)
# 	[Emolex PN Score]: 0.680104031209 vs 0.439914433119
#
# ------------------------------
# [GAME]: GW10 Stoke vs Watford
# [SCORE]: HT(0-1) => FT(0-2)
# [Emolex PN Score]: 0.583333333333 vs 0.728665207877
#
# ------------------------------
# [GAME]: GW10 Arsenal vs Everton
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.70813578608 vs 0.499674690956
#
# ------------------------------
# [GAME]: GW10 Bournemouth vs Tottenham
# [SCORE]: HT(1-3) => FT(1-5)
# [Emolex PN Score]: 0.535294117647 vs 0.557914167051
#
# ------------------------------
# [GAME]: GW11 Watford vs WestHam
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.710424710425 vs 0.611336032389
#
# ------------------------------
# [GAME]: GW11 Everton vs Sunderland
# [SCORE]: HT(2-1) => FT(6-2)
# 	[Emolex PN Score]: 0.672237697307 vs 0.5841995842
#
# ------------------------------
# [GAME]: GW11 Southampton vs Bournemouth
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.822556390977 vs 0.522082018927
#
# ------------------------------
# [GAME]: GW11 Tottenham vs Villa
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.697653014266 vs 0.503787103378
#
# ------------------------------
# [GAME]: GW13 Chelsea vs Norwich
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.617300724638 vs 0.57712305026
#
# ------------------------------
# [GAME]: GW13 Everton vs Villa
# [SCORE]: HT(3-0) => FT(4-0)
# 	[Emolex PN Score]: 0.735294117647 vs 0.450222374273
#
# ------------------------------
# [GAME]: GW13 WestBromwich vs Arsenal
# [SCORE]: HT(2-1) => FT(2-1)
# 	[Emolex PN Score]: 0.661052631579 vs 0.570642897781
#
# ------------------------------
# [GAME]: GW13 Newcastle vs Leicester
# [SCORE]: HT(0-1) => FT(0-3)
# [Emolex PN Score]: 0.47008137865 vs 0.679571663921
#
# ------------------------------
# [GAME]: GW13 Southampton vs Stoke
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.461741424802 vs 0.736462093863
#
# ------------------------------
# [GAME]: GW13 City vs Liverpool
# [SCORE]: HT(1-3) => FT(1-4)
# [Emolex PN Score]: 0.492274412855 vs 0.68452668646
#
# ------------------------------
# [GAME]: GW13 Tottenham vs WestHam
# [SCORE]: HT(2-0) => FT(4-1)
# 	[Emolex PN Score]: 0.6056163535 vs 0.536782538399
#
# ------------------------------
# [GAME]: GW13 Crystal vs Sunderland
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.581632653061 vs 0.614219114219
#
# ------------------------------
# [GAME]: GW14 Sunderland vs Stoke
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.672916666667 vs 0.658031088083
#
# ------------------------------
# [GAME]: GW14 Crystal vs Newcastle
# [SCORE]: HT(3-1) => FT(5-1)
# 	[Emolex PN Score]: 0.702637889688 vs 0.493248045487
#
# ------------------------------
# [GAME]: GW14 City vs Southampton
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.646558391338 vs 0.499501495513
#
# ------------------------------
# [GAME]: GW15 Stoke vs City
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.681683899557 vs 0.482912332838
#
# ------------------------------
# [GAME]: GW15 Swansea vs Leicester
# [SCORE]: HT(0-2) => FT(0-3)
# [Emolex PN Score]: 0.643892339545 vs 0.693973634652
#
# ------------------------------
# [GAME]: GW15 Chelsea vs Bournemouth
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.486455331412 vs 0.773214285714
#
# ------------------------------
# [GAME]: GW15 Newcastle vs Liverpool
# [SCORE]: HT(0-0) => FT(2-0)
# 	[Emolex PN Score]: 0.579034255056 vs 0.524506217996
#
# ------------------------------
# [GAME]: GW16 Sunderland vs Watford
# [SCORE]: HT(0-1) => FT(0-1)
# [Emolex PN Score]: 0.536 vs 0.689903846154
#
# ------------------------------
# [GAME]: GW16 Crystal vs Southampton
# [SCORE]: HT(1-0) => FT(1-0)
# 	[Emolex PN Score]: 0.795634920635 vs 0.674255691769
#
# ------------------------------
# [GAME]: GW16 Bournemouth vs United
# [SCORE]: HT(1-1) => FT(2-1)
# 	[Emolex PN Score]: 0.727064220183 vs 0.601901494031
#
# ------------------------------
# [GAME]: GW16 Villa vs Arsenal
# [SCORE]: HT(0-2) => FT(0-2)
# [Emolex PN Score]: 0.447569803516 vs 0.755153253271
#
# ------------------------------
# [GAME]: GW17 WestBromwich vs Bournemouth
# [SCORE]: HT(0-0) => FT(1-2)
# [Emolex PN Score]: 0.408759124088 vs 0.581151832461
#
# ------------------------------
# [GAME]: GW17 Chelsea vs Sunderland
# [SCORE]: HT(2-0) => FT(3-1)
# 	[Emolex PN Score]: 0.545132241367 vs 0.467661691542
#
# ------------------------------
# [GAME]: GW17 Everton vs Leicester
# [SCORE]: HT(1-1) => FT(2-3)
# [Emolex PN Score]: 0.536827195467 vs 0.671321160043
#
# ------------------------------
# [GAME]: GW17 United vs Norwich
# [SCORE]: HT(0-1) => FT(1-2)
# [Emolex PN Score]: 0.627458584963 vs 0.63446969697
#
# ------------------------------
# [GAME]: GW17 Southampton vs Tottenham
# [SCORE]: HT(0-2) => FT(0-2)
# [Emolex PN Score]: 0.529868114818 vs 0.592160673793
#
# ------------------------------
# [GAME]: GW17 Watford vs Liverpool
# [SCORE]: HT(2-0) => FT(3-0)
# 	[Emolex PN Score]: 0.638689048761 vs 0.473828488673
#
# ------------------------------
# [GAME]: GW17 Arsenal vs City
# [SCORE]: HT(2-0) => FT(2-1)
# 	[Emolex PN Score]: 0.749741022099 vs 0.527036276523
#
# ------------------------------
# [GAME]: GW18 Stoke vs United
# [SCORE]: HT(2-0) => FT(2-0)
# 	[Emolex PN Score]: 0.662837449742 vs 0.512773722628
#
# ------------------------------
# [GAME]: GW18 Tottenham vs Norwich
# [SCORE]: HT(2-0) => FT(3-0)
# 	[Emolex PN Score]: 0.535782747604 vs 0.467860906217
#
# ------------------------------
# [GAME]: GW18 Swansea vs WestBromwich
# [SCORE]: HT(1-0) => FT(1-0)
# 	[Emolex PN Score]: 0.6953125 vs 0.415662650602
#
# ------------------------------
# [GAME]: GW18 City vs Sunderland
# [SCORE]: HT(3-0) => FT(4-1)
# 	[Emolex PN Score]: 0.694015444015 vs 0.489500362056
#
# ------------------------------
# [GAME]: GW18 Newcastle vs Everton
# [SCORE]: HT(0-0) => FT(0-1)
# [Emolex PN Score]: 0.51752677702 vs 0.55506993007
#
# ------------------------------
# [GAME]: GW18 Southampton vs Arsenal
# [SCORE]: HT(1-0) => FT(4-0)
# 	[Emolex PN Score]: 0.626699629172 vs 0.55698617072
#
# ------------------------------
# [GAME]: GW19 Everton vs Stoke
# [SCORE]: HT(1-2) => FT(3-4)
# [Emolex PN Score]: 0.52573932092 vs 0.68759811617
#
# ------------------------------
# [GAME]: GW19 Norwich vs Villa
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.661943319838 vs 0.482547993019
#
# ------------------------------
# [GAME]: GW19 Watford vs Tottenham
# [SCORE]: HT(1-1) => FT(1-2)
# [Emolex PN Score]: 0.63468013468 vs 0.642980189492
#
# ------------------------------
# [GAME]: GW19 WestBromwich vs Newcastle
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.600405679513 vs 0.50515995872
#
# ------------------------------
# [GAME]: GW19 Arsenal vs Bournemouth
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.693695805015 vs 0.605691056911
#
# ------------------------------
# [GAME]: GW20 WestHam vs Liverpool
# [SCORE]: HT(1-0) => FT(2-0)
# 	[Emolex PN Score]: 0.61300555115 vs 0.473423888971
#
# ------------------------------
# [GAME]: GW20 Arsenal vs Newcastle
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.652105159122 vs 0.567054764985
#
# ------------------------------
# [GAME]: GW20 WestBromwich vs Stoke
# [SCORE]: HT(0-0) => FT(2-1)
# 	[Emolex PN Score]: 0.680434782609 vs 0.613496932515
#
# ------------------------------
# [GAME]: GW20 Sunderland vs Villa
# [SCORE]: HT(1-0) => FT(3-1)
# 	[Emolex PN Score]: 0.602722772277 vs 0.504083147736
#
# ------------------------------
# [GAME]: GW20 Norwich vs Southampton
# [SCORE]: HT(0-0) => FT(1-0)
# 	[Emolex PN Score]: 0.824222936763 vs 0.573149741824
#
#
#
# OK: 83, NG: 32, EQ: 41

# %%
# Save Resulst as CSV
dfResult = dfGameInfos.copy()

def PnScore(index, side):
    for res in res_ht_rt:
        if index == res[0]:
            return res[side]
    return -1

dfResult['pn_away'] = [PnScore(index, 2) for index in range(len(weeks))]
dfResult['pn_home'] = [PnScore(index, 1) for index in range(len(weeks))]


# Save as CSV
useful_methods.DFtoCSV(dfResult, paths.READ_PATH_GAME_INFO, 'Predict-Emolex-63min-NonRT', index=False)
print("[Saved in]: %s" % (paths.READ_PATH_GAME_INFO + 'Predict-Emolex-63min-NonRT.csv'))
# Out:
# [Saved in]: /Users/Bya/Dropbox/Research/datas/EPL/Predict-Emolex-63min-NonRT.csv
